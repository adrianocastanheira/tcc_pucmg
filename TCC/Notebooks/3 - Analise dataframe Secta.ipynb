# %% [markdown]
# # Este notebook trata da importação do dataframe que servirá de base para os modelos de aprendizagem de máquina e está dividido da seguinte forma:
# ## 1 - Importa e processa dados do Secta (MERCADORIAS.csv)
# ## 2 - Analisa e processa coluna 'ncm'
# ## 3 - Cria funções auxiliares para o processamento da coluna descrição
# ## 4 - Analisa e processa coluna 'descricao'
# ## 5 - Cria a coluna 'descricao_limpa'
# ## 6 - Cria a coluna 'descricao_limpa_sem_stopwords'
# ## 7 - Cria a coluna 'descricao_limpa_stemming'
# ## 8 - Cria a coluna 'descricao_limpa_sem_stopwords_stemming'

# %%
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import unicodedata
import re

import nltk
from nltk.stem import RSLPStemmer
import operator

from collections import Counter, defaultdict
from wordcloud import WordCloud

import sys
sys.path.append('..')
import extras.processtec as pt

# %% [markdown]
# ## 1 - Importa e processa dados do Secta

# %%
secta = pd.read_csv('../data/MERCADORIAS.csv')

# %%
len(secta)  # tamanho do dataframe secta
# Out:
# 4467033

# %% [markdown]
# ## 1.1 - Extrai informações do dataframe:
# ### tamanho: 4.467.033
# ### - colunas:
# ### Data Registro, tipo de dado object
# ### tipo, tipo de dado object
# ### NCM, tipo de dado loat64
# ### descrição, tipo de dado object
# ### marca, tipo de dado object
# ### modelo, tipo de dado object
# ### Observacao, tipo de dado object

# %%
secta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4467033 entries, 0 to 4467032
# Data columns (total 7 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   Data Registro  object
#  1   tipo           object
#  2   NCM            float64
#  3   descrição      object
#  4   marca          object
#  5   modelo         object
#  6   Observacao     object
# dtypes: float64(1), object(6)
# memory usage: 238.6+ MB

# %%
secta.head(30)
# Out:
#           Data Registro         tipo         NCM                  descrição  \
# 0   2010-01-06 00:00:00  ELETRONICOS  95041010.0                 VIDEO GAME
# 1   2010-01-06 00:00:00  ELETRONICOS  95041010.0                 VIDEO GAME
# 2   2010-01-06 00:00:00  ELETRONICOS  95041099.0     CONTROLE DE VIDEO GAME
# 3   2010-01-06 00:00:00  ELETRONICOS  95041099.0     CONTROLE DE VIDEO GAME
# 4   2010-01-06 00:00:00  ELETRONICOS  95041099.0        ACESS DE VIDEO GAME
# 5   2010-01-06 00:00:00  ELETRONICOS  95041099.0     CONTROLE DE VIDEO GAME
# 6   2010-01-06 00:00:00  ELETRONICOS  95041099.0     CONTROLE DE VIDEO GAME
# 7   2010-01-06 00:00:00  ELETRONICOS  95041099.0        ACESS DE VIDEO GAME
# 8   2010-01-06 00:00:00     PERFUMES  33030010.0                    PERFUME
# 9   2010-01-06 00:00:00  ELETRONICOS  95041099.0   MEMORY CARD P/VIDEO GAME
# 10  2010-01-06 00:00:00       OUTRAS  85122019.0       KIT DE LAMPADA XENON
# 11  2010-01-06 00:00:00  ELETRONICOS  95049090.0       VIDEO GAME MINIATURA
# 12  2010-01-06 00:00:00  ELETRONICOS  95041010.0                 VIDEO GAME
# 13  2010-01-06 00:00:00  ELETRONICOS  85235110.0   MEMORIA FLASH P/MAQ.FOT.
# 14  2014-07-28 00:00:00     PERFUMES  33030010.0                    PERFUME
# 15  2014-07-28 00:00:00  ELETRONICOS  85171891.0                   TELEFONE
# 16  2014-07-28 00:00:00  ELETRONICOS  84703000.0        CALCULADORA DE MESA
# 17  2014-07-28 00:00:00  ELETRONICOS  84703000.0        CALCULADORA DE MESA
# 18  2014-07-28 00:00:00  ELETRONICOS  84703000.0        CALCULADORA DE MESA
# 19  2014-07-28 00:00:00  ELETRONICOS  84701000.0                CALCULADORA
# 20  2014-07-28 00:00:00  ELETRONICOS  85171211.0                WALK TALKIE
# 21  2014-07-28 00:00:00  ELETRONICOS  85183000.0             FONE DE OUVIDO
# 22  2014-07-28 00:00:00  ELETRONICOS  84703000.0        CALCULADORA DE MESA
# 23  2014-07-28 00:00:00  ELETRONICOS  85171100.0           TELEFONE SEM FIO
# 24  2014-07-28 00:00:00       OUTRAS  38089999.0                 AGROTOXICO
# 25  2014-07-28 00:00:00  ELETRONICOS  85044010.0        CARREGADOR DE PILHA
# 26  2014-07-28 00:00:00  ELETRONICOS  85271990.0                RADIO AM/FM
# 27  2014-07-28 00:00:00       OUTRAS  85232929.0          FITA DE FILMADORA
# 28  2014-07-28 00:00:00       OUTRAS  85078000.0  BATERIA DE TELEFONE S/FIO
# 29  2014-07-28 00:00:00        PNEUS  40111000.0          PNEU DE CAMIONETE
#
#         marca                       modelo Observacao
# 0   MICROSOFT                     XBOX 360        NaN
# 1        SONY                PLAYSTATION 2        NaN
# 2        SONY                          PS2        NaN
# 3        SONY                          PS3     S/ FIO
# 4        SONY                          PS2        NaN
# 5         NaN                          NaN        NaN
# 6    NINTENDO                          WII        NaN
# 7         NaN                          NaN        NaN
# 8         NaN                          NaN        NaN
# 9        SONY                         PSII        NaN
# 10        NaN                          NaN        NaN
# 11       SONY                     PSP 3000        NaN
# 12       SONY                PLAYSTATION 3        NaN
# 13        NaN                          2GB        NaN
# 14     ADIDAS  DYNAMIC - MASCULINO - 50 ML        NaN
# 15        NaN                          NaN        NaN
# 16      SHARP                        1801V        NaN
# 17      SHARP                        1750V        NaN
# 18      CASIO                          NaN        NaN
# 19      CASIO                   CIENTÍFICA        NaN
# 20        NaN                          NaN        NaN
# 21        NaN                          NaN        NaN
# 22      CANON                         5300        NaN
# 23        NaN                          NaN        NaN
# 24        NaN                          NaN        NaN
# 25        NaN                          NaN        NaN
# 26        NaN                          NaN        NaN
# 27        NaN                          NaN        NaN
# 28        NaN                          NaN        NaN
# 29        BCT                          NaN        NaN

# %%
secta.describe()
# Out:
#                 NCM
# count  4.467014e+06
# mean   6.961921e+07
# std    2.493719e+07
# min    0.000000e+00
# 25%    4.201009e+07
# 50%    8.504401e+07
# 75%    8.527199e+07
# max    1.000000e+08

# %% [markdown]
# ## Delimita o dataset para dados do ano 2021

# %%
secta = secta[secta['Data Registro'] > '2021-01-01 00:00:00']

# %%
len(secta)  # tamanho do dataframe secta
# Out:
# 174808

# %%
secta.head()
# Out:
#             Data Registro      tipo         NCM         descrição      marca  \
# 4103  2021-01-04 00:00:00    OUTRAS  85177099.0  ACESS DE CELULAR        NaN
# 4104  2021-01-04 00:00:00  PERFUMES  33030010.0           PERFUME  D HERMOSA
# 4105  2021-01-04 00:00:00  PERFUMES  33030010.0           PERFUME  D HERMOSA
# 4106  2021-01-04 00:00:00  PERFUMES  33030010.0           PERFUME  D HERMOSA
# 4107  2021-01-04 00:00:00    OUTRAS  33049990.0         MAQUIAGEM        NaN
#
#          modelo Observacao
# 4103        NaN        NaN
# 4104   MARRY ME      100ML
# 4105   REMEMBER      100ML
# 4106  ROSE GOLD      100ML
# 4107        NaN        NaN

# %% [markdown]
# ### 1.2 - renomeia colunas

# %%
# renomeia as colunas
secta = secta.rename(columns={"NCM": "ncm", "descrição": "desc", "Observacao": "observacao"})

# %% [markdown]
# ### 1.3 - exclui linhas com tipo e descrição vazias

# %%
sum(secta.desc.isna())
# Out:
# 0

# %%
secta = secta.dropna(subset=['desc'])

# %%
sum(secta.tipo.isna())
# Out:
# 0

# %%
secta = secta.dropna(subset=['tipo'])

# %% [markdown]
# ### 1.4 - substitui a descrição genérica *[OUTROS (DEMAIS TIPOS)] por espaço vazio

# %%
# quantidade de termos '*[OUTROS (DEMAIS TIPOS)]' na coluna 'desc'
len(secta[secta['desc'] == '*[OUTROS (DEMAIS TIPOS)]'])
# Out:
# 4184

# %%
# substitui '*[OUTROS (DEMAIS TIPOS)]' por vazio e verifica quantidade
secta['desc'] = secta.desc.replace('*[OUTROS (DEMAIS TIPOS)]', '')
len(secta[secta['desc'] == '*[OUTROS (DEMAIS TIPOS)]'])
# Out:
# 0

# %% [markdown]
# ### 1.5 - substitui o tipo genérico OUTRAS por espaço vazio

# %%
# quantidade de termos 'OUTRAS' na coluna 'tipo'
len(secta[secta['tipo'] == 'OUTRAS'])
# Out:
# 41721

# %%
# substitui 'OUTRAS' por vazio e verifica quantidade
secta['tipo'] = secta.tipo.replace('OUTRAS', '')
len(secta[secta['tipo'] == 'OUTRAS'])
# Out:
# 0

# %% [markdown]
# ### 1.5 - Substitui valores NaN das colunas tipo, descrição, marca, modelo e Observacao

# %%
# substitui tudo que é NaN por vazio
secta['tipo'] = secta.tipo.replace(np.nan, '', regex=True)

# %%
secta['desc'] = secta.desc.replace(np.nan, '', regex=True)

# %%
secta['marca'] = secta.marca.replace(np.nan, '', regex=True)

# %%
secta['modelo'] = secta.modelo.replace(np.nan, '', regex=True)

# %%
secta['observacao'] = secta.observacao.replace(np.nan, '', regex=True)

# %%
secta.head(30)
# Out:
#             Data Registro         tipo         ncm  \
# 4103  2021-01-04 00:00:00               85177099.0
# 4104  2021-01-04 00:00:00     PERFUMES  33030010.0
# 4105  2021-01-04 00:00:00     PERFUMES  33030010.0
# 4106  2021-01-04 00:00:00     PERFUMES  33030010.0
# 4107  2021-01-04 00:00:00               33049990.0
# 4108  2021-01-04 00:00:00   BRINQUEDOS  95030099.0
# 4956  2021-01-04 00:00:00  INFORMATICA  85256090.0
# 4957  2021-01-04 00:00:00               95045000.0
# 4958  2021-01-04 00:00:00  INFORMATICA  85291019.0
# 4959  2021-01-04 00:00:00      BEBIDAS  22087000.0
# 4960  2021-01-04 00:00:00               33059000.0
# 4961  2021-01-04 00:00:00      BEBIDAS  22083020.0
# 4962  2021-01-04 00:00:00  INFORMATICA  85176254.0
# 4963  2021-01-04 00:00:00     RELOGIOS  91021900.0
# 4964  2021-01-04 00:00:00  ELETRONICOS  85272100.0
# 4965  2021-01-04 00:00:00  INFORMATICA  85176259.0
# 4966  2021-01-04 00:00:00  INFORMATICA  85176241.0
# 4967  2021-01-04 00:00:00   VIDEOGAMES  95045000.0
# 4968  2021-01-04 00:00:00               85299020.0
# 4969  2021-01-04 00:00:00  INFORMATICA  85176249.0
# 4970  2021-01-04 00:00:00  ELETRONICOS  85235190.0
# 4971  2021-01-04 00:00:00  ELETRONICOS  85287190.0
# 4972  2021-01-04 00:00:00  ELETRONICOS  85176299.0
# 4973  2021-01-04 00:00:00  INFORMATICA  85176241.0
# 4974  2021-01-04 00:00:00               85299020.0
# 4975  2021-01-04 00:00:00               85101000.0
# 4976  2021-01-04 00:00:00  INFORMATICA  84733011.0
# 4977  2021-01-04 00:00:00               96035000.0
# 4978  2021-01-04 00:00:00  ELETRONICOS  85287190.0
# 4979  2021-01-04 00:00:00     PERFUMES  33030010.0
#
#                             desc         marca          modelo  \
# 4103            ACESS DE CELULAR
# 4104                     PERFUME     D HERMOSA        MARRY ME
# 4105                     PERFUME     D HERMOSA        REMEMBER
# 4106                     PERFUME     D HERMOSA       ROSE GOLD
# 4107                   MAQUIAGEM
# 4108                   BRINQUEDO
# 4956  ADAPTADOR USB P/REDE S/FIO       TP-LINK      ARCHER T4U
# 4957         ACESS DE VIDEO GAME      LOGITECH         X52 PRO
# 4958        ANTENA PARA INTERNET      UBIQUITI       LBE-M5-23
# 4959                       LICOR       AMARULA           750ML
# 4960         TINTURA PARA CABELO
# 4961                      UISQUE  JACK DANIELS              1L
# 4962                         HUB       TP-LINK      TL-SG1024D
# 4963            RELOGIO DE PULSO
# 4964      RADIO TOCA MP3 P/ AUTO
# 4965   UNIDADE DE REDE OTICA ONU
# 4966     ROTEADOR P/REDE SEM FIO       TP-LINK       TL-WR849N
# 4967      CONTROLE DE VIDEO GAME     MICROSOFT        XBOX ONE
# 4968          ACESS DE TELEVISAO        XIAOMI        MI BOX S
# 4969                    ROTEADOR      UBIQUITI       ROCKET AC
# 4970     SSD (SOLID STATE DRIVE)      WD GREEN           240GB
# 4971        RECEPTOR DE SATELITE      MYTV BOX
# 4972           RECEPTOR DE MIDIA        GOOGLE      CHROMECAST
# 4973              REPETIDOR WIFI
# 4974          ACESS DE TELEVISAO        XIAOMI     MI TV STICK
# 4975           APARADOR DE BARBA     PANASONIC           ER389
# 4976                    GABINETE     SATELLITE           8103K
# 4977      ESCOVA CABELO ELETRICA        QUANTA        QTES5900
# 4978        RECEPTOR DE SATELITE
# 4979                     PERFUME   TED LAPIDUS  FANTASME 100ML
#
#             observacao
# 4103
# 4104             100ML
# 4105             100ML
# 4106             100ML
# 4107
# 4108
# 4956
# 4957  S/N 1750RY000779
# 4958
# 4959
# 4960
# 4961
# 4962
# 4963
# 4964
# 4965          XPON ONU
# 4966
# 4967
# 4968
# 4969
# 4970
# 4971
# 4972
# 4973
# 4974
# 4975
# 4976
# 4977
# 4978
# 4979

# %% [markdown]
# ### 1.5 - concatena as colunas 'desc', 'marca', 'modelo' e 'observacao' e cria nova coluna chamada 'descricao'

# %%
# cria nova coluna chamada 'descricao' cujo conteúdo é a concatenação 
# das colunas 'desc', 'marca', 'modelo' e 'observacao'
secta['descricao'] = secta['tipo'] + ' ' + secta[
    'desc'].astype(str) + ' ' + secta['marca'].astype(str) +' '  + secta[
    'modelo'].astype(str) + ' '  + secta['observacao'].astype(str)

# %% [markdown]
# ### 1.6 - cria um novo dataframe com as colunas 'descricao' e 'ncm'

# %%
# cria novo dataframe com as colunas 'descricao' e 'ncm' 
secta = secta[['descricao','ncm']]

# %%
secta.head()
# Out:
#                                        descricao         ncm
# 4103                         ACESS DE CELULAR     85177099.0
# 4104   PERFUMES PERFUME D HERMOSA MARRY ME 100ML  33030010.0
# 4105   PERFUMES PERFUME D HERMOSA REMEMBER 100ML  33030010.0
# 4106  PERFUMES PERFUME D HERMOSA ROSE GOLD 100ML  33030010.0
# 4107                                MAQUIAGEM     33049990.0

# %%
len(secta)
# Out:
# 174808

# %% [markdown]
# ## 2 - Analisa e processa coluna "ncm"

# %% [markdown]
# ## 2.1 - Análise de dados não numéricos e campos vazios. Tenta transformar valores em float, o que falhar transformar em 'NaN' para depois excluir

# %%
# tenta transformar em float, se não conseguir marca como NaN
for i, value in enumerate(secta.ncm):
    try:
        float(value)
    except Exception:
        secta.ncm[i] = float('NaN')

# %%
# quantidade de itens faltantes na coluna ncm
sum(secta.ncm.isna())
# Out:
# 8

# %%
# apaga todas as linhas do dataframe onde 
# o valor da coluna ncm é valor faltante
secta = secta.dropna(subset=['ncm'])

# %%
# tamanho do dataframe após remoção
# dos valores faltantes
len(secta)
# Out:
# 174800

# %% [markdown]
# ## 2.2 - Transforma valores em números inteiros, converte para string e preenche os zeros a esquerda de modo a termos 8 caracteres no total.

# %%
secta['ncm_str'] = secta.ncm.astype(float).astype(int).astype(str)
secta['ncm_str'] = secta.ncm_str.str.zfill(8)  # preenche zeros a esquerda de modo a termos 8 caracteres no final

# %% [markdown]
# ## 2.3 Cria colunas "capitulo", "posicao", "subposicao", "item" e "subitem" -

# %%
# os dois primeiros dígitos da NCM
secta['capitulo'] = secta.ncm_str.str[:2]

# %%
# terceiro e quarto dígitos da NCM
secta['posicao'] = secta.ncm_str.str[2:4]

# %%
# quinto e sexto dígito da NCM
secta['subposicao'] = secta.ncm_str.str[4:6]

# %%
# sétimo dígito da NCM
secta['item'] = secta.ncm_str.str[6]

# %%
# oitavo dígito da NCM
secta['subitem'] = secta.ncm_str.str[7]

# %%
# apaga se tiver capitulo '00' - no DF original havia uma linha de teste com esse valor
secta = secta.drop(secta[secta['capitulo'] == '00'].index)

# %%
len(secta)
# Out:
# 174793

# %% [markdown]
# ## 2.4 - Análise estatística da coluna 'capítulo'.

# %% [markdown]
# ### 2.4.1 Cria dicionário contendo o somatório total de cada capítulo

# %%
# cira dicionário com somatório total de itens na coluna
capitulos = {}
for value in secta.capitulo:
    if capitulos.get(value):
        capitulos[value] += 1
    else:
        capitulos[value] = 1

# %% [markdown]
# ### 2.4.2 ordena do capítulos em ordem decrescente de quantidade

# %%
# ordena dicionário em ordem decrescente de quantidade
capitulos = dict(sorted(capitulos.items(), key=lambda item: item[1],reverse=True))
# exibe os 10 itens com mais registros
[(item,qtidd) for item, qtidd in capitulos.items() if qtidd > 2100]
# Out:
# [('85', 74655),
#  ('84', 20499),
#  ('33', 16486),
#  ('22', 12356),
#  ('95', 8808),
#  ('24', 5224),
#  ('90', 4055),
#  ('87', 3689),
#  ('61', 3649),
#  ('42', 2266)]

# %% [markdown]
# ### 2.4.3 Gráfico de barras da quantidade de capítulos

# %%
# Cria gráfico de barras
values = secta['capitulo'].value_counts()  # conta quantidade de valores da coluna capítulo
threshold = 3000  # define limite inferior para exibição no gráfico (exibir 10 primeiros )
mask = values > threshold  
values = values.loc[mask] # pega os valores que devem ser exibidos

# informações do gráfico
ax = values.plot(kind='bar', figsize=(14,8), title="Distribuição dos capitulos")
ax.set_xlabel("Capitulos")
ax.set_ylabel("Quantidade")
# Out:
# Text(0, 0.5, 'Quantidade')

# %% [markdown]
# ## Conclusão - 'capitulo' com maior representatividade são:'85', '84', '33', '22', '95', '24', '90', '87', '61'

# %% [markdown]
# ## 2.5 - Análise estatística da coluna 'posicao'.

# %%
# cira dicionário com somatório total de itens na coluna
posicao = {}
for value in secta.posicao:
    if posicao.get(value):
        posicao[value] += 1
    else:
        posicao[value] = 1

# ordena dicionário em ordem decrescente de quantidade
posicao = dict(sorted(posicao.items(), key=lambda item: item[1],reverse=True))
# exibe os 10 itens com mais registros
[(item,qtidd) for item, qtidd in posicao.items() if qtidd > 5100]
# Out:
# [('17', 36314),
#  ('04', 20938),
#  ('03', 18479),
#  ('71', 14402),
#  ('18', 10076),
#  ('02', 9821),
#  ('23', 6502),
#  ('28', 6076),
#  ('07', 5727)]

# %%
# Cria gráfico de barras
values = secta['posicao'].value_counts()  # conta quantidade de valores da coluna capítulo
threshold = 5100  # define limite inferior para exibição no gráfico (exibir 10 primeiros )
mask = values > threshold  
values = values.loc[mask] # pega os valores que devem ser exibidos

# informações do gráfico
ax = values.plot(kind='bar', figsize=(14,8), title="Distribuição das posições")
ax.set_xlabel("Posições")
ax.set_ylabel("Quantidade")
# Out:
# Text(0, 0.5, 'Quantidade')

# %% [markdown]
# ## Conclusão - as posições com maiores frequências acumuladas são 17, 04, 03, 71, 18, 02, 23, 28, 07

# %% [markdown]
# ## 2.6 - Análise estatística da coluna 'subposicao'.

# %%
# cira dicionário com somatório total de itens na coluna
subposicao = {}
for value in secta.subposicao:
    if subposicao.get(value):
        subposicao[value] += 1
    else:
        subposicao[value] = 1

# ordena dicionário em ordem decrescente de quantidade
subposicao = dict(sorted(subposicao.items(), key=lambda item: item[1],reverse=True))
# exibe os 10 itens com mais registros
[(item,qtidd) for item, qtidd in subposicao.items() if qtidd > 7100]
# Out:
# [('12', 17865),
#  ('00', 17041),
#  ('90', 16873),
#  ('62', 13966),
#  ('30', 12833),
#  ('21', 12567),
#  ('41', 10077),
#  ('10', 9313),
#  ('70', 8356),
#  ('20', 7888)]

# %%
values = secta['subposicao'].value_counts()
threshold = 7100
mask = values > threshold
values = values.loc[mask]

ax = values.plot(kind='bar', figsize=(14,8), title="Distribuição das subposições")
ax.set_xlabel("Subposições")
ax.set_ylabel("Quantidade")
# Out:
# Text(0, 0.5, 'Quantidade')

# %% [markdown]
# ## Conclusão - Os itens na coluna 'subposicao', os com maior representatividade (quantidade maior que 7100 itens) são: 12, 00, 90, 62, 30, 21, 41, 10, 70, 20

# %% [markdown]
# ## 2.7 - Análise estatística das colunas 'item' e 'subitem'.

# %%
# Cria gráfico de barras
values = secta['item'].value_counts()  # conta quantidade de valores da coluna capítulo

# informações do gráfico
ax = values.plot(kind='bar', figsize=(14,8), title="Distribuição dos itens")
ax.set_xlabel("Itens")
ax.set_ylabel("Quantidade")
# Out:
# Text(0, 0.5, 'Quantidade')

# %%
# Cria gráfico de barras
values = secta['subitem'].value_counts()  # conta quantidade de valores da coluna capítulo

ax = values.plot(kind='bar', figsize=(14,8), title="Distribuição dos Subitens")
ax.set_xlabel("Subitens")
ax.set_ylabel("Quantidade")
# Out:
# Text(0, 0.5, 'Quantidade')

# %% [markdown]
# ## Conclusão: o dígito 0 é o que tem maior reprensentatividade tanto para item como para subitem

# %% [markdown]
# ## 2.7 - Capítulos Faltantes:

# %%
print(f'O dataframe itens não contém o(s) capitlo(s):')
for i in range(96):
    if len(secta[secta['capitulo'] == str(i+1).zfill(2)]) == 0:
        print(f'{str(i+1).zfill(2)}', end=' ')
# Out:
# O dataframe itens não contém o(s) capitlo(s):
# 14 41 43 45 50 51 53 59 75 77 78 79 81

# %% [markdown]
# ### dataframe completo não contém os capítulos 43 53 75 77 81
# ### dataframe de 2021 não contém os capítulos 14 41 43 45 50 51 53 59 75 77 78 79 81

# %% [markdown]
# ## 3 - Cria funções que serão úteis para o processamento do texto do dataframe

# %% [markdown]
# ## 3.1 - Função que remove sinais de pontuação e espaços

# %%
def remove_accents(input_str): 
    """ 
    Função converte string em bytes, mas antes normaliza string usando NFKD
    
    NFKD - decompõem em dois code point e analisa compatibilidades (sem ser canonicamente equivalente)
    https://docs.python.org/3/library/unicodedata.html
    """
    nfkd_form = unicodedata.normalize('NFKD', input_str)
    only_ascii = nfkd_form.encode('ASCII', 'ignore')
    return only_ascii

# %% [markdown]
# ## 3.2 - Função que retorna somente o radical da palavra passada como parâmetro

# %%
st = RSLPStemmer()
def stem_word(word):
    aux = word
    if aux != b'':
        aux = st.stem(aux.decode("utf-8"))  # pega o radical das palavras
        aux = str.encode(aux)
    return aux

# %% [markdown]
# ## 3.3 - Função que verifica se é CPF ou CNPJ

# %%
def cpf_ou_cnpj(string):
    if re.search(
         "^([0-9]{2}[\.]?[0-9]{3}[\.]?[0-9]{3}[\/]?[0-9]{4}[-]?[0-9]{2})|([0-9]{3}[\.]?[0-9]{3}[\.]?[0-9]{3}[-]?[0-9]{2})$",
         word):
        return True
    return False

# %% [markdown]
# ## 3.4 - Função que processa o texto:
# ## a) convertendo para minúsculo
# ## b) removendo sinais de pontuação,
# ## c) removendo sinais ortográficos,
# ## d) remove CPF e CNPJ,
# ## e) removendo stopwords (opcional),
# ## f) retorna radicais das palavras - stemming (opcional)

# %%
def cria_coluna_descricao(dataframe, col_origem, col_destino, stop_words, stemming=False):
    num_words = Counter()
    word_count = Counter()
    times = 0
    novas_linhas = []
    col_index = dataframe.columns.get_loc(col_origem) + 1 

    for linha in dataframe.itertuples():  # para cada linha do dataframe
        lista_linha = re.split('\W+', linha[col_index].strip())  # exclui sinais de pontuação, inclusive espaços
        num_words[len(lista_linha)]+=1  # atualiza contador de quantidade de palavras
        nova_linha = []
        for word in lista_linha:
            word = word.lower()
            if word not in stop_words:  #verifica se não está nos stopword
                # verifica se não é CPF ou CNPJ
                 if not cpf_ou_cnpj(word):
                    word = remove_accents(word)  # remove acentuação
                    if stemming:
                        word = stem_word(word)  # retorna somente o radical da palavra 
                    if word == b'no':
                        print(lista_linha)
                    word_count[word]+=1  # atualiza contador de palavras
                    nova_linha.append(word.decode().strip())
        if len(nova_linha) >= 0:
            novas_linhas.append(' '.join(nova_linha))
    
    dataframe[col_destino] = novas_linhas  # cria nova coluna do dataframe com as palavras limpas
    return num_words, word_count

# %% [markdown]
# ## 4 - Analisa e processa coluna 'descricao', que servirá para criação do vocabulário

# %% [markdown]
# ## 4.1 - Criação da lista de palavras irrelevantes
# ## Antes de criar vocabulários é necessário realizar análise das palavras irrelevantes.
# ## Palavras irrelevantes são aquelas que descrevem a mercadoria num nível muito detalhado, incluindo por exemplo o nome da marca, o número de referência, etc.
# ## Exemplo de descrição: 'telefone celular marca samsung', tanto a palavra 'marca' como 'samsung' são irrelevantes para classificação.
# ## Dessa forma, iremos incluir na lista de stopwords (palavras que deverão ser eliminadas do dataframe) algumas palavras de referência (marca, ref, imitação) e a palavra seguinte a essa.

# %%
stop_words_posterior = set(['marca', 'ref', 'referencia', 'imitacao', 'modelo', 'nº', 
                            'n', 'volume', 'tamanho', 'origem'])
aux = list(stop_words_posterior)
excecao = ['gabinete', 'bulbo', 'eletrico', 'inflavel', 'componentes', 
           'diversas', 'diversos', 'digital', 'estatuetas', 'microfibra', 
          'transparentes', 'headphone', 'bracelete', 'feminino']

# %%
for linha in secta['descricao']:
    linha = remove_accents(linha).decode()
    linha = linha.lower()
    for word in aux:
        if word in linha.split():  # garante que a stopword existe na linha
            posi = re.search(r'\b(' + word + r')\b', linha).start()
            if posi:
                try:
                    stop_word = linha[posi:].split()[1]  # pega a palavra posterior à palavra procurada
                    if not stop_word in excecao:
                        stop_words_posterior.add(stop_word)
                except IndexError:
                    pass

# %%
stop_words_anterior = set(['g', 'gramas', 'kg', 'kilos', 'kilograma', 
                           'kilogramas', 'quilo','quilos', 'ml', 'l', 
                           'litro', 'litros', 'mm', 'cm', 'm', 'giga', 
                           'gigabyte', 'gigabytes', 'gb', 'tera', 'terabyte', 
                           'terabytes', 'tb'])
aux = list(stop_words_anterior)

# %%
for linha in secta['descricao']:
    linha = remove_accents(linha).decode()
    linha = linha.lower()
    for word in aux:
        if word in linha.split(): # garante que a stopword existe na linha
            posi = re.search(r'\b(' + word + r')\b', linha).start()
            if posi:
                try:
                    stop_word = linha[:posi].split()[-1]  # pega a palavra anterior à palavra procurada
                    if not stop_word in excecao:
                        stop_words_anterior.add(stop_word)
                except IndexError:
                    pass

# %%
len(stop_words_posterior), len(stop_words_anterior)
# Out:
# (1344, 500)

# %%
stop_words_itens = stop_words_posterior.union(stop_words_anterior)
len(stop_words_itens)
# Out:
# 1794

# %%
stop_words_outras = set(['brazil', '2020', '2019', 'parte', 'kit', 'xiaomi', 
                         'huawei', '', '4gb', '32gb', '64gb', '128gb', '100ml', '750ml', 
                         'no', '9', '8', 'c', 'imei', 'tp', 'link', 'redmi', 'hd'])
stop_words_itens = stop_words_itens.union(stop_words_outras)
len(stop_words_itens)
# Out:
# 1813

# %%
stop_words_posterior
# Out:
# {'a144/',
#  '8180',
#  'nj-172',
#  'mp-2218ase1',
#  'ly-576',
#  's6-v8-45w',
#  'dow',
#  '45w',
#  'ac-1',
#  '5041',
#  'f8120-1100-d107',
#  'centara',
#  'yj1012',
#  '6040',
#  '69',
#  'b-a54;',
#  'ear7+',
#  'vietna-cx1',
#  'microsoft',
#  'dell,',
#  '(mini',
#  ',modelo',
#  'sc',
#  'hr-3002',
#  'ps3',
#  'v8kz',
#  'ty-721',
#  '14',
#  'f822-235-f140',
#  'es077',
#  'm8021y',
#  '163',
#  '2013/2013,',
#  'cj-008',
#  'cv-m010037',
#  'fi0913-wx,',
#  'zenit',
#  'jn-836',
#  '2009',
#  'famosas',
#  'cp18-004',
#  'computador',
#  'bk-n20',
#  '116',
#  '690',
#  'nj-181',
#  '171',
#  '20/0285410-0',
#  '191',
#  'a-75;',
#  '1587',
#  'fossil',
#  'a174',
#  'ferrari',
#  'mini',
#  '2.mq3v',
#  'irlanda',
#  'cqn1',
#  'lc-509',
#  'b05',
#  '30q',
#  'bf03-066',
#  'pd-11',
#  'f836-350-f163',
#  'argentina',
#  'p-3;',
#  'variado',
#  'm1903f10g',
#  'florida',
#  'jn-855',
#  'indeterminado',
#  'f880-800-f219',
#  '48',
#  'ty709-12',
#  'ac-8',
#  'russia',
#  'm8305p',
#  'f850-5100-f005',
#  'c2',
#  '33-2304',
#  'bw-1902,',
#  '18780',
#  'a1480',
#  's/o',
#  '2010,',
#  'td-6000a',
#  'xb360',
#  'p80',
#  'a-81;',
#  'al-1235',
#  'ty-734',
#  '1229',
#  'b-a59;',
#  'e-28;',
#  '2sq3t',
#  'china-cx1',
#  '71',
#  'estrangeiro',
#  'yk-80a',
#  '2012',
#  'ms-1611bt',
#  'esanha',
#  'cp25-007',
#  'a1893',
#  '4',
#  'wj,',
#  '140200',
#  'xcg-001',
#  'hr-288',
#  'vc-878',
#  'a1337',
#  'f854-470-b292',
#  'ou',
#  '891',
#  '360',
#  'prologo',
#  'k10',
#  'neocurve,',
#  'f824-225-f149',
#  'macdavid',
#  '900gn',
#  'ej-i5',
#  'reino',
#  'dvd',
#  'da0692-18223482238',
#  'aparente.',
#  'gift',
#  'spain',
#  'crawford,',
#  'sk-8104',
#  'da81134',
#  'e2',
#  'paraguaya',
#  '5010',
#  'da2035',
#  'xh-1520',
#  'viatnam',
#  'china-cx',
#  '31at2',
#  'yg2007028',
#  'italy',
#  'xy71-1',
#  'ew2008',
#  'f856-470-f119',
#  'taiwan',
#  'china/tunisia',
#  'a-14;',
#  'fendi',
#  '82310',
#  '12,',
#  '(gabinete',
#  'hp',
#  'incluso',
#  'diamondlex',
#  'jl-vga',
#  'b-118',
#  'cp16-001',
#  'ly-045',
#  'eua',
#  'f838-400-e231',
#  '/proced',
#  'espanha-cx2',
#  '2494',
#  'ly-577',
#  'v8',
#  'espanha-cx3',
#  'tipo',
#  '9255',
#  'schutz',
#  'f812-750-f178',
#  'a-80;',
#  'tm-type-c',
#  'i7mini',
#  'nj-187',
#  'depo,',
#  '069',
#  'mi',
#  '10/0',
#  'nike',
#  'mxq-pro',
#  '3519',
#  'ly-480',
#  'b-121',
#  'a132/',
#  'anti',
#  '8',
#  'a1347',
#  'f815-240-f133',
#  'beard',
#  '11',
#  'eau',
#  '0c6y7m',
#  'cartier',
#  'jl-cabo',
#  '617-128',
#  'mizuno,',
#  'franca',
#  'b-a22;',
#  'cp03-034',
#  '5110',
#  'italia-cx3',
#  'y280',
#  'tt200502',
#  'exbom',
#  'ly-507',
#  '330',
#  '10',
#  'ty-728',
#  'desacompanhado',
#  'jbl',
#  'bill',
#  '*****',
#  'yj-002',
#  'hmf-250',
#  'aparentes.',
#  'hr-525',
#  'ty-730',
#  'germany',
#  'guess,',
#  '140x190',
#  'cp24-024',
#  'japaocx01',
#  'pd-025-1',
#  'japan',
#  'skate',
#  'ref',
#  '998',
#  'nj-176',
#  'f868-590-f118',
#  'venom',
#  '15',
#  'b-a4;',
#  'jn-866',
#  '20/0285428-3',
#  'juul',
#  'metabone,',
#  'ip',
#  'jl-sata',
#  'gs-995',
#  '52',
#  'mh020',
#  '307',
#  'a130/',
#  'f836-320-f211',
#  'ty-720',
#  'f824-280-f193',
#  'chuna',
#  'a18',
#  'wx06',
#  '084',
#  '238',
#  'snd321f',
#  'mod',
#  'wjl-s1160',
#  'xy68-1',
#  'tiaiwan',
#  'tyh36',
#  '2007.',
#  'cassio',
#  'da2051',
#  'md818fe/a',
#  'chh',
#  'indeterminada',
#  'f805-500-f114',
#  'ld2026',
#  'alemanha-cx2',
#  'ly-621',
#  'turquia',
#  'rj-18735',
#  'mt2',
#  'gn-l27',
#  '39',
#  'x',
#  'lg-016',
#  '125',
#  'm8202',
#  'costa',
#  'p-1;',
#  '192',
#  'n/espec.',
#  'da1988',
#  'gh-x30',
#  'samsung',
#  'f836-380-f125',
#  'f860-235-f251',
#  '2sq3v',
#  'f845-430-f135',
#  'ty-724',
#  '4kg',
#  'na',
#  'cbo',
#  'franca-cx3',
#  'sj5912am1',
#  'a-76;',
#  'sp-t24',
#  '1997,',
#  'ty-737',
#  'lk',
#  's6',
#  'ly-549',
#  'vietna.',
#  'mei03',
#  '4-6',
#  'hys',
#  'jn-858',
#  'u88',
#  '30124/60x979948',
#  'm1734',
#  '40-1',
#  'f818-250-f176',
#  'm4804h',
#  'jl-cabousb',
#  'ly-580',
#  'indeterminados',
#  '/',
#  'bs',
#  'wjl-b06-c',
#  '40mm',
#  'branco,',
#  'mexico',
#  'f820-250-d011',
#  'lef',
#  'x-6371',
#  'm8009k',
#  'bola',
#  'motor',
#  'e828-2400-c101',
#  'f848-470-f223',
#  'china/vietnan',
#  'tx3',
#  'xmsh07hm;',
#  '1-mqv-v',
#  'f850-500-f221',
#  'f848-480-f222',
#  'm8210',
#  '2020/2021',
#  'casio,',
#  'malasia',
#  'branco',
#  'k1',
#  'chosta',
#  'e10',
#  'nike,',
#  'hills',
#  'xy70-1',
#  'b-117',
#  'da1887',
#  '6316',
#  'sy-005',
#  'b-a60;',
#  '7e',
#  'el',
#  'paraguaia',
#  'new',
#  'vietnam',
#  'b-a83;',
#  '2015,',
#  'china,',
#  'ly-571',
#  'cv-m010036',
#  'fj-71',
#  'a2',
#  'f2067',
#  'm',
#  'rig',
#  '2496',
#  'usa-cx3',
#  'ly-560',
#  'mpcc-d720bt',
#  'on',
#  'f818-250-f022',
#  'monofone',
#  '3',
#  '81539',
#  'a55;',
#  'versace',
#  '1884',
#  'nangrand',
#  'a217m',
#  'multilaser',
#  'cp01',
#  'bf01-034',
#  'adulto',
#  'oakley',
#  '12',
#  'blackmagic,',
#  'a-89;',
#  '2059',
#  'pulsar',
#  'argentino',
#  '60-6010-000',
#  'v3',
#  'qiao',
#  'uc68',
#  'a1662-origem',
#  'f208',
#  'a-93',
#  'paragaui',
#  'da0888-1',
#  'ap2',
#  '1279',
#  '0502',
#  'life',
#  'r630,',
#  'a153/',
#  'f815-200-c430',
#  'a1897',
#  'p2-p2',
#  'china',
#  'fj-18732',
#  'y668',
#  's3',
#  'bf',
#  'quicksilver',
#  'cf1052',
#  'stryker',
#  'p2',
#  '20/0285400-3',
#  'nj-188',
#  'japao',
#  'ii',
#  'z2',
#  'f828-320-b553',
#  'sy-004',
#  'l4117',
#  'canada',
#  '03-01',
#  'ten',
#  '81910',
#  'happy',
#  'f835-3100-c102',
#  '1602',
#  'rohs',
#  '82335',
#  'lcd-800',
#  '2008',
#  'ps-1008',
#  'da1985',
#  'a1778',
#  'mogami,',
#  '5885',
#  '007',
#  'a2289',
#  'high',
#  '135',
#  'puma,',
#  'invicta',
#  'caixa',
#  'xf-3601',
#  '3780',
#  'eletrico,',
#  'slc-105',
#  '100x140',
#  '82297',
#  'ad',
#  'tailandia-cx2',
#  'a706,',
#  'romenia',
#  'ps2',
#  '9239',
#  '157',
#  '1-mq3-v',
#  '0240030970',
#  'bx-508',
#  'hxy-bzgg06',
#  'bl-069',
#  'cl-16001',
#  'mei01',
#  'uruguai',
#  'leci',
#  'f818-240-f105',
#  'hr-2009',
#  'f815-225-f132',
#  '0878',
#  'a1856',
#  'estrengeira',
#  '87',
#  'f818-620-d024',
#  'suica',
#  '2152',
#  '2497',
#  '(usada)',
#  'inderteminado',
#  'refreshinsole',
#  'f824-260-d601',
#  'ff',
#  'full',
#  'car-375z',
#  'forma',
#  'a1634',
#  'hr-506',
#  'xmsh10hm;',
#  'f812-205-f159',
#  'conjunto',
#  'com',
#  'xy67-1',
#  'f842-430-d114',
#  'franca-cx',
#  'a2402,',
#  'canada.',
#  '287',
#  '5884',
#  'f845-600-f138',
#  'ch48s',
#  'cp10-009',
#  'f824-275-d602',
#  'neutrik,',
#  'hr-3004',
#  '84',
#  'contendo',
#  'b-120',
#  'paraguay-cx2',
#  'sony',
#  'foranea,',
#  'knup/exbom',
#  'm2004j11g',
#  'lua',
#  '2018',
#  'mx',
#  'v90157',
#  'f825-250-f101',
#  'da1692',
#  'ps-3001',
#  'asics,',
#  'y-b39;',
#  'm1634',
#  '2264',
#  'john',
#  'ty-735',
#  'atamos,',
#  '1586',
#  '849970',
#  'chiina',
#  'storz',
#  'jn-839',
#  'ly-558',
#  '140x200',
#  'nicaragua',
#  '2378',
#  'illesteva',
#  'grace',
#  'liquido',
#  '0541',
#  '102',
#  'japao.',
#  '1ph',
#  '38/40mm',
#  'apple,',
#  '16,',
#  'x-14;',
#  'f2066',
#  'f834-325-f058',
#  '1314',
#  'f840-340-e160',
#  'estados',
#  'tailand',
#  '128000',
#  '97',
#  'hi',
#  'xbox',
#  'da0888',
#  'guerra',
#  'f830-318-f201',
#  'f820-230-f045',
#  'ly-556',
#  's031',
#  'usada',
#  'f848-280-f104',
#  'm8204',
#  'fj-18736',
#  'modelo',
#  'bolax',
#  'republica',
#  'jl-p2',
#  'imitacao',
#  '20',
#  'enjoy',
#  'china-cp03-019',
#  'sm-a107f/ds',
#  'ty738',
#  'aez1672/adq8727',
#  '2379',
#  'shimano',
#  'ada',
#  'calvin',
#  'jn-862',
#  '2236',
#  'faken',
#  's20u',
#  'ty-723',
#  'fj-91',
#  'hr-2005',
#  'prada',
#  'interruptor',
#  'bf01-076',
#  'a-32;',
#  'vietnaa',
#  'umarex',
#  'tve',
#  'key',
#  'cp03-088',
#  'f830-350-f044',
#  'feminina',
#  'g',
#  'bf01-044',
#  'h6',
#  'eureka',
#  'es',
#  'f820-250-f177',
#  'jn-860',
#  'thailan',
#  'ctf',
#  'n',
#  'f1',
#  'sptm',
#  'puma',
#  '2022',
#  'hr-2004',
#  'e3',
#  'sk-8101',
#  '501',
#  'shimano,',
#  'f868-690-d113',
#  'holder',
#  'hr-510',
#  'benzoato',
#  '5791',
#  'ray',
#  'alemanha',
#  'cp08-043',
#  'ly-593',
#  'chanel',
#  'ask',
#  'con-8147',
#  'ly-541',
#  'origem',
#  'tomate',
#  'ha-i5er',
#  'cp27-002',
#  'c-026',
#  'd5',
#  'm5457',
#  'malasia.',
#  '2.1',
#  'nj-173',
#  'pcr',
#  'kipling',
#  'colombia',
#  '266',
#  'inova',
#  'adidas',
#  'china-cx2-s/n',
#  'line',
#  'f845-520-f137',
#  '260',
#  'kit',
#  'lef-1008',
#  'mighty',
#  'a148/',
#  'b-a52;',
#  'cf1152',
#  'a1644',
#  'x-2878',
#  'tiffany',
#  'k9.',
#  '2811',
#  'parana',
#  '2012.',
#  'chile.',
#  'gran',
#  'd.5',
#  'swiss',
#  'f824-300-f160',
#  'm8305q',
#  'estado',
#  'hot',
#  'a-77;',
#  '1741',
#  'a1599',
#  'wjl-vr2',
#  '5396937-2',
#  'e850-5100-f004',
#  'espanha.',
#  'bf02-021',
#  'mexico.',
#  'c1',
#  'k-8;',
#  'f822-240-f139',
#  '100140',
#  'f822-260-b262',
#  'fh',
#  'gh-x20',
#  'hr-501',
#  'y-b35;',
#  'hcc-qc3015a',
#  'b57',
#  'e-16;',
#  'k-10;',
#  'f830-350-f110',
#  'lkm',
#  '34',
#  'f7305',
#  'ex',
#  'boost,',
#  'wi-fi',
#  '1577',
#  'ecooda',
#  'jolie',
#  '82305',
#  '38',
#  'f828-320-f112',
#  'm8304p',
#  'ms-1705bt',
#  'pys2007014',
#  'm4806q',
#  '133',
#  '(',
#  'z3',
#  '8111',
#  'i9s',
#  'f820-260-f156',
#  '126',
#  '4-9',
#  '9',
#  '60x40',
#  'lithuania',
#  '153',
#  'wifi',
#  'no.',
#  'guess',
#  'cp18-036',
#  'gucci',
#  'da1857-1',
#  'cp23-018',
#  'paraguai',
#  'apple-',
#  '60-6035-001',
#  'escocia',
#  'j-22;',
#  'm8209',
#  'paraguai.',
#  'vision',
#  'note',
#  'f812-210-f161',
#  'f820-250-f175',
#  'cf1051',
#  'ac-5',
#  '2711',
#  'p70s',
#  'ac-2',
#  'medio',
#  'tommy',
#  'obsoleto',
#  'b-a37,',
#  'franca.',
#  'evis,',
#  '6326',
#  'a131/',
#  'playstation',
#  'f836-320-f210',
#  'f830-3318-f201',
#  'africa',
#  'xl',
#  'usa',
#  '81915',
#  'f814-200-f162',
#  '168',
#  '22020',
#  '27',
#  'electrical',
#  '240-030-960',
#  'f832-360-f113',
#  'ab01',
#  '5822',
#  '10071438',
#  'vietnan',
#  'speed',
#  '-',
#  'ls',
#  'a-47;',
#  '1993,',
#  'vape',
#  'estojos',
#  '26816',
#  'de',
#  'ro',
#  'f842-330-f126',
#  '1882',
#  '1-mq2-t',
#  'a2197',
#  'slc-130',
#  '5',
#  'v380',
#  '2',
#  'airblue',
#  'francebf02-016',
#  'mtv',
#  'f868-640-d099',
#  'nj-177',
#  'cl-5552',
#  'schaeffler',
#  'f820-570-0076',
#  'hp-24',
#  'mogami',
#  'emporio',
#  '6090',
#  'ac-7',
#  'argentina.',
#  'moso',
#  '4575',
#  'm804q',
#  'cruise',
#  'f818-250-f024',
#  'nj-185',
#  'vietna',
#  'bf03-009',
#  'usb-01',
#  'a2352',
#  'g-shock',
#  'coreia',
#  'f848-235-f249',
#  'da1986',
#  'w20b66a',
#  'mp-au2319',
#  'in',
#  'typec',
#  '82303',
#  '5512',
#  'f805-530-f115',
#  '200-08',
#  '45x75',
#  'fox',
#  'ray-ban',
#  'mec,',
#  'j019',
#  'a1784',
#  'inpods',
#  'ck',
#  'm8200',
#  'f822-230-f141',
#  'alto',
#  'bf04-078',
#  'ap3',
#  'aparentes',
#  'ysl',
#  'data',
#  'f818-210-f102',
#  'louis',
#  '100',
#  'italia.',
#  '6',
#  'lef-1007',
#  'ty-727',
#  '162',
#  'cosequin',
#  'hr-3005',
#  'hr-521',
#  'sy-003',
#  '4f100415',
#  '818',
#  'china.',
#  'mod.',
#  'indetermina',
#  'm9214',
#  'qtspb50',
#  'koolertran',
#  'coship.',
#  'smok)',
#  'suporte',
#  'mink',
#  '2506',
#  'cp25-016',
#  'aparente',
#  'inglaterra',
#  'f824-270-f150',
#  'italia',
#  'a-17;',
#  'da1999',
#  'm4801h',
#  'moleton',
#  's8',
#  'g12knb,',
#  '82323',
#  'wireless',
#  'grande',
#  'da0692',
#  'chna',
#  'estrangeira',
#  'e5',
#  'zona',
#  'glam',
#  'laser',
#  'diogo',
#  'storm',
#  'p-2;',
#  'xh513-2',
#  '1088-010-000p/endoscopio',
#  '18',
#  'l',
#  'e850-5100-c100',
#  'f810-650-f179',
#  'chile/proced',
#  'a3',
#  'indonesia',
#  'le-024',
#  'nj-189',
#  'k-9;',
#  'b-05',
#  '164',
#  'setilithe',
#  'a2172,',
#  'centauro',
#  '02',
#  '7',
#  'novo',
#  'xh513-3',
#  'colt',
#  '3509',
#  'bluetooth',
#  'camboja',
#  'j-27;',
#  'y-b40;',
#  'coreia.',
#  'michael',
#  'kp-4030',
#  'olympus,',
#  's:',
#  '60x90',
#  'xh517-3',
#  '8x1',
#  'sandisk',
#  '154',
#  'marca',
#  'p-222',
#  'gl-12050',
#  'plastico',
#  '4570',
#  '66',
#  'ssx',
#  '140190',
#  'cf-2830',
#  'lacoste',
#  'portugal',
#  'doublestar,',
#  'sdc001',
#  'deruibo,',
#  '2009/2009',
#  '105',
#  'mean',
#  'rolex',
#  'f822-235-f046',
#  'letonia',
#  'hb',
#  'china-cx2',
#  'zn2426',
#  '01',
#  'ty729',
#  'm8304q',
#  'narok',
#  '257',
#  'f207',
#  'kypers',
#  'nao',
#  's-360-12',
#  'ty-736',
#  '1-mq3-t',
#  'vermelho/branco',
#  'hr-2003',
#  'f830-350-f155',
#  'b',
#  'tyh32',
#  'japao-cx',
#  'china-',
#  'paris',
#  'cl-20171',
#  'modelos',
#  '134',
#  '124',
#  'honesty',
#  '156',
#  'china-cx3',
#  'foranea',
#  'sy-006',
#  'f812-180-f120',
#  'f865-600-d098',
#  'vans',
#  '(cx',
#  'jlsp4',
#  'blusas',
#  's6-tc',
#  'y900',
#  'y330',
#  'qtspb56',
#  'da1112',
#  'sf-666',
#  'kaya',
#  'malasia-cx2',
#  'f856-450-f117',
#  'in.p.r.c',
#  '235',
#  ...}

# %% [markdown]
# ## 4.2 - Adicionar as palavras irrelevantes na lista de stopwords da biblioteca nltk

# %%
stopwords = nltk.corpus.stopwords.words('portuguese')
[stopwords.append(_) for _ in stop_words_itens]
stopwords = list(set(stopwords))  # apaga repetidas 
print(len(stopwords))
# Out:
# 2006

# %%
stopwords
# Out:
# ['',
#  'a144/',
#  'estejam',
#  '8180',
#  'nj-172',
#  's6-v8-45w',
#  'ly-576',
#  'mp-2218ase1',
#  'dow',
#  '45w',
#  'ac-1',
#  '5041',
#  'f8120-1100-d107',
#  'joico',
#  'houve',
#  'centara',
#  'yj1012',
#  '6040',
#  '69',
#  'cadeira',
#  '16,200',
#  'b-a54;',
#  'ear7+',
#  'vietna-cx1',
#  '0.3',
#  'microsoft',
#  'dell,',
#  '0,84',
#  '(mini',
#  ',modelo',
#  '2,14',
#  'sc',
#  'hr-3002',
#  'ps3',
#  'v8kz',
#  'ty-721',
#  '14',
#  'mademoiselle',
#  'freecor',
#  '34,50',
#  'f822-235-f140',
#  'es077',
#  'm8021y',
#  'galaxy',
#  '163',
#  '2013/2013,',
#  'cj-008',
#  'cv-m010037',
#  'fi0913-wx,',
#  'terão',
#  'zenit',
#  'label',
#  'jn-836',
#  'fill',
#  '2009',
#  'famosas',
#  'cp18-004',
#  'computador',
#  'liga',
#  'bk-n20',
#  '116',
#  'pea',
#  '690',
#  'nj-181',
#  '171',
#  '20/0285410-0',
#  '191',
#  'a-75;',
#  '1587',
#  'fossil',
#  'a174',
#  'ferrari',
#  'nossas',
#  'mini',
#  'tem',
#  'm.benz',
#  '2.mq3v',
#  'irlanda',
#  'cqn1',
#  'lc-509',
#  'b05',
#  '30q',
#  '700',
#  'bf03-066',
#  'kiss-236',
#  'pd-11',
#  'f836-350-f163',
#  '1300',
#  'argentina',
#  'p-3;',
#  '0,13',
#  '2000',
#  'variado',
#  'temos',
#  'm1903f10g',
#  'no',
#  'elas',
#  'anos',
#  'florida',
#  'jn-855',
#  'indeterminado',
#  'f880-800-f219',
#  '720',
#  'nossos',
#  '48',
#  'ty709-12',
#  'ac-8',
#  'russia',
#  '001',
#  'm8305p',
#  'f850-5100-f005',
#  'c2',
#  '33-2304',
#  'da',
#  'bw-1902,',
#  '18780',
#  'a1480',
#  's/o',
#  '2010,',
#  'passione-100',
#  'slender',
#  'td-6000a',
#  'xb360',
#  'p80',
#  'a-81;',
#  'al-1235',
#  '9-128',
#  'instruments',
#  'ty-734',
#  '1229',
#  'b-a59;',
#  'e-28;',
#  '2sq3t',
#  'china-cx1',
#  '71',
#  'se',
#  'estrangeiro',
#  'yk-80a',
#  '2012',
#  'ms-1611bt',
#  'esanha',
#  'cp25-007',
#  'elite',
#  'a1893',
#  'gigabytes',
#  '4',
#  'wj,',
#  '140200',
#  'terabytes',
#  'fomos',
#  '(22',
#  '4gb',
#  'xcg-001',
#  'hr-288',
#  'vc-878',
#  'estou',
#  '32gb',
#  'a1337',
#  'lens',
#  'f854-470-b292',
#  'ou',
#  '2,4',
#  '891',
#  '360',
#  'prologo',
#  'pod1.2',
#  'é',
#  'k10',
#  'neocurve,',
#  'os',
#  '58,2',
#  '10,94',
#  'f824-225-f149',
#  'seriam',
#  'macdavid',
#  '0,45',
#  '43',
#  '0,34',
#  '900gn',
#  '340',
#  '2.5',
#  'ej-i5',
#  'reino',
#  'dvd',
#  'homme-100',
#  'delas',
#  'da0692-18223482238',
#  'aparente.',
#  'gift',
#  'tenham',
#  'spain',
#  'crawford,',
#  '33,7',
#  'sk-8104',
#  'da81134',
#  'seja',
#  'e2',
#  'paraguaya',
#  '5010',
#  '256',
#  'da2035',
#  '75',
#  'xh-1520',
#  'viatnam',
#  '39,50',
#  'china-cx',
#  '31at2',
#  'yg2007028',
#  'italy',
#  'xy71-1',
#  'ew2008',
#  'f856-470-f119',
#  'lcd',
#  'taiwan',
#  '2,22',
#  'china/tunisia',
#  '710',
#  'focus',
#  'a-14;',
#  'fendi',
#  'depois',
#  '82310',
#  '12,',
#  'life-236',
#  '(gabinete',
#  '1,9',
#  'hp',
#  'incluso',
#  'diamondlex',
#  'jl-vga',
#  'b-118',
#  'cp16-001',
#  'ly-045',
#  'eua',
#  'f838-400-e231',
#  '/proced',
#  'espanha-cx2',
#  '2494',
#  'estejamos',
#  'f4000',
#  '4,5',
#  'g4',
#  'ly-577',
#  'v8',
#  '(0.20',
#  'espanha-cx3',
#  'tipo',
#  '9255',
#  '11,5',
#  '1000',
#  'schutz',
#  'f812-750-f178',
#  '388',
#  'leaves',
#  'a-80;',
#  'k-pak',
#  'tm-type-c',
#  'i7mini',
#  'nj-187',
#  'eles',
#  '6,30',
#  'depo,',
#  '0-6',
#  'estivéssemos',
#  '069',
#  'mi',
#  '10/0',
#  'nike',
#  'mxq-pro',
#  'caliburn',
#  '3519',
#  '17,5',
#  'ly-480',
#  'b-121',
#  'a132/',
#  'anti',
#  '8',
#  'a1347',
#  'f815-240-f133',
#  '355',
#  'beard',
#  '11',
#  'eau',
#  '0c6y7m',
#  'nem',
#  'cartier',
#  'givenchy',
#  'jl-cabo',
#  'mitsubishi',
#  '617-128',
#  'mizuno,',
#  'franca',
#  'b-a22;',
#  'cp03-034',
#  '5110',
#  'science',
#  'italia-cx3',
#  'y280',
#  'tt200502',
#  'exbom',
#  'ly-507',
#  'flex',
#  '330',
#  '10',
#  'ty-728',
#  'desacompanhado',
#  'jbl',
#  'bill',
#  '*****',
#  'yj-002',
#  'hmf-250',
#  'aparentes.',
#  '180',
#  'hr-525',
#  '64gb',
#  'em',
#  '95,5',
#  'ty-730',
#  'germany',
#  'guess,',
#  '140x190',
#  'cp24-024',
#  'aquelas',
#  'japaocx01',
#  'pd-025-1',
#  'japan',
#  'skate',
#  'tenha',
#  'ref',
#  'budweiser',
#  'imei',
#  '998',
#  'nj-176',
#  'f868-590-f118',
#  'picasso',
#  'venom',
#  '15',
#  'b-a4;',
#  '110',
#  '232',
#  'jn-866',
#  '20/0285428-3',
#  'juul',
#  'metabone,',
#  '35,00',
#  'ip',
#  '25',
#  'jl-sata',
#  'tiverem',
#  'gs-995',
#  '52',
#  '(0,7',
#  'mh020',
#  '307',
#  'a130/',
#  'f836-320-f211',
#  'ty-720',
#  '0,200',
#  'f824-280-f193',
#  'chuna',
#  'a18',
#  'wx06',
#  '084',
#  '238',
#  'snd321f',
#  'mod',
#  'wjl-s1160',
#  'xy68-1',
#  'tiaiwan',
#  'tyh36',
#  '2007.',
#  'cassio',
#  'da2051',
#  'md818fe/a',
#  'chh',
#  'tp',
#  'indeterminada',
#  '5.5',
#  'aorus',
#  'f805-500-f114',
#  'ld2026',
#  'alemanha-cx2',
#  'ly-621',
#  'bijuteria',
#  'turquia',
#  'rj-18735',
#  'mt2',
#  '975',
#  'gn-l27',
#  '39',
#  'x',
#  'lg-016',
#  'link',
#  '125',
#  'video',
#  'teríamos',
#  'm8202',
#  'costa',
#  'p-1;',
#  '192',
#  '3.0',
#  'n/espec.',
#  'da1988',
#  'gh-x30',
#  'samsung',
#  'f836-380-f125',
#  'f860-235-f251',
#  '865ml',
#  '2sq3v',
#  'f845-430-f135',
#  'ty-724',
#  'fortrek',
#  'estivemos',
#  '4kg',
#  'hajamos',
#  'na',
#  '1020',
#  'cbo',
#  'franca-cx3',
#  'sj5912am1',
#  'a-76;',
#  'sp-t24',
#  '1997,',
#  'ty-737',
#  'lk',
#  's6',
#  'ly-549',
#  'vietna.',
#  'mei03',
#  '4-6',
#  'me',
#  'hys',
#  '512',
#  'jn-858',
#  'f350',
#  'u88',
#  '30124/60x979948',
#  '750ml',
#  'também',
#  'my',
#  'm1734',
#  '40-1',
#  'f818-250-f176',
#  'm4804h',
#  '0,36',
#  'jl-cabousb',
#  'teu',
#  '100ml',
#  'ly-580',
#  'houverão',
#  'indeterminados',
#  '/',
#  'bs',
#  'wjl-b06-c',
#  'rutini',
#  '3.5',
#  '40mm',
#  '36',
#  'houveríamos',
#  'branco,',
#  'mexico',
#  'f820-250-d011',
#  'grenco',
#  '1,13',
#  'lef',
#  'x-6371',
#  '31.5x8',
#  'm8009k',
#  'bola',
#  'motor',
#  'pampa',
#  'e828-2400-c101',
#  'f848-470-f223',
#  'china/vietnan',
#  '900',
#  '42/44',
#  'tx3',
#  'xmsh07hm;',
#  '1-mqv-v',
#  'f850-500-f221',
#  'f848-480-f222',
#  'm8210',
#  '2020/2021',
#  'casio,',
#  'malasia',
#  'branco',
#  'sou',
#  'k1',
#  'chosta',
#  'pixma',
#  'e10',
#  'tém',
#  'nike,',
#  'hills',
#  'xy70-1',
#  'b-117',
#  'da1887',
#  'houvermos',
#  '6316',
#  'ao',
#  'sy-005',
#  '964',
#  'b-a60;',
#  '7e',
#  'el',
#  'paraguaia',
#  'new',
#  'eletronicos',
#  'vietnam',
#  'houvessem',
#  '30',
#  'b-a83;',
#  '2015,',
#  '0.35',
#  'china,',
#  'ly-571',
#  '6.25',
#  '5,8',
#  'cv-m010036',
#  'fj-71',
#  'a2',
#  'one-150',
#  'f2067',
#  'm',
#  'rig',
#  'estiver',
#  '2496',
#  'usa-cx3',
#  'ly-560',
#  'mesmo',
#  'mpcc-d720bt',
#  'on',
#  'f818-250-f022',
#  'monofone',
#  'está',
#  '3',
#  '81539',
#  'a55;',
#  'versace',
#  '1884',
#  'nangrand',
#  'a217m',
#  'vos',
#  'multilaser',
#  'cp01',
#  'bf01-034',
#  'adulto',
#  '2429',
#  'airsoft',
#  'oakley',
#  '12',
#  'blackmagic,',
#  'a-89;',
#  '2059',
#  '5,06',
#  'pulsar',
#  'aquele',
#  'argentino',
#  '60-6010-000',
#  'v3',
#  '0,92',
#  'qiao',
#  'uc68',
#  'a1662-origem',
#  'tivemos',
#  '970',
#  'f208',
#  'a-93',
#  'paragaui',
#  'memoria',
#  'da0888-1',
#  'ap2',
#  'só',
#  '1279',
#  '0502',
#  'life',
#  '03',
#  '11,60',
#  'r630,',
#  'a153/',
#  '40',
#  'houvéramos',
#  'f815-200-c430',
#  'a1897',
#  'p2-p2',
#  'china',
#  'fj-18732',
#  'y668',
#  's3',
#  'bf',
#  'quicksilver',
#  'cf1052',
#  'estão',
#  'stryker',
#  'p2',
#  '20/0285400-3',
#  'escort',
#  'scania',
#  'nj-188',
#  'esta',
#  'japao',
#  'são',
#  'ii',
#  'crystal-90',
#  'z2',
#  'f828-320-b553',
#  'philips',
#  'sy-004',
#  'caliburng',
#  'dos',
#  'será',
#  'l4117',
#  '30.',
#  'canada',
#  '375',
#  'houvera',
#  '03-01',
#  'ten',
#  '81910',
#  '270',
#  'remoto',
#  'happy',
#  'f835-3100-c102',
#  'nós',
#  '1602',
#  'eletronico',
#  'rohs',
#  '82335',
#  'lcd-800',
#  '2008',
#  'ps-1008',
#  'da1985',
#  'a1778',
#  'mogami,',
#  '5885',
#  '6,5',
#  'vocês',
#  '007',
#  '140g',
#  'a2289',
#  'high',
#  '135',
#  'tenhamos',
#  'bin',
#  'puma,',
#  'aquilo',
#  'fora',
#  'invicta',
#  'caixa',
#  'xf-3601',
#  '3780',
#  'eletrico,',
#  'c/2',
#  'digidesign',
#  'slc-105',
#  '100x140',
#  '82297',
#  'ad',
#  'tailandia-cx2',
#  '0.20',
#  'a706,',
#  'mod.prima-30-(ls21530e)-capacidade:30',
#  'romenia',
#  'ps2',
#  'celular/j120',
#  'este',
#  '9239',
#  '157',
#  '530',
#  'aos',
#  '1-mq3-v',
#  'sejamos',
#  'kilograma',
#  '0240030970',
#  'nas',
#  'bx-508',
#  'hxy-bzgg06',
#  'bl-069',
#  'cl-16001',
#  '06',
#  'artesana',
#  'mei01',
#  'uruguai',
#  '0,53',
#  'leci',
#  'f818-240-f105',
#  'hei',
#  'hr-2009',
#  'f815-225-f132',
#  'quilo',
#  '0878',
#  'a1856',
#  'coconut-150',
#  'estrengeira',
#  '87',
#  'f818-620-d024',
#  'teus',
#  'suica',
#  'litros',
#  '2152',
#  '2497',
#  '(usada)',
#  'inderteminado',
#  'refreshinsole',
#  'f824-260-d601',
#  'ff',
#  'full',
#  '2,40',
#  'car-375z',
#  'forma',
#  'a1634',
#  '0,11',
#  'hr-506',
#  'xmsh10hm;',
#  'pelos',
#  'f812-205-f159',
#  '245',
#  'conjunto',
#  'profile',
#  'com',
#  'xy67-1',
#  'f842-430-d114',
#  'kylin',
#  'uma',
#  'franca-cx',
#  'a2402,',
#  'canada.',
#  '287',
#  '5884',
#  '1500',
#  'f845-600-f138',
#  'ch48s',
#  '4410',
#  '2/4/8/16/32/64',
#  'cp10-009',
#  'f824-275-d602',
#  'neutrik,',
#  'hr-3004',
#  '84',
#  'contendo',
#  'b-120',
#  'paraguay-cx2',
#  'sony',
#  'serei',
#  'foranea,',
#  'knup/exbom',
#  'm2004j11g',
#  'per',
#  'lua',
#  '128gb',
#  '2018',
#  'mx',
#  '709',
#  'v90157',
#  'f825-250-f101',
#  'da1692',
#  'ps-3001',
#  'asics,',
#  'y-b39;',
#  'm1634',
#  '2264',
#  'n-acetyl',
#  'john',
#  'ty-735',
#  'teria',
#  'aqueles',
#  'atamos,',
#  '1586',
#  '849970',
#  '32-39-50',
#  'chiina',
#  'sejam',
#  'front',
#  'storz',
#  'jn-839',
#  'ly-558',
#  '140x200',
#  'nicaragua',
#  '2378',
#  'illesteva',
#  'grace',
#  'liquido',
#  '0541',
#  '102',
#  'japao.',
#  '1ph',
#  '38/40mm',
#  'apple,',
#  'seu',
#  '2,57',
#  '16,',
#  'x-14;',
#  'f2066',
#  'f834-325-f058',
#  'fossem',
#  'teriam',
#  '1314',
#  'f840-340-e160',
#  'luca',
#  'estados',
#  'tailand',
#  '128000',
#  '1,5',
#  'essa',
#  '97',
#  'hi',
#  'xbox',
#  'da0888',
#  'guerra',
#  'f830-318-f201',
#  'f820-230-f045',
#  'estes',
#  'ly-556',
#  'kask',
#  's031',
#  'usada',
#  'f848-280-f104',
#  'm8204',
#  'fj-18736',
#  'modelo',
#  'bolax',
#  'republica',
#  'haja',
#  'jl-p2',
#  'imitacao',
#  '20',
#  'enjoy',
#  'china-cp03-019',
#  'green',
#  'sm-a107f/ds',
#  'ty738',
#  'pressao',
#  'aez1672/adq8727',
#  '2379',
#  'shimano',
#  'ada',
#  'ventilador',
#  'calvin',
#  'jn-862',
#  '2236',
#  'faken',
#  'miyake',
#  's20u',
#  '4a',
#  'ty-723',
#  'ducato',
#  'musica',
#  'fj-91',
#  'hr-2005',
#  'prada',
#  '1125',
#  'interruptor',
#  'esse',
#  'bf01-076',
#  'a-32;',
#  'vietnaa',
#  'umarex',
#  'às',
#  'tve',
#  '95',
#  'litro',
#  '182,00',
#  'key',
#  'cp03-088',
#  'f830-350-f044',
#  'feminina',
#  '350',
#  'g',
#  'bf01-044',
#  'h6',
#  '14,56',
#  'eureka',
#  'es',
#  'f820-250-f177',
#  'jn-860',
#  '45',
#  'thailan',
#  'pela',
#  'ctf',
#  'n',
#  'f1',
#  'sptm',
#  'puma',
#  '2022',
#  'hr-2004',
#  'e3',
#  '473',
#  'não',
#  'sk-8101',
#  '501',
#  'drive)',
#  'estavam',
#  'shimano,',
#  'estivéramos',
#  'tivéramos',
#  'f868-690-d113',
#  'holder',
#  'c/20',
#  'hr-510',
#  '32,5',
#  'benzoato',
#  '7.5',
#  '5791',
#  'ray',
#  '24o',
#  'lhe',
#  '120',
#  'alemanha',
#  'cp08-043',
#  'ly-593',
#  'chanel',
#  'estive',
#  'ask',
#  'con-8147',
#  'ly-541',
#  'origem',
#  'tomate',
#  'ha-i5er',
#  'cp27-002',
#  'ac',
#  'c-026',
#  'd5',
#  'tuas',
#  'minha',
#  '1.2',
#  'm5457',
#  'malasia.',
#  '20,10',
#  '2.1',
#  'nj-173',
#  '240',
#  'pcr',
#  '10,84',
#  'cpu)',
#  'terá',
#  '600',
#  'kipling',
#  'colombia',
#  '266',
#  '1,59',
#  'à',
#  'inova',
#  'caminhao',
#  'adidas',
#  'china-cx2-s/n',
#  'line',
#  'f845-520-f137',
#  '260',
#  '08',
#  'kit',
#  'vertica',
#  'lef-1008',
#  'mighty',
#  'a148/',
#  '3/4',
#  'b-a52;',
#  'cf1152',
#  '3,54',
#  'a1644',
#  'x-2878',
#  'tiffany',
#  'k9.',
#  'we',
#  'como',
#  '2811',
#  'parana',
#  '44',
#  '3,5',
#  'quilmes',
#  '2012.',
#  'chile.',
#  'gran',
#  'for',
#  'd.5',
#  'swiss',
#  'esteve',
#  'f824-300-f160',
#  'm8305q',
#  'tivéssemos',
#  'hot',
#  'estado',
#  'houveriam',
#  'tivera',
#  'a-77;',
#  '325',
#  'esses',
#  '425',
#  'brazil',
#  '1741',
#  'a1599',
#  'wjl-vr2',
#  '5396937-2',
#  'e850-5100-f004',
#  'espanha.',
#  'te',
#  'bf02-021',
#  'mexico.',
#  'éramos',
#  'c1',
#  'k-8;',
#  ...]

# %% [markdown]
# ## 5 - Cria a coluna 'descricao_limpa'
# ## 5.1 - Nessa coluna não foram retiradas as stopwords e também não foram retirados os afixos

# %%
# cria a coluna descricao_limpa sem informar nenhuma stopword e sem fazer o stemming
num_words, word_count = cria_coluna_descricao(secta, 'descricao', 'descricao_limpa', "")
# Out:
# ['CIGARROS', 'CHARUTO', 'PARTAGAS', 'MADURO', 'NO', '1', 'CAIXA', 'COM', '25', 'UNIDADES']
# ['CIGARROS', 'CHARUTO', 'PARTAGAS', 'SERIE', 'E', 'NO', '2', 'CAIXA', 'COM', '25', 'UNIDADES']
# ['CIGARROS', 'CHARUTO', 'HOYO', 'DE', 'MONTERREY', 'EPICURE', 'NO', '2', 'CAIXA', 'COM', '25', 'UNIDADES']
# ['INFORMATICA', 'PLACA', 'MAE', 'ASUS', 'PRIME', 'A320M', 'K', 'INSTALADA', 'NO', 'GABINETE']
# ['INFORMATICA', 'COOLER', 'VENTILADOR', 'CPU', 'AMD', 'INSTALADO', 'NO', 'GAINETE']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'NO', '168', '25ML']
# ['PERFUMES', 'PERFUME', 'BRAND', 'COLLECTION', 'NO', '152', '25ML']
# ['PERFUMES', 'PERFUME', 'BRAND', 'COLLECTION', 'NO', '235', '25ML']
# ['PERFUMES', 'PERFUME', 'BRAND', 'COLLECTION', 'NO', '250', '25ML']
# ['CREME', 'PROD', 'BELEZA', 'DREAM', 'BRAND', 'NO', '194', '200ML']
# ['PERFUMES', 'PERFUME', 'BRAND', 'COLECTION', 'NO', '010', '25ML']
# ['BEBIDAS', 'UISQUE', 'JACK', 'DANIELS', 'OLD', 'Nº', '7', '1', 'LITRO']
# ['PERFUMES', 'PERFUME', 'BRAND', 'COLLECTION', 'NO', '003', '25ML']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'COLLECTION', 'NO', '070', '25ML']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'COLLECTION', 'NO', '116', '25ML']
# ['CREMES', 'HIDRATANTES', 'DREAM', 'BRAND', 'NO', '021', 'NO', '168', 'NO', '097', 'NO', '069', '200ML']
# ['CREMES', 'HIDRATANTES', 'DREAM', 'BRAND', 'NO', '021', 'NO', '168', 'NO', '097', 'NO', '069', '200ML']
# ['CREMES', 'HIDRATANTES', 'DREAM', 'BRAND', 'NO', '021', 'NO', '168', 'NO', '097', 'NO', '069', '200ML']
# ['CREMES', 'HIDRATANTES', 'DREAM', 'BRAND', 'NO', '021', 'NO', '168', 'NO', '097', 'NO', '069', '200ML']
# ['PERFUMES', 'PERFUME', 'BRAND', 'COLLECTION', 'NO', '100', '25ML']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'NO', '012', '25ML']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'NO', '136', '25ML']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'NO', '087', '25ML']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'NO', '070', '25ML']
# ['LINHA', 'DE', 'PESCA', 'MARURI', 'NO', '50', '100M']
# ['PERFUMES', 'PERFUME', 'CHANEL', 'nº', '5', '100ml']
# ['PERFUMES', 'PERFUME', 'CHANEL', 'nº', '5', '100ml']
# ['PERFUMES', 'PERFUME', 'CHANEL', 'nº', '5', '100ml']
# ['BEBIDAS', 'UISQUE', 'JACK', 'DANIELS', 'OLD', 'NO', '7']
# ['BEBIDAS', 'UISQUE', 'JACK', 'DANIELS', 'OLD', 'NO', '7', 'BRAND']
# ['BROCA', 'PARA', 'FURADEIRA', 'IRVEN', 'Nº', '28']
# ['BROCA', 'PARA', 'FURADEIRA', 'IRVEN', 'Nº', '28']
# ['PERFUMES', 'PERFUME', 'CHANEL', 'Nº', '5', '100', 'ML']
# ['PERFUMES', 'PERFUME', 'CHANEL', 'Nº', '5']
# ['PERFUMES', 'PERFUME', 'CHANEL', 'Nº', '5']
# ['CIGARROS', 'CIGARRO', 'CLASSIC', 'FABRICADO', 'NO', 'PARAGUAI']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'NO', '161', '25ML']
# ['ARMAS', 'APARELHO', 'DE', 'CHOQUE', 'ART', 'NO', '801', '']
# ['PARTES', 'E', 'PEÇAS', 'CX', 'ELETRON', 'SUPORTE', 'PLASTICO', 'PARA', 'FLUXO', 'DE', 'NOTAS', 'NO', 'CAIXA', 'ELETRONICO']
# ['MEDICAMENTOS', 'SUPLEMENTO', 'VITAMINICO', 'NO', 'FLUSCH', 'NIACIN', '800MG', '100', 'CAP']
# ['PARTES', 'E', 'PEÇAS', 'OUTRAS', 'MAQUINAS', 'SUPORTE', 'DO', 'CONTROLADOR', 'DIGITAL', 'PARA', 'AQUECIMENTO', 'DE', 'PNEUS', 'NO', 'BOX']
# ['BOLSAS', 'BOLSA', 'DE', 'VIAGEM', 'USADA', 'UTILIZADA', 'NO', 'TRANSPORTE', 'DAS', 'MERCADORIAS', '']
# ['PERFUMES', 'PERFUME', 'BRAND', 'COLLECTION', 'Nº', '191']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'Nº', '5']
# ['PERFUMES', 'PERFUME', 'BRAND', 'COLLETION', 'Nº', '076']
# ['PERFUMES', 'PERFUME', 'BRAND', 'COLLETION', 'Nº', '171']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'Nº', '116']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'Nº', '008']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'Nº', '009']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'Nº', '100']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'Nº', '153']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'Nº', '154']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'Nº', '007']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'Nº', '087']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'Nº', '124']
# ['PNEUS', 'PNEU', 'DE', 'CAMINHAO', 'DOUBLESTAR', 'INSTALADOS', 'NO', 'VEICULO']
# ['PNEUS', 'PNEU', 'DE', 'CAMINHAO', 'DERUBIO', 'INSTALADOS', 'NO', 'VEICULO']
# ['PNEUS', 'PNEU', 'DE', 'CAMINHAO', 'DOUBLESTAR', 'INSTALADOS', 'NO', 'VEICULO']
# ['PNEUS', 'PNEU', 'DE', 'CAMINHAO', 'DERUBIO', 'INSTALADOS', 'NO', 'VEICULO']
# ['PNEUS', 'PNEU', 'DE', 'CAMINHAO', 'SUNSET', 'INSTALADOS', 'NO', 'VEICULO']
# ['PNEUS', 'PNEU', 'DE', 'CAMINHAO', 'PNEUS', 'INST', 'NO', 'VEICULO', '']
# ['INFORMATICA', 'IMPRESSORA', 'HP', 'LASER', '0135W', '110V', 'SERIE', 'NO', 'CNB3M5VBMS']
# ['INFORMATICA', 'IMPRESSORA', 'HP', 'LASER', '0135W', '110V', 'SERIE', 'NO', 'CMB1M5ZXOZ']
# ['INFORMATICA', 'IMPRESSORA', 'HP', 'LASER', 'M107W', '110V', 'SERIE', 'NO', 'CNB1N3W5GT']
# ['PERFUMES', 'PERFUME', 'BRAND', 'COLLECTION', 'Nº', '191']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'Nº', '5']
# ['PERFUMES', 'PERFUME', 'BRAND', 'COLLETION', 'Nº', '076']
# ['PERFUMES', 'PERFUME', 'BRAND', 'COLLETION', 'Nº', '171']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'Nº', '116']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'Nº', '008']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'Nº', '009']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'Nº', '100']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'Nº', '153']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'Nº', '154']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'Nº', '007']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'Nº', '087']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'Nº', '124']
# ['VEICULOS', 'CAVALO', 'MECANICO', 'SCANIA', 'BWO', '7416', '1987', '1987', 'BRANCA', 'CHASSI', '9BSTH4X2ZH3225880', 'RENAVAM', '00367424312', 'PNEUS', 'INST', 'NO', 'VEICULO']
# ['PNEUS', 'PNEU', 'DE', 'CAMINHAO', 'AUTONE', '295', '80R22', '5', 'PNEUS', 'INST', 'NO', 'VEICULO', '']
# ['PNEUS', 'PNEU', 'DE', 'CAMINHAO', 'LONG', 'MARCH', '295', '80R22', '5', 'PNEUS', 'INST', 'NO', 'VEICULO', '']
# ['PNEUS', 'PNEU', 'DE', 'CAMINHAO', 'LONG', 'MARCH', '275', '80R22', '5', 'PNEUS', 'INST', 'NO', 'VEICULO', '']
# ['PNEUS', 'PNEU', 'DE', 'CAMINHAO', 'LONG', 'MARCH', '295', '80R22', '5', 'INST', 'NO', 'ESTEPE', '']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'APPLE', 'SERIES', '3', 'Nº', 'S', 'SGJ9D3YXBJ5X0', '38MM']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9S', '128GB', 'Nº', 'S', '27961', '60VC00828']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9S', '128GB', 'Nº', 'S', '27281', '60VD06468']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9S', '128GB', 'Nº', 'S', '27281', '60VD05153']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9S', '128GB', 'Nº', 'S', '27961', '60VC00844']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '27921', 'K0VB02086']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '27921', 'K0VB02545']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29233', '60UR06472']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29228', '60V810717']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29234', '60UN82900']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9C', '64GB', 'Nº', 'S', '29295', '60V780303']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9C', '64GB', 'Nº', 'S', '29295', '60V874129']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25419', '60VC02317']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25419', '60UT11401']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'AMAZFIT', 'BIPLITE', 'Nº', 'S', '19151033087459']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'AMAZFIT', 'BIPLITE', 'Nº', 'S', '19151032065381']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'XIAOMI', 'MI', 'BAND', '5', 'Nº', 'S', '28350', '20908825']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'XIAOMI', 'MI', 'BAND', '5', 'Nº', 'S', '28350', '20908938']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'APPLE', 'SERIES', '3', 'Nº', 'S', 'SGJ9D3YXBJ5X0', '38MM']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9S', '128GB', 'Nº', 'S', '27961', '60VC00828']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9S', '128GB', 'Nº', 'S', '27281', '60VD06468']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9S', '128GB', 'Nº', 'S', '27281', '60VD05153']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9S', '128GB', 'Nº', 'S', '27961', '60VC00844']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '27921', 'K0VB02086']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '27921', 'K0VB02545']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29233', '60UR06472']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29228', '60V810717']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29234', '60UN82900']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9C', '64GB', 'Nº', 'S', '29295', '60V780303']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9C', '64GB', 'Nº', 'S', '29295', '60V874129']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25419', '60VC02317']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25419', '60UT11401']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'AMAZFIT', 'BIPLITE', 'Nº', 'S', '19151033087459']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'AMAZFIT', 'BIPLITE', 'Nº', 'S', '19151032065381']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'XIAOMI', 'MI', 'BAND', '5', 'Nº', 'S', '28350', '20908825']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'XIAOMI', 'MI', 'BAND', '5', 'Nº', 'S', '28350', '20908938']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29233', '60U801791']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29233', '60U806982']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29233', '60U904746']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29233', '60U806954']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29227', '60TY19668']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '27921', 'K0UF07046']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '27921', 'K0UF06354']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '27921', 'K0UF02802']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '27921', 'K0UF06495']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '27921', 'K0UF07087']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25420', '60UH01057']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25420', '60UH01059']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '27922', 'K0UJ03092']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25420', '60U308233']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25434', '60T309001']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25420', '60U308337']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25421', '60UR07927']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '24976', '60SW04379']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '24976', '60RN03148']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '8A', '64GB', 'Nº', 'S', '26311', '30T501471']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '8A', '64GB', 'Nº', 'S', '26311', '30T501476']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '8A', '64GB', 'Nº', 'S', '26311', '00TA00624']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '8A', '64GB', 'Nº', 'S', '26313', '30SU04542']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '8A', '64GB', 'Nº', 'S', '26312', '00RF08190']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '8A', '64GB', 'Nº', 'S', '26313', '30SU04769']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '8A', '64GB', 'Nº', 'S', '26311', '30T506910']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '8A', '64GB', 'Nº', 'S', '26312', '00RF08200']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '8A', '64GB', 'Nº', 'S', '26311', '00TA00272']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29229', '60UQ79749']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29227', '60U602049']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9', '32GB', 'Nº', 'S', '28376', '30TA00592']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9', '32GB', 'Nº', 'S', '28378', 'S0T708317']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9', '32GB', 'Nº', 'S', '28378', 'S0UA04037']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9', '32GB', 'Nº', 'S', '28380', '30U800110']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9', '32GB', 'Nº', 'S', '28377', 'S0TJ04566']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9', '32GB', 'Nº', 'S', '28377', 'S0TJ04660']
# ['TELEFONES', 'SMARTPHONE', 'MOTOROLA', 'MOTO', 'C', '16GB', 'Nº', 'S', 'PA6K04903D']
# ['TELEFONES', 'SMARTPHONE', 'MOTOROLA', 'MOTO', 'C', '16GB', 'Nº', 'S', 'PA6K04399D']
# ['VIDEOGAMES', 'VIDEO', 'GAME', 'SONY', 'PLAYSTATION', '4', 'Nº', 'S', 'MC722895038']
# ['ELETRONICOS', 'FONE', 'DE', 'OUVIDO', 'JBL', 'TUNE', '500', 'Nº', 'S', 'TL0796', 'FJ0026331']
# ['ELETRONICOS', 'FONE', 'DE', 'OUVIDO', 'JBL', 'TUNE', '500', 'BT', 'Nº', 'S', 'TL0705', 'JJ0439763']
# ['ELETRONICOS', 'FONE', 'DE', 'OUVIDO', 'JBL', 'TUNE', '500', 'Nº', 'S', 'TL0796', 'FJ0026230']
# ['ELETRONICOS', 'FONE', 'DE', 'OUVIDO', 'JBL', 'TUNE', '500', 'BT', 'Nº', 'S', 'TL0705', 'JJ0432219']
# ['ELETRONICOS', 'FONE', 'DE', 'OUVIDO', 'JBL', 'TUNE', '500', 'BT', 'Nº', 'S', 'TL0705', 'JJ0439777']
# ['ELETRONICOS', 'RADIO', 'TOCA', 'CD', 'P', 'AUTO', 'QUANTA', 'QTRA73', 'Nº', 'S', '0520', 'QTSVA']
# ['ELETRONICOS', 'CAIXA', 'ACUSTICA', 'QUANTA', 'QTMSR10', 'Nº', 'S', '0520', 'QTGZW']
# ['ELETRONICOS', 'CAIXA', 'ACUSTICA', 'QUANTA', 'QTMSR10', 'Nº', 'S', '0520', 'QTGZW']
# ['ELETRONICOS', 'CAIXA', 'ACUSTICA', 'JBL', 'GO2', 'Nº', 'S', 'AN0351', 'HJ0481148']
# ['ELETRONICOS', 'CAIXA', 'ACUSTICA', 'JBL', 'GO2', 'Nº', 'S', 'AN0351', 'HJ0480809']
# ['INFORMATICA', 'ROTEADOR', 'TP', 'LINK', 'TL', 'WR949N', 'Nº', 'S', '219B493002330']
# ['INFORMATICA', 'ROTEADOR', 'TP', 'LINK', 'AC1350', 'Nº', 'S', '2197297004196']
# ['INFORMATICA', 'ROTEADOR', 'TP', 'LINK', 'ARCHER', 'C50', 'Nº', 'S', '2201482005910']
# ['INFORMATICA', 'ROTEADOR', 'TP', 'LINK', 'ARCHER', 'C50', 'Nº', 'S', '2201482003381']
# ['INFORMATICA', 'ROTEADOR', 'TP', 'LINK', 'ARCHER', 'C50', 'Nº', 'S', '2201482003386']
# ['INFORMATICA', 'ROTEADOR', 'TP', 'LINK', 'ARCHER', 'C50', 'Nº', 'S', '2201482003388']
# ['INFORMATICA', 'ROTEADOR', 'TP', 'LINK', 'ARCHER', 'C50', 'Nº', 'S', '2201482003385']
# ['INFORMATICA', 'ROTEADOR', 'TP', 'LINK', 'ARCHER', 'C50', 'Nº', 'S', '2201482003382']
# ['INFORMATICA', 'ROTEADOR', 'TP', 'LINK', 'TL', 'WR849N', 'Nº', 'S', '2194309018629']
# ['INFORMATICA', 'ROTEADOR', 'TP', 'LINK', 'TL', 'WR849N', 'Nº', 'S', '2194895010767']
# ['INFORMATICA', 'ROTEADOR', 'TP', 'LINK', 'TL', 'WR849N', 'Nº', 'S', '219BB32012483']
# ['INFORMATICA', 'REPETIDOR', 'WIFI', 'TP', 'LINK', 'TL', 'WA850RE', 'Nº', 'S', '22033D4000903']
# ['INFORMATICA', 'REPETIDOR', 'WIFI', 'TP', 'LINK', 'TL', 'WA850RE', 'Nº', 'S', '22033D4000353']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'XIAOMI', 'MI', 'SMART', 'BAND', '4', 'PLUS', 'Nº', 'S', 'MGW4052GL']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'XIAOMI', 'MI', 'SMART', 'BAND', '4', 'PLUS', 'Nº', 'S', 'MGW4052GL']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'XIAOMI', 'MI', 'SMART', 'BAND', '4', 'PLUS', 'Nº', 'S', 'MGW4052GL']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'XIAOMI', 'MI', 'SMART', 'BAND', '4', 'PLUS', 'Nº', 'S', 'MGW4052GL']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'XIAOMI', 'MI', 'SMART', 'BAND', '4', 'PLUS', 'Nº', 'S', 'MGW4052GL']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'XIAOMI', 'MI', 'SMART', 'BAND', 'PLUS', 'Nº', 'S', 'MGW4052GL']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'XIAOMI', 'MI', 'FITNESS', 'BAND', '4', 'Nº', 'S', 'MGW4046CN']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'XIAOMI', 'MI', 'FITNESS', 'BAND', '4', 'Nº', 'S', 'MGW4046CN']
# ['ELETRONICOS', 'RECEPTOR', 'DE', 'MIDIA', 'GOOGLE', 'CHROMECASTE', 'Nº', 'S', 'GA00439', 'US']
# ['VIDEOGAMES', 'CONTROLE', 'DE', 'VIDEO', 'GAME', 'MICROSOFT', 'XBOX', 'ONE', 'Nº', 'S', '09640708285951']
# ['ELETRONICOS', 'FONE', 'DE', 'OUVIDO', 'XIAOMI', 'REDMI', 'AIR', 'DOTS', 'Nº', 'S', '22632', '11190955']
# ['ELETRONICOS', 'FONE', 'DE', 'OUVIDO', 'XIAOMI', 'REDMI', 'AIR', 'DOTS', 'Nº', 'S', '22632', '09408949']
# ['ELETRONICOS', 'FONE', 'DE', 'OUVIDO', 'XIAOMI', 'REDMI', 'AIR', 'DOTS', 'Nº', 'S', '22632', '09409046']
# ['ELETRONICOS', 'FONE', 'DE', 'OUVIDO', 'XIAOMI', 'REDMI', 'AIR', 'DOTS', 'Nº', 'S', '22632', '09408983']
# ['ELETRONICOS', 'FONE', 'DE', 'OUVIDO', 'XIAOMI', 'REDMI', 'AIR', 'DOTS', 'Nº', 'S', '22632', '09408969']
# ['ELETRONICOS', 'FONE', 'DE', 'OUVIDO', 'XIAOMI', 'REDMI', 'AIR', 'DOTS', 'Nº', 'S', '22632', '09409101']
# ['ELETRONICOS', 'FONE', 'DE', 'OUVIDO', 'XIAOMI', 'REDMI', 'EARBUDS', 'BASIC', 'Nº', 'S', '23579', '00582182']
# ['TELEFONES', 'TELEFONE', 'CELULAR', 'BLU', 'TANK', '4', 'Nº', 'S', '1080021018072871']
# ['TELEFONES', 'TELEFONE', 'CELULAR', 'BLU', 'TANK', '4', 'Nº', 'S', '1020021018007568']
# ['TELEFONES', 'TELEFONE', 'CELULAR', 'BLU', 'TANK', '4', 'Nº', 'S', '1020021018007366']
# ['TELEFONES', 'TELEFONE', 'CELULAR', 'TANK', '4', 'Nº', 'S', '1080021018072883']
# ['TELEFONES', 'TELEFONE', 'CELULAR', 'DTC', 'SELFIE', 'FLIP', 'Nº', 'S', '354376080590918']
# ['TELEFONES', 'TELEFONE', 'CELULAR', 'DTC', 'SELFIE', 'FLIP', 'Nº', 'S', '354376080556638']
# ['TELEFONES', 'TELEFONE', 'CELULAR', 'DTC', 'SELFIE', 'FLIP', 'Nº', 'S', '354376080577097']
# ['TELEFONES', 'TELEFONE', 'CELULAR', 'DTC', 'SELFIE', 'FLIP', 'Nº', 'S', '354376080565571']
# ['TELEFONES', 'TELEFONE', 'CELULAR', 'POSITIVO', 'P25', 'Nº', 'S', 'P25CPY2001035535']
# ['TELEFONES', 'TELEFONE', 'CELULAR', 'POSITIVO', 'P25', 'Nº', 'S', 'P25CPY2001031621']
# ['TELEFONES', 'TELEFONE', 'CELULAR', 'ALCATEL', 'ONE', 'TOUCH', 'Nº', 'S', '1052D', '3AOFUS1']
# ['TELEFONES', 'TELEFONE', 'CELULAR', 'ALCATEL', 'ONE', 'TOUCH', 'Nº', 'S', '1052D', '3AOFUS1']
# ['TELEFONES', 'TELEFONE', 'CELULAR', 'BLU', 'C4', 'Nº', 'S', '2120018018025685']
# ['ELETRONICOS', 'FONE', 'DE', 'OUVIDO', 'JBL', 'TUNE115', 'BT', 'Nº', 'S', 'KT0130', 'HJ0039126']
# ['ELETRONICOS', 'FONE', 'DE', 'OUVIDO', 'JBL', 'TUNE115', 'BT', 'Nº', 'S', 'KT0130', 'HJ0039128']
# ['ELETRONICOS', 'FONE', 'DE', 'OUVIDO', 'JBL', 'TUNE115', 'BT', 'Nº', 'S', 'KT0130', 'HJ0039146']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9', '64GB', 'Nº', 'S', '28377', 'S0TJ07829']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9', '64GB', 'Nº', 'S', '28377', 'S0TJ06046']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29227', '60U403026']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29228', '60VJ16120']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29229', '60VC02481']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29228', '60VJ15652']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9C', '64GB', 'Nº', 'S', '29299', '60VE09439']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9C', '64GB', 'Nº', 'S', '29300', '60VE78807']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9C', '64GB', 'Nº', 'S', '29300', '60VE78799']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9C', '64GB', 'Nº', 'S', '29298', '60VC72628']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9C', '64GB', 'Nº', 'S', '29299', '60VE10352']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9C', '64GB', 'Nº', 'S', '29299', '60VE09330']
# ['INFORMATICA', 'TABLET', 'AMAZON', 'FIRE', '7', '32GB', 'Nº', 'S', 'G0W0XK089316F52K']
# ['ELETRONICOS', 'RECEPTOR', 'DE', 'MIDIA', 'AMAZON', 'ECHO', 'DOT', 'ALEXA', 'Nº', 'S', 'G0911M07935619SD']
# ['ELETRONICOS', 'RECEPTOR', 'DE', 'MIDIA', 'AMAZON', 'ECHO', 'DOT', 'ALEXA', 'Nº', 'S', 'G0911M0994970LUW']
# ['ELETRONICOS', 'RECEPTOR', 'DE', 'MIDIA', 'AMAZON', 'ECHO', 'DOT', 'ALEXA', 'Nº', 'S', 'G0911M0995052Q0A']
# ['ELETRONICOS', 'RECEPTOR', 'DE', 'MIDIA', 'AMAZON', 'ECHO', 'DOT', 'ALEXA', 'Nº', 'S', 'G0911M0894361PV8']
# ['ELETRONICOS', 'RECEPTOR', 'DE', 'MIDIA', 'AMAZON', 'ECHO', 'DOT', 'ALEXA', 'Nº', 'S', 'G0911M09950611AK']
# ['ELETRONICOS', 'RECEPTOR', 'DE', 'MIDIA', 'AMAZON', 'ECHO', 'DOT', 'ALEXA', 'Nº', 'S', 'G0911M07930403J6']
# ['INFORMATICA', 'ROTEADOR', 'TP', 'LINK', 'TL', 'WR840', 'Nº', 'S', '3203126001785']
# ['INFORMATICA', 'ROTEADOR', 'TP', 'LINK', 'TL', 'WR840', 'Nº', 'S', '3202096009530']
# ['INFORMATICA', 'ROTEADOR', 'TP', 'LINK', 'TL', 'WR840', 'Nº', 'S', '3202096009537']
# ['INFORMATICA', 'ROTEADOR', 'TP', 'LINK', 'TL', 'WR840', 'Nº', 'S', '3203126001791']
# ['VIDEOGAMES', 'VIDEO', 'GAME', 'MICROSOFT', 'XBOX', 'ONE', 'X', '1', 'TB', 'Nº', 'S', '016937183517']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9S', '128GB', 'Nº', 'S', '27283', '20VZ00026']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9S', '128GB', 'Nº', 'S', '27283', '20VZ00151']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9S', '128GB', 'Nº', 'S', '27283', '20VZ00219']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9S', '128GB', 'Nº', 'S', '27283', '20VZ00353']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '27921', '20V502579']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '27921', '20UW00695']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', 'PRO', '128GB', 'Nº', 'S', '25973', 'K0UF01304']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', 'PRO', '128GB', 'Nº', 'S', '25536', '00UN00649']
# ['ELETRONICOS', 'BABA', 'ELETRONICA', 'MOTOROLA', 'HALO', 'Nº', 'S', '421719E017253']
# ['ELETRONICOS', 'BABA', 'ELETRONICA', 'MOTOROLA', 'COMFORT50', 'Nº', 'S', '418519C092061']
# ['ELETRONICOS', 'BABA', 'ELETRONICA', 'MOTOROLA', 'COMFORT50', 'Nº', 'S', '418519C090771']
# ['INFORMATICA', 'MOUSE', 'RAZER', 'DEATHADDER', 'ELITE', 'Nº', 'S', '8886419332060']
# ['INFORMATICA', 'MOUSE', 'RAZER', 'DEATHADDER', 'ELITE', 'Nº', 'S', '8886419332060']
# ['INFORMATICA', 'MOUSE', 'RAZER', 'DEATHADDER', 'ELITE', 'Nº', 'S', '8886419332060']
# ['INFORMATICA', 'MOUSE', 'RAZER', 'DEATHADDER', 'ELITE', 'Nº', 'S', '8886419332060']
# ['INFORMATICA', 'MOUSE', 'RAZER', 'DEATHADDER', 'ELITE', 'Nº', 'S', '8886419332060']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'AMAZFIT', 'BIP', 'S', 'Nº', 'S', '18211016053947']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'AMAZFIT', 'BIP', 'S', 'Nº', 'S', '18211016053870']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'AMAZFIT', 'BIP', 'S', 'Nº', 'S', '18211016053901']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'AMAZFIT', 'BIP', 'S', 'Nº', 'S', '18211016053905']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'AMAZFIT', 'BIP', 'S', 'Nº', 'S', '18211016053806']
# ['ELETRONICOS', 'RECEPTOR', 'DE', 'MIDIA', 'GOOGLE', 'CHROMECAST', 'Nº', 'S', '03281HFADYA18Q']
# ['INFORMATICA', 'HD', 'PARA', 'NOTEBOOK', 'CRUCIAL', 'SSD', '240GB', 'Nº', 'S', '2026E403C357']
# ['INFORMATICA', 'MOUSE', 'REDRAGON', 'M711', 'FPS', 'Nº', 'S', 'RDM711', 'FPS19033104428']
# ['INFORMATICA', 'MOUSE', 'REDRAGON', 'M711', 'Nº', 'S', 'RDM71119121507748']
# ['INFORMATICA', 'ADAPTADOR', 'USB', 'REDE', 'S', 'FIO', 'TP', 'LINK', 'UE300', 'Nº', 'S', '22064H0002072']
# ['INFORMATICA', 'ADAPTADOR', 'USB', 'REDE', 'S', 'FIO', 'TP', 'LINK', 'UE300', 'Nº', 'S', '2206410003570']
# ['INFORMATICA', 'ADAPTADOR', 'USB', 'REDE', 'S', 'FIO', 'TP', 'LINK', 'UE300', 'Nº', 'S', '2206410003576']
# ['INFORMATICA', 'ADAPTADOR', 'USB', 'REDE', 'S', 'FIO', 'TP', 'LINK', 'UE300', 'Nº', 'S', '22064H0002048']
# ['INFORMATICA', 'ADAPTADOR', 'USB', 'REDE', 'S', 'FIO', 'TP', 'LINK', 'UE300', 'Nº', 'S', '22064H0002054']
# ['INFORMATICA', 'ADAPTADOR', 'USB', 'REDE', 'S', 'FIO', 'TP', 'LINK', 'UE300', 'Nº', 'S', '22064H0002051']
# ['INFORMATICA', 'MODEM', 'G', 'EPON', '01G', 'Nº', 'S', 'V18122406808']
# ['INFORMATICA', 'MODEM', 'G', 'EPON', '01G', 'Nº', 'S', 'V18122406802']
# ['INFORMATICA', 'MODEM', 'G', 'EPON', '01G', 'Nº', 'S', 'V18122406796']
# ['INFORMATICA', 'MODEM', 'G', 'EPON', '01G', 'Nº', 'S', 'V18122406797']
# ['INFORMATICA', 'MODEM', 'G', 'EPON', '01G', 'Nº', 'S', 'V18122406803']
# ['INFORMATICA', 'MODEM', 'G', 'EPON', '01G', 'Nº', 'S', 'V18122406798']
# ['INFORMATICA', 'MODEM', 'G', 'EPON', '01G', 'Nº', 'S', 'V18122406800']
# ['INFORMATICA', 'MODEM', 'G', 'EPON', '01G', 'Nº', 'S', 'V18122406805']
# ['INFORMATICA', 'MODEM', 'G', 'EPON', '01G', 'Nº', 'S', 'V18122406788']
# ['INFORMATICA', 'MODEM', 'G', 'EPON', '01G', 'Nº', 'S', 'V18122406813']
# ['INFORMATICA', 'MODEM', 'G', 'EPON', '01G', 'Nº', 'S', 'V18122406799']
# ['INFORMATICA', 'MODEM', 'G', 'EPON', '01G', 'Nº', 'S', 'V18122406794']
# ['INFORMATICA', 'MODEM', 'G', 'EPON', '01G', 'Nº', 'S', 'V18122406804']
# ['INFORMATICA', 'MODEM', 'G', 'EPON', '01G', 'Nº', 'S', 'V18122406784']
# ['INFORMATICA', 'MODEM', 'G', 'EPON', '01G', 'Nº', 'S', 'V18122406785']
# ['INFORMATICA', 'MODEM', 'G', 'EPON', '01G', 'Nº', 'S', 'V18122406789']
# ['INFORMATICA', 'MODEM', 'G', 'EPON', '01G', 'Nº', 'S', 'V18122406793']
# ['INFORMATICA', 'MODEM', 'G', 'EPON', '01G', 'Nº', 'S', 'V18122406782']
# ['INFORMATICA', 'MODEM', 'G', 'EPON', '01G', 'Nº', 'S', 'V18122406787']
# ['INFORMATICA', 'MODEM', 'G', 'EPON', '01G', 'Nº', 'S', 'V18122406814']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9S', '128GB', 'Nº', 'S', '27912', '60TS02274']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9S', '64GB', 'Nº', 'S', '27284', '20UR01492']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9S', '64GB', 'Nº', 'S', '27284', '20UR00659']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9', '64GB', 'Nº', 'S', '28379', 'S0TX06480']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9', '64GB', 'Nº', 'S', '28377', 'S0TJ12439']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9', '64GB', 'Nº', 'S', '28379', 'S0TX06500']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9', '64GB', 'Nº', 'S', '28379', 'S0TX06515']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9', '64GB', 'Nº', 'S', '28379', 'S0TX06520']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '64GB', 'Nº', 'S', '27995', '20UC01336']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '64GB', 'Nº', 'S', '27991', 'K0RT00591']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '64GB', 'Nº', 'S', '27990', 'K0RV04049']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '64GB', 'Nº', 'S', '27990', 'K0RV03173']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '64GB', 'Nº', 'S', '27991', 'K0RS03639']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '64GB', 'Nº', 'S', '27990', 'K0RV06723']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29229', '60US77942']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29229', '60US78206']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29229', '60US78026']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29229', '60US78002']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '128GB', 'Nº', 'S', '25992', '60UJ00568']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '128GB', 'Nº', 'S', '25992', '60UE01052']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '128GB', 'Nº', 'S', '25993', '60UQ03405']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '128GB', 'Nº', 'S', '25993', '60UQ04122']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25434', '60TN09472']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25421', '60UD06181']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25419', '60UK00258']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25419', '60UK00309']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25421', '60TV12834']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25419', '60U601487']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25434', '60TN08209']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25421', '60UD00235']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25421', '60TV13922']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25421', '60TV14235']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25420', '60UJ04196']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25419', '60U601540']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25419', '60U601782']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25420', '60UJ00142']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25420', '60UJ01029']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '8A', '32GB', 'Nº', 'S', '26321', '00TP04617']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '8A', '32GB', 'Nº', 'S', '26321', '00TP04752']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9S', '128GB', 'Nº', 'S', '27961', '60WF03988']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9S', '128GB', 'Nº', 'S', '27281', '60VU00522']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9S', '128GB', 'Nº', 'S', '27281', '60VU00084']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9', '32GB', 'Nº', 'S', '28375', '30U303561']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9', '32GB', 'Nº', 'S', '28376', '30TW01513']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9', '32GB', 'Nº', 'S', '28376', '30TW01982']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29233', '60V408242']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29229', '60UV07899']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29228', '60V572439']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29234', '60UE72402']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29228', '60V572480']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25421', '60VN04929']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25421', '60VN02494']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25421', '60VN02549']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25421', '60VN02382']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'AMAZFIT', 'BIPE', 'LITE', 'A1915', 'Nº', 'S', '19151031061265']
# ['ELETRONICOS', 'RECEPTOR', 'DE', 'MIDIA', 'GOOGLE', 'CHROMECAST', 'Nº', 'S', '07231HFADWJ118']
# ['ELETRONICOS', 'RECEPTOR', 'DE', 'MIDIA', 'GOOGLE', 'CHROMECAST', 'Nº', 'S', '07231HFADWJ4N7']
# ['ELETRONICOS', 'RECEPTOR', 'DE', 'MIDIA', 'GOOGLE', 'CHROMECAST', 'Nº', 'S', '07231HFADWJ2K9']
# ['ELETRONICOS', 'RECEPTOR', 'DE', 'MIDIA', 'AMAZON', 'FIRE', 'TV', 'STICK', 'ALEXA', 'Nº', 'S', 'G070L824019210W6']
# ['TELEFONES', 'SMARTPHONE', 'SAMSUNG', 'GALAXY', 'A01', 'CORE', '16GB', 'Nº', 'S', 'R58N85R3MAR']
# ['TELEFONES', 'SMARTPHONE', 'SAMSUNG', 'GALAXY', 'A01', 'CORE', '16GB', 'Nº', 'S', 'R58N85R1M6H']
# ['TELEFONES', 'SMARTPHONE', 'BLU', 'J2', '32GB', 'Nº', 'S', '7070018020011015']
# ['TELEFONES', 'SMARTPHONE', 'BLU', 'J2', '32GB', 'Nº', 'S', '7070018020010890']
# ['TELEFONES', 'SMARTPHONE', 'POSITIVO', 'TWIST', '16GB', 'Nº', 'S', 'S511YCPY003484']
# ['TELEFONES', 'SMARTPHONE', 'POSITIVO', 'TWIST', '16GB', 'Nº', 'S', 'S511YCPY005396']
# ['TELEFONES', 'SMARTPHONE', 'POSITIVO', 'TWIST', '16GB', 'Nº', 'S', 'S511YCPY005124']
# ['PNEUS', 'PNEU', 'DE', 'AUTOMOVEL', 'XBRI', '175', '75', 'R14', 'MONTADOS', 'NO', 'VEÍCULO', '']
# ['TELEFONES', 'SMARTPHONE', 'APPLE', 'IPHONE', '12', '64GB', 'Nº', 'S', 'F17DP5NT0F0Q']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'APPLE', 'SERIES', '6', '44MM', 'Nº', 'S', 'SH4HDN69RQ1RP']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'APPLE', 'SERIES', '6', '44MM', 'Nº', 'S', 'SH4HDM32BQ1RP']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'APPLE', 'SERIES', '6', '44MM', 'Nº', 'S', 'SGY6DQLBUQ1RF']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'APPLE', 'SERIES', '6', '44MM', 'Nº', 'S', 'SGY6DQLBAQ1RF']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'APPLE', 'SERIES', '6', '44MM', 'Nº', 'S', 'SH4JDM8ZHQ1RP']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'APPLE', 'SERIES', '6', '44MM', 'Nº', 'S', 'SH4HDMD5JQ1RF']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'APPLE', 'SERIES', '6', '44MM', 'Nº', 'S', 'SH4JDM07EQ1RP']
# ['PNEUS', 'PNEU', 'DE', 'AUTOMOVEL', 'XBRI', '175', '75', 'R14', 'MONTADOS', 'NO', 'VEÍCULO', '']
# ['PNEUS', 'PNEU', 'DE', 'AUTOMOVEL', 'XBRI', '175', '75', 'R14', 'MONTADOS', 'NO', 'VEÍCULO', '']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '29934', 'K0YS00695']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '29934', 'K0YS00762']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9C', '64GB', 'Nº', 'S', '29305', '60WC01167']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9C', '64GB', 'Nº', 'S', '29295', '60XJ03691']
# ['ELETRONICOS', 'RECEPTOR', 'DE', 'MIDIA', 'GOOGLE', 'CHROMECAST', 'Nº', 'S', '08221HFADU27AL']
# ['ELETRONICOS', 'RECEPTOR', 'DE', 'MIDIA', 'GOOGLE', 'CHROMECAST', 'Nº', 'S', '09211HFADXD0DV']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'XIAOMI', 'MI', 'SMART', 'BAND', '5', 'Nº', 'S', '28350', '10920245']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'XIAOMI', 'MI', 'SMART', 'BAND', '5', 'Nº', 'S', '28350', '10920254']
# ['INFORMATICA', 'HD', 'EXTERNO', 'SEAGATE', '2TB', 'Nº', 'S', 'NAASA321']
# ['INFORMATICA', 'HD', 'EXTERNO', 'SEAGATE', '2TB', 'Nº', 'S', 'NAASA2AS']
# ['ELETRONICOS', 'FONE', 'DE', 'OUVIDO', 'XIAOMI', 'MI', 'EARBUDS', 'BASIC', '2', 'Nº', 'S', '28592', '05646622']
# ['ELETRONICOS', 'FONE', 'DE', 'OUVIDO', 'XIAOMI', 'MI', 'EARBUDS', 'BASIC', '2', 'Nº', 'S', '28592', '05423317']
# ['INFORMATICA', 'ROTEADOR', 'TP', 'LINK', 'ARCHER', 'C60', 'Nº', 'S', '2197297003107']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'MI', 'NOTE', '10', 'LITE', '128GB', 'Nº', 'S', '2764320SC00146']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'MI', 'NOTE', '10', 'LITE', '128GB', 'Nº', 'S', '2751920SC00542']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'MI', 'NOTE', '10', 'LITE', '128GB', 'Nº', 'S', '2751220RV00270']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'MI', 'NOTE', '10', 'LITE', '128GB', 'Nº', 'S', '2751920SC00446']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'MI', 'NOTE', '10', 'LITE', '128GB', 'Nº', 'S', '2751920SC01033']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'MI', 'NOTE', '10', 'LITE', '128GB', 'Nº', 'S', '2751920SC01045']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'MI', 'NOTE', '10', 'LITE', '128GB', 'Nº', 'S', '2751220RW00247']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'MI', 'NOTE', '10', 'LITE', '128GB', 'Nº', 'S', '2751920SC00133']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'MI', 'NOTE', '10', 'LITE', '128GB', 'Nº', 'S', '2751920SC00639']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'MI', 'NOTE', '10', 'LITE', '128GB', 'Nº', 'S', '2764320SC00133']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'MI', 'NOTE', '10', 'LITE', '128GB', 'Nº', 'S', '2613020T501885']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'MI', 'NOTE', '9', 'LITE', '128GB', 'Nº', 'S', '2521829X805642']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'MI', 'NOTE', '9', 'LITE', '128GB', 'Nº', 'S', '2521829X806000']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9S', '128GB', 'Nº', 'S', '2791060UN01568']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', 'PRO', '128GB', 'Nº', 'S', '2795320VE02527']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', 'PRO', '128GB', 'Nº', 'S', '2795320VE02498']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', 'PRO', '128GB', 'Nº', 'S', '2795320VE02427']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', 'PRO', '64GB', 'Nº', 'S', '2795220UD00265']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', 'PRO', '64GB', 'Nº', 'S', '2795220UD00015']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '28544K0V206876']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '28545K0UX02096']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '28544K0V206899']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '28545K0UX01946']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '28544K0V206734']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '28545K0UX02049']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '29929K0VE02050']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '28544K0V206893']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '28545K0UX01840']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '28545K0UX01957']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '28545K0UX02093']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '29929K0VE02921']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '29929K0VE03263']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '28545K0UX02024']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '28545K0UX01961']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '28545K0UX01910']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '28545K0UX02003']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '28545K0UX02050']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '29929K0VE02923']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '28544K0V206551']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '28545K0UX02109']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '28545K0UX01977']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '28545K0UX02040']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '28545K0UX01990']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', 'PRO', '128GB', 'Nº', 'S', '2553600VD04171']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', 'PRO', '128GB', 'Nº', 'S', '2553600VD04083']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', 'PRO', '128GB', 'Nº', 'S', '2553600VD04206']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', 'PRO', '128GB', 'Nº', 'S', '2553100UC00446']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', 'PRO', '128GB', 'Nº', 'S', '2553200R205694']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', 'PRO', '128GB', 'Nº', 'S', '2553600VD04044']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', 'PRO', '128GB', 'Nº', 'S', '25973K0UM00014']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', 'PRO', '128GB', 'Nº', 'S', '2553100UC00447']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', 'PRO', '128GB', 'Nº', 'S', '2553600VD04204']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', 'PRO', '128GB', 'Nº', 'S', '25973K0UM00791']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '128GB', 'Nº', 'S', '2598760V803976']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '128GB', 'Nº', 'S', '2598760V804632']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '128GB', 'Nº', 'S', '2598760V804666']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2543260UF00061']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2543360VB00250']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2541960UQ05358']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2542160UV15730']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2541960UR06230']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2541960UQ02866']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2542060UA02720']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2543360VB00114']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2541960UR04488']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2541960UQ04122']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2542160UV10905']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2541960UQ07465']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2542060UA02086']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2543260UF02488']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2542060UA01044']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2541960UQ06450']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2543360VB00226']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2541960UQ04102']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2542160UV14573']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2543360VB00101']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2543360VB00153']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2542060UA02672']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2542160UV15579']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2541960UQ05271']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2541960UQ00470']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2543260UF03443']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '7A', '32GB', 'Nº', 'S', '2425930SD01556']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '7A', '32GB', 'Nº', 'S', '2367330SC04522']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '7A', '32GB', 'Nº', 'S', '2425930SD01437']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '7A', '32GB', 'Nº', 'S', '2367330SC04199']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '7A', '32GB', 'Nº', 'S', '2367330SC05164']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '7A', '32GB', 'Nº', 'S', '2367330SC05038']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '7A', '32GB', 'Nº', 'S', '2367330SD00060']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '7A', '32GB', 'Nº', 'S', '2367330SC05369']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '7A', '32GB', 'Nº', 'S', '2425930SD01532']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '7A', '32GB', 'Nº', 'S', '2367330SC04921']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '7A', '32GB', 'Nº', 'S', '2367330SC04365']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '7A', '32GB', 'Nº', 'S', '2425930SD01555']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '7A', '32GB', 'Nº', 'S', '2367330SD00262']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '7A', '32GB', 'Nº', 'S', '2367330SC03642']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '7A', '32GB', 'Nº', 'S', '2367330SD00298']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '7A', '32GB', 'Nº', 'S', '2367330SC05413']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '7A', '32GB', 'Nº', 'S', '2367330SC04496']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '7A', '32GB', 'Nº', 'S', '2425930SD01444']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '7A', '32GB', 'Nº', 'S', '2367330SC04573']
# ['INFORMATICA', 'PLACA', 'MAE', 'GIGABYTE', 'H310M', 'S2H', '2', '0', 'Nº', 'S', 'SN19439A013928']
# ['INFORMATICA', 'PLACA', 'MAE', 'GIGABYTE', 'H310M', 'S2H', '2', '0', 'Nº', 'S', 'SN19439A013924']
# ['INFORMATICA', 'PLACA', 'MAE', 'GIGABYTE', 'H310M', 'S2H', '2', '0', 'Nº', 'S', 'SN19439A013927']
# ['INFORMATICA', 'PLACA', 'MAE', 'GIGABYTE', 'H310M', 'S2H', '2', '0', 'Nº', 'S', 'SN19439A013958']
# ['INFORMATICA', 'PLACA', 'MAE', 'GIGABYTE', 'H310M', 'S2H', '2', '0', 'Nº', 'S', 'SN19439A013951']
# ['INFORMATICA', 'PLACA', 'MAE', 'GIGABYTE', 'H310M', 'S2H', '2', '0', 'Nº', 'S', 'SN19439A013922']
# ['INFORMATICA', 'PLACA', 'MAE', 'GIGABYTE', 'H310M', 'S2H', '2', '0', 'Nº', 'S', 'SN19439A013957']
# ['INFORMATICA', 'PLACA', 'MAE', 'GIGABYTE', 'H310M', 'S2H', '2', '0', 'Nº', 'S', 'SN19439A013899']
# ['INFORMATICA', 'PLACA', 'MAE', 'GIGABYTE', 'H310M', 'S2H', '2', '0', 'Nº', 'S', 'SN19439A014017']
# ['INFORMATICA', 'PLACA', 'MAE', 'GIGABYTE', 'H310M', 'S2H', '2', '0', 'Nº', 'S', 'SN19439A013952']
# ['INFORMATICA', 'PLACA', 'MAE', 'GIGABYTE', 'H310M', 'S2H', '2', '0', 'Nº', 'S', 'SN19439A013828']
# ['INFORMATICA', 'PLACA', 'MAE', 'GIGABYTE', 'H310M', 'S2H', '2', '0', 'Nº', 'S', 'SN19439A013956']
# ['INFORMATICA', 'PLACA', 'MAE', 'GIGABYTE', 'H310M', 'S2H', '2', '0', 'Nº', 'S', 'SN19439A013900']
# ['INFORMATICA', 'PLACA', 'MAE', 'GIGABYTE', 'H310M', 'S2H', '2', '0', 'Nº', 'S', 'SN19439A013826']
# ['INFORMATICA', 'PLACA', 'MAE', 'GIGABYTE', 'H310M', 'S2H', '2', '0', 'Nº', 'S', 'SN19439A013930']
# ['INFORMATICA', 'PLACA', 'MAE', 'GIGABYTE', 'H310M', 'S2H', '2', '0', 'Nº', 'S', 'SN19439A013921']
# ['INFORMATICA', 'PLACA', 'MAE', 'GIGABYTE', 'H310M', 'S2H', '2', '0', 'Nº', 'S', 'SN19439A013954']
# ['INFORMATICA', 'PLACA', 'MAE', 'GIGABYTE', 'H310M', 'S2H', '2', '0', 'Nº', 'S', 'SN19439A013953']
# ['INFORMATICA', 'PLACA', 'MAE', 'GIGABYTE', 'H310M', 'S2H', '2', '0', 'Nº', 'S', 'SN19439A013929']
# ['INFORMATICA', 'PLACA', 'MAE', 'GIGABYTE', 'H310M', 'S2H', '2', '0', 'Nº', 'S', 'SN19439A013955']
# ['INFORMATICA', 'PROCESSADOR', 'CPU', 'INTEL', 'CORE', 'I3', '9', '100F', 'Nº', 'S', 'U0EY641802204']
# ['INFORMATICA', 'PROCESSADOR', 'CPU', 'INTEL', 'CORE', 'I3', '9', '100F', 'Nº', 'S', 'U0M62V4101079']
# ['INFORMATICA', 'PROCESSADOR', 'CPU', 'INTEL', 'CORE', 'I3', '9', '100F', 'Nº', 'S', 'U0EY641802192']
# ['INFORMATICA', 'PROCESSADOR', 'CPU', 'INTEL', 'CORE', 'I3', '9', '100F', 'Nº', 'S', 'U0M62V4101424']
# ['INFORMATICA', 'PROCESSADOR', 'CPU', 'INTEL', 'CORE', 'I3', '9', '100F', 'Nº', 'S', 'U0M62V4100794']
# ['INFORMATICA', 'PROCESSADOR', 'CPU', 'INTEL', 'CORE', 'I3', '9', '100F', 'Nº', 'S', 'U0EY641802845']
# ['INFORMATICA', 'PROCESSADOR', 'CPU', 'INTEL', 'CORE', 'I3', '9', '100F', 'Nº', 'S', 'U0EY641802814']
# ['INFORMATICA', 'PROCESSADOR', 'CPU', 'INTEL', 'CORE', 'I3', '9', '100F', 'Nº', 'S', 'U0M62V4103927']
# ['INFORMATICA', 'PROCESSADOR', 'CPU', 'INTEL', 'CORE', 'I3', '9', '100F', 'Nº', 'S', 'U0EY641800116']
# ['INFORMATICA', 'PROCESSADOR', 'CPU', 'INTEL', 'CORE', 'I3', '9', '100F', 'Nº', 'S', 'U0EY641802887']
# ['INFORMATICA', 'PROCESSADOR', 'CPU', 'INTEL', 'CORE', 'I3', '9', '100F', 'Nº', 'S', 'U0EY641802699']
# ['INFORMATICA', 'PROCESSADOR', 'CPU', 'INTEL', 'CORE', 'I3', '9', '100F', 'Nº', 'S', 'U0M62V4100926']
# ['INFORMATICA', 'PROCESSADOR', 'CPU', 'INTEL', 'CORE', 'I3', '9', '100F', 'Nº', 'S', 'U0EY641802524']
# ['INFORMATICA', 'PROCESSADOR', 'CPU', 'INTEL', 'CORE', 'I3', '9', '100F', 'Nº', 'S', 'U0EY641800226']
# ['INFORMATICA', 'PROCESSADOR', 'CPU', 'INTEL', 'CORE', 'I3', '9', '100F', 'Nº', 'S', 'U0EY641802703']
# ...
# ['PERFUMES', 'PERFUME', '25', 'ML', 'CX', 'COM', '12', 'UN', 'DREAM', 'BRAND', 'Nº', '034']
# ['PERFUMES', 'PERFUME', '25', 'ML', 'CX', 'COM', '12', 'UN', 'DREAM', 'BRAND', 'Nº', '012']
# ['PERFUMES', 'PERFUME', '25ML', 'CX', 'COM', '12', 'UN', 'DREAM', 'BRAND', 'Nº', '009']
# ['PERFUMES', 'PERFUME', '25', 'ML', 'CX', 'COM', '12', 'UN', 'DREAM', 'BRAND', 'Nº', '017']
# ['PERFUMES', 'PERFUME', '25', 'ML', 'CX', 'COM', '12', 'UN', 'DREAM', 'BRAND', 'Nº', '136']
# ['PERFUMES', 'PERFUME', '25', 'ML', 'CX', 'COM', '12', 'UN', 'DREAM', 'BRAN', 'Nº', '116']
# ['BEBIDAS', 'UISQUE', 'JACK', 'DANIELS', 'NO', '7', '1', 'LITRO']
# ['BEBIDAS', 'UISQUE', 'JACK', 'DANIELS', 'NO', '7', '1', 'LITRO']
# ['BEBIDAS', 'UISQUE', 'JACK', 'DANIELS', 'NO', '7', '1', 'LITRO']
# ['BEBIDAS', 'UISQUE', 'JACK', 'DANIELS', 'NO', '7', '1', 'LITRO']
# ['ELETRONICOS', 'TELA', 'TOUCH', 'PARA', 'IPAD', 'NO', 'HOME', 'BUTTON', 'DIVERSOS', 'CAIXA', '36']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'NO', '105']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'NO', '005']
# ['CIGARROS', 'CIGARRO', 'HILL', 'REF', 'OFÍCIO', 'Nº', '2825', '2020']
# ['CIGARROS', 'CIGARRO', 'CLASSIC', 'REF', 'OFÍCIO', 'Nº', '2825', '2020']
# ['CIGARROS', 'CIGARRO', 'PALERMO', 'REF', 'OFÍCIO', 'Nº', '10992020', '700610']
# ['BEBIDAS', 'GIM', 'TANQUERAY', 'Nº', 'TEN']
# ['BEBIDAS', 'UISQUE', 'JACK', 'DANIELS', 'Nº', '7']
# ['AGROTOXICOS', 'AGROTOXICO', 'CONFORME', 'LAUDO', 'PERICIAL', 'ANEXADO', 'NO', 'PROCESSO']
# ['AGROTOXICOS', 'AGROTOXICO', 'CONFORME', 'LAUDO', 'PERICIAL', 'ANEXADO', 'NO', 'PROCESSO']
# ['PERFUMES', 'PERFUME', 'CHANEL', 'Nº', '5', '100ML']
# ['TELEFONES', 'TELEFONE', 'CELULAR', 'SANSUNG', 'GALAXY', 'A10S', '32GB', '4GLTE', 'PRODUZIDO', 'NO', 'BRASIL', 'BF04', '077']
# ['TELEFONES', 'TELEFONE', 'CELULAR', 'MULTILASER', 'P9076', 'PRODUZIDO', 'NO', 'BRASIL', 'BF04', '077']
# ['ADESIVO', 'JOES', 'PARA', 'PNEU', 'NO', 'FLATS', 'S', 'O']
# ['PNEUS', 'PNEU', 'DE', 'AUTOMOVEL', 'MONTADO', 'NA', 'RODA', 'GALANT', 'GL', '905', '295', '80R', '22', '5', 'ORIGEM', 'CHINA', 'NO', 'ESTEPE', '']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'COLLECTION', 'NO', '008', '25ML']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'COLLECTION', 'NO', '116', '30ML']
# ['MAQUIAGEM', 'MISSHA', 'M', 'PERFECT', 'COVER', 'B', 'B', 'CREAM', 'NO', '25', 'BASE']
# ['MEDICAMENTOS', 'MEDICAMENTOS', 'DIVERSOS', 'VOLUME', 'LACRE', 'Nº', '9373']
# ['ARMAS', 'REVOLVER', 'ARMA', 'DE', 'FOGO', 'TEJANO', 'DETETIVE', '22LR', 'Nº', 'DA', 'ARMA', '01123A']
# ['VEICULOS', 'CAMINHAO', 'M', 'BENZ', '710', 'PLACAS', 'IIG1892', 'BRANCA', '1998', 'CHASSI', 'Nº', '9BM688156WB176147']
# ['80170379', 'KIT', 'PLÁSTICO', 'PARA', 'FIX', 'DO', 'MOTOR', 'NO', 'SISTEMA', 'DE', 'TOLDOS', 'NIMBUS']
# ['80170383', 'KIT', 'PLÁSTICO', 'PARA', 'FIXAÇÃO', 'DO', 'MOTOR', 'NO', 'SISTEMA', 'DE', 'TOLDOS', 'NIMBUS', 'COM', 'CAIXA']
# ['70020150', 'DISCO', 'EM', 'PLÁSTICO', 'COM', 'C', 'EIXO', 'EM', 'AÇO', 'C', 'REDUTOR', 'P', 'CONDUZIR', 'DE', 'PESO', 'E', 'SERVE', 'A', 'FITA', 'RECOLHEDORA', 'NO', 'SISTEMA', 'PERSIANA']
# ['80170254', 'CAIXA', 'EM', 'ALUMINIO', 'UTILIZADA', 'NO', 'SISTEMA', 'DE', 'TOLDOS', 'NIMBUS']
# ['710003', '001712', '5000', 'ANTENA', 'DIRECIONAL', 'PAINEL', 'OUTDOOR', '694', '960', '694', '960', '1710', '2690', '1710', '2690MHZ', 'Nº', 'DE', 'SÉRIE', 'RELAÇÃO', 'ANEXA']
# ['ACESS', 'DE', 'CELULAR', 'N', 'D', 'NO', 'K868', '25086', '2020', 'SMALL', 'MAGIC', 'BALL', 'LED']
# ['PINCEL', 'Nº', '6']
# ['PNEUS', 'PNEU', 'DE', 'AUTOMOVEL', 'DOUBLESTAR', 'INSTALADO', 'NO', 'VÉIC', 'GOL', 'PLACA', 'BVM', '2813', '195', '60', 'R15']
# ['TELEFONES', 'TELEFONE', 'CISCO', 'IP', 'PHONE', '7975', 'NO', 'ESTADO', '045', '0939', '2725', '5112269481']
# ['COMPUTADORES', 'USADOS', 'NO', 'ESTADO', 'OBSOLETOS', 'BIEMENS', 'RAPIS', 'POINT', '500', '5', 'VOL', '045', '0978', '7293']
# ['BEBIDAS', 'VINHO', 'ESPUMANTE', 'ROSE', 'BRUT', 'GFA', 'C', '750', 'ML', 'NO', 'ESTADO', '075', '4738', '0056', '1316733445']
# ['LEITOR', 'RFID', 'XSPAN', 'RFID', 'READER', 'SYSTEM', 'IPJ', 'REV', 'R660', 'IMPINJ', 'C', 'ACESS', 'MAT', 'DIVS', 'NO', 'ESTADO', '045', '3081', '5002', '5908350766']
# ['INFORMATICA', 'NOTEBOOK', 'HP', 'PAVILION', 'NO', 'ESTADO', '891', '1303', '4114']
# ['TELEFONES', 'TELEFONE', 'CISCO', 'IP', 'PHONE', '7975', 'NO', 'ESTADO', '045', '0939', '2725', '5112269481']
# ['INFORMATICA', 'NOTEBOOK', 'HP', 'C', 'ACESS', 'NO', 'ESTADO', '01', 'VOL', '891', '1305', '3762']
# ['TELEFONES', 'TELEFONE', 'CELULAR', 'IPHONE', '5S', 'NO', 'ESTADO', 'VOL', '05', '891', '1305', '3246']
# ['TELEFONES', 'TELEFONE', 'CELULAR', 'IPHONE', '5', 'E', 'SANSUNG', 'NO', 'ESTADO', '891', '1302', '8831']
# ['PEÇAS', 'DE', 'ARTESANATO', 'AFRICANO', 'ESTATUETAS', 'DE', 'MADEIRA', 'MÁSCARAS', 'DIVS', 'NO', 'ESTADO', '083', '9076', '6233']
# ['INFORMATICA', 'NOTEBOOK', 'NO', 'ESTADO', 'VOL', '03', '957', '8619', '5745', '1019319162']
# ['INFORMATICA', 'NOTEBOOK', 'BAK', 'NO', 'ESTADO', '_VOL', '01', '891', '1302', '2951']
# ['INFORMATICA', 'NOTEBOOK', 'HP', 'PAVILION', 'NO', 'ESTADO', '891', '1303', '4114']
# ['ROUPAS', 'EM', 'GRANDE', 'QUANT', 'PARA', 'ALEGADA', 'DOAÇÃO', 'P', 'CRIANÇAS', 'POBRES', 'DE', 'ORGANIZAÇÕES', 'SOCIAIS', 'NO', 'BRASIL', '891', '2013', '9534']
# ['ROUPA', 'EM', 'GRANDE', 'QUANT', 'PARA', 'ALEGADA', 'DOAÇÃO', 'P', 'CRIANÇAS', 'POBRES', 'DE', 'ORGANIZAÇÕES', 'SOCIAIS', 'NO', 'BRASIL', '891', '2013', '9545']
# ['ROUPAS', 'EM', 'GRANDE', 'QUANT', 'PARA', 'ALEGADA', 'DOAÇÃO', 'P', 'CRIANÇAS', 'POBRES', 'DE', 'ORGANIZAÇÕES', 'SOCIAIS', 'NO', 'BRASIL', '891', '2013', '9604']
# ['ROUPAS', 'EM', 'GRANDE', 'QUANT', 'PARA', 'ALEGADA', 'DOAÇÃO', 'P', 'CRIANÇAS', 'POBRES', 'DE', 'ORGANIZAÇÕES', 'SOCIAIS', 'NO', 'BRASIL', '891', '2013', '9630']
# ['INFORMATICA', 'TABLET', 'E', 'TECLADO', 'PARA', 'TABLET', 'NO', 'ESTADO', '891', '1200', '1426']
# ['QUADRO', 'COM', 'CERTIFICADO', 'DE', 'AUTENTICIDA', 'DE', 'NO', 'ESTADO', '057', '3603', '0562', '208460025']
# ['ROUPAS', 'EM', 'GRANDE', 'QUANT', 'PARA', 'ALEGADA', 'DOAÇÃO', 'P', 'CRIANÇAS', 'POBRES', 'DE', 'ORGANIZAÇÕES', 'SOCIAIS', 'NO', 'BRASIL', '891', '2013', '9534']
# ['ROUPA', 'EM', 'GRANDE', 'QUANT', 'PARA', 'ALEGADA', 'DOAÇÃO', 'P', 'CRIANÇAS', 'POBRES', 'DE', 'ORGANIZAÇÕES', 'SOCIAIS', 'NO', 'BRASIL', '891', '2013', '9545']
# ['ROUPAS', 'EM', 'GRANDE', 'QUANT', 'PARA', 'ALEGADA', 'DOAÇÃO', 'P', 'CRIANÇAS', 'POBRES', 'DE', 'ORGANIZAÇÕES', 'SOCIAIS', 'NO', 'BRASIL', '891', '2013', '9604']
# ['ROUPAS', 'EM', 'GRANDE', 'QUANT', 'PARA', 'ALEGADA', 'DOAÇÃO', 'P', 'CRIANÇAS', 'POBRES', 'DE', 'ORGANIZAÇÕES', 'SOCIAIS', 'NO', 'BRASIL', '891', '2013', '9630']
# ['MATERIAL', 'ODONTOLÓGICO', 'PARA', 'ESTÉTICA', 'DESCRITO', 'E', 'QUANTIFICADO', 'NO', 'TERMO', 'DE', 'INTERDIÇÃO', 'ANVISA', '891', '2016', '1363']
# ['ELETRONICOS', 'DVD', 'PLAYER', 'PORTAT', 'C', 'TELA', 'MDX', 'NO', 'ESTADO', 'VOL', '01', '891', '1302', '8503']
# ['ROUPAS', 'INFANTIS', 'E', 'DE', 'BEBÊ', 'NO', 'ESTADO', 'PESO', 'BRUTO', '891', '2014', '5123']
# ['RELOGIOS', 'RELOGIO', 'DE', 'PULSO', 'MARCAS', 'DIVERSAS', 'VOL', '03', 'NO', 'ESTADO', '891', '1303', '8233']
# ['RELOGIOS', 'RELOGIO', 'DE', 'PULSO', 'NO', 'ESTADO', 'DIESEL', 'E', 'INVICTA', '01', 'VOL', '891', '1303', '9143']
# ['ARTIGO', 'DECORATIVO', 'DE', 'TETO', 'SEPAHAN', 'CEILING', 'NO', 'ESTADO', 'C', 'MANUAL', 'ACESS', '157', '5813', '2480']
# ['VIDEOGAMES', 'VIDEO', 'GAME', 'PLAYSTATION', '2', 'NO', 'ESTADO', '01', 'VOL', '891', '1302', '8842']
# ['CIGARROS', 'CIGARRO', 'CUJA', 'IMPORTAÇÃO', 'É', 'PROIBIDA', 'NO', 'BRASIL', 'PESO', 'BRUTO', '891', '2014', '2194']
# ['INFORMATICA', 'TABLET', 'E', 'TECLADO', 'PARA', 'TABLET', 'NO', 'ESTADO', '891', '1200', '1426']
# ['QUADRO', 'COM', 'CERTIFICADO', 'DE', 'AUTENTICIDA', 'DE', 'NO', 'ESTADO', '057', '3603', '0562', '208460025']
# ['ARTIGO', 'DECORATIVO', 'DE', 'TETO', 'SEPAHAN', 'CEILING', 'NO', 'ESTADO', 'C', 'MANUAL', 'ACESS', '157', '5813', '2480']
# ['INFORMATICA', 'NOTEBOOK', 'NO', 'ESTADO', 'VOL', '03', '957', '8619', '5745', '1019319162']
# ['INFORMATICA', 'NOTEBOOK', 'BAK', 'NO', 'ESTADO', '_VOL', '01', '891', '1302', '2951']
# ['RELOGIOS', 'RELOGIO', 'DE', 'PULSO', 'NO', 'ESTADO', 'DIESEL', 'E', 'INVICTA', '01', 'VOL', '891', '1303', '9143']
# ['TELEFONES', 'TELEFONE', 'CELULAR', 'IPHONE', '5', 'E', 'SANSUNG', 'NO', 'ESTADO', '891', '1302', '8831']
# ['CAMERAS', 'CAMERA', 'FOTOGRAFICA', 'SONY', 'NO', 'ESTADO', 'VOL', '01', '891', '1101', '7392']
# ['MECANISMO', 'DE', 'IMPRESSÃO', 'KODAK', 'SQUARE', 'SPOT', 'THERMAL', 'IMAGE', 'HEAD', 'SN', 'T08445', 'NO', 'ESTADO', '045', '0790', '0454', '12564217']
# ['RELOGIOS', 'RELOGIO', 'DE', 'PULSO', 'NO', 'ESTADO', 'IND', 'CONTRAFAÇÃO', '01', 'VOL', '891', '1202', '7842']
# ['INFORMATICA', 'NOTEBOOK', 'ASUS', 'NO', 'ESTADO', '01', 'VOL', '891', '1104', '1645']
# ['ELETRONICOS', 'FILMADORA', 'PANASONIC', 'NO', 'ESTADO', '01', 'VOL', '891', '1104', '1645']
# ['RELOGIOS', 'RELOGIO', 'DE', 'PULSO', 'NO', 'ESTADO', '01', 'VOL', '891', '1203', '0222']
# ['ACESS', 'DE', 'CELULAR', 'GAMEPAD', 'SUPORTE', 'PARA', 'JOGAR', 'NO', 'CELULAR', 'PAIS', 'CHINA']
# ['ACESS', 'DE', 'CELULAR', 'GAMEPAD', 'SUPORTE', 'PARA', 'JOGAR', 'NO', 'CELULAR', 'PAIS', 'CHINA']
# ['ELETRONICOS', 'COMPONENTES', 'ELETRONICOS', 'PLACAS', 'ELETRONICAS', 'NO', 'ESTADO', 'DIVERSOS', 'HREMEXPR40608536754767125D73NX', 'L', 'USADO']
# ['PECAS', 'DIVERSAS', 'KIT', 'PARA', 'MEDICAO', 'E', 'INSPECAO', 'DE', 'PARAFUSO', 'I', 'BOLT', 'LOADMASTER', '3600', 'NO', 'ESTADO', 'DSIC89220132313', 'L', 'USADO']
# ['ELETRONICOS', 'COMPONENTES', 'ELETRONICOS', 'PLACA', 'COM', 'TECLADO', 'DO', 'OPERADOR', 'NO', 'ESTADO', 'SIEMENS', 'SINUMERIK', '802', 'D', 'HREMEXPR0236534062371118054875', 'L', 'USADO']
# ['ELETRONICOS', 'COMPONENTES', 'ELETRONICOS', 'PLACA', 'ELETRONICA', 'NO', 'ESTADO', 'ROCKWELL', 'AUTOMATION', '179527', 'A02', 'HREMEXPR369775138339419557895', 'L', 'USADO']
# ['ELETRONICOS', 'COMPONENTES', 'ELETRONICOS', 'PLACA', 'ELETRONICA', 'NO', 'ESTADO', '394053', 'A01', 'HREMEXPR369775138339419557895', 'L', 'USADO']
# ['PECAS', 'DIVERSAS', 'KIT', 'PARA', 'MEDICAO', 'E', 'INSPECAO', 'DE', 'PARAFUSO', 'I', 'BOLT', 'LOADMASTER', '3600', 'NO', 'ESTADO', 'DSIC89220132313', 'L', 'USADO']
# ['ELETRONICOS', 'COMPONENTES', 'ELETRONICOS', 'PLACA', 'COM', 'TECLADO', 'DO', 'OPERADOR', 'NO', 'ESTADO', 'SIEMENS', 'SINUMERIK', '802', 'D', 'HREMEXPR0236534062371118054875', 'L', 'USADO']
# ['ELETRONICOS', 'COMPONENTES', 'ELETRONICOS', 'PLACA', 'ELETRONICA', 'NO', 'ESTADO', 'ROCKWELL', 'AUTOMATION', '179527', 'A02', 'HREMEXPR369775138339419557895', 'L', 'USADO']
# ['ELETRONICOS', 'COMPONENTES', 'ELETRONICOS', 'PLACA', 'ELETRONICA', 'NO', 'ESTADO', '394053', 'A01', 'HREMEXPR369775138339419557895', 'L', 'USADO']
# ['INFORMATICA', 'CPU', 'CPU', 'NO', 'ESTADO', 'DELL', 'DCCY', 'HREMEXPR40608543931700663PSVKW', 'L', 'USADO']
# ['INFORMATICA', 'CPU', 'CPU', 'NO', 'ESTADO', 'DELL', 'DCCY', 'HREMEXPR40608543931700663PSVKW', 'L', 'USADO']
# ['PECAS', 'DIVERSAS', 'KIT', 'MEDIDOR', 'DE', 'COR', 'NO', 'ESTADO', 'MINOLTA', 'CR', '300', 'AWB369699472314590545164', 'L', 'USADO']
# ['TELEFONES', 'TELEFONE', 'CELULAR', 'IPHONE', 'NO', 'ESTADO', 'APPLE', 'AWB369699473933160126686', 'L', 'USADO']
# ['VENTILADOR', 'PARANA', 'LACRES', 'Nº', '22346', '22347', '22348', '22349']
# ['MANTA', 'COBRE', 'LEITO', 'TAPETE', 'LACRES', 'Nº', '23350', '23351', '23352', '23353', '23354', '23355']
# ['BRINQUEDOS', 'BRINQUEDO', 'E', 'BAZAR', 'LACRES', 'Nº', '022356', '022357', '022358', '']
# ['BRINQUEDOS', 'BRINQUEDO', 'E', 'BAZAR', 'LACRES', 'Nº', '022356', '022357', '022358', '']
# ['MANTA', 'COBRE', 'LEITO', 'TAPETE', 'LACRES', 'Nº', '23350', '23351', '23352', '23353', '23354', '23355']
# ['VENTILADOR', 'PARANA', 'LACRES', 'Nº', '22346', '22347', '22348', '22349']
# ['BRINQUEDOS', 'BRINQUEDO', 'E', 'BAZAR', 'LACRES', 'Nº', '022356', '022357', '022358', '']
# ['MANTA', 'COBRE', 'LEITO', 'TAPETE', 'LACRES', 'Nº', '23350', '23351', '23352', '23353', '23354', '23355']
# ['VENTILADOR', 'PARANA', 'LACRES', 'Nº', '22346', '22347', '22348', '22349']
# ['PNEUS', 'PNEU', 'DE', 'AUTOMOVEL', 'DUPLADO', 'NO', 'INTERIOR', 'DOS', 'QUATRO', 'RODANDO']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'NO', '021', '25ML']
# ['ARMAS', 'PARTES', 'E', 'PEÇAS', 'ARMA', 'FOGO', 'DLASK', 'ARMS', 'CORP', 'ULTRA', 'LIGHT', 'TRIGGER', 'GATILHO', 'PARA', 'ARMAS', 'DE', 'FOGO', 'FABRICADO', 'NO', 'CANADÁ']
# ['ARMAS', 'PARTES', 'E', 'PEÇAS', 'ARMA', 'FOGO', 'WEAVER', 'MODELO', '849970', 'MIRA', 'TELESCÓPICA', 'N', 'SÉRIE', 'C08668', 'FABRICADA', 'NO', 'JAPÃO']
# ['ARMAS', 'PARTES', 'E', 'PEÇAS', 'ARMA', 'FOGO', 'CANOS', 'DE', 'ARMA', 'DE', 'FOGO', '40', 'S', 'W', 'Nº', '5010', 'PCE', '']
# ['BRINQUEDOS', 'BRINQUEDO', 'ZHI', 'LE', 'XING', 'NO', 'H241', 'BOLA', 'VOADORA']
# ['PNEU', 'HELY', '22', '5', '295', '80', 'INSTALADOS', 'NO', 'CAMINHÃO', 'PLACAS', 'HEQ', '5365', 'SENDO', '1', 'ESTEPE', 'PNEUS', 'NOVOS', '']
# ['PNEU', 'HELY', '22', '5', '295', '80', 'INSTALADOS', 'NO', 'CAMINHÃO', 'PLACAS', 'OCZ', '5833', 'SENDO', '2', 'ESTEPES', 'PNEUS', 'NOVOS', '']
# ['BEBIDAS', 'BEBIDA', 'MOUCHÃO', 'VINHO', 'TINTO', 'TUNEL', 'Nº', '3', '4', 'SAFRA', '2013', '750', 'ML', 'GARRAFA']
# ['EMBALAGEM', 'DE', 'PAPEL', 'ROLEX', 'ESTOJO', 'DE', 'RELÓGIO', 'ROLEX', 'S', 'O', 'RELÓGIO', 'Nº', 'SÉRIE', '39139', '08', 'UNIDADE']
# ['EMBALAGEM', 'DE', 'PAPEL', 'ROLEX', 'ESTOJO', 'DE', 'RELÓGIO', 'ROLEX', 'S', 'O', 'RELÓGIO', 'Nº', 'SÉRIE', '39139', '02', 'UNIDADE']
# ['RELOGIOS', 'RELOGIO', 'DE', 'PULSO', 'INVICTA', 'MODELO', 'NO', '18213', 'NÃO', 'IDENTIFICANDO', 'ORIGEM']
# ['RELOGIOS', 'RELOGIO', 'DE', 'PULSO', 'INVICTA', 'RESERVE', 'BOLT', 'ZEUS', 'MODELO', 'NO', '25209', 'NÃO', 'IDENTIFICANDO', 'ORIGEM']
# ['INFORMATICA', 'IMPRESSORA', 'MAGICARD', 'ENDURONEO', 'DUPLEX', 'FABRICADO', 'NO', 'REINO', 'UNIDO']
# ['RELOGIOS', 'RELOGIO', 'DE', 'PULSO', 'INVICTA', 'MODEL', 'NO', '6981']
# ['RELOGIOS', 'RELOGIO', 'DE', 'PULSO', 'INVICTA', 'MODEL', 'NO', '25852']
# ['RELOGIOS', 'RELOGIO', 'DE', 'PULSO', 'INVICTA', 'MODEL', 'NO', '3330']
# ['VIDEOGAMES', 'VIDEO', 'GAME', 'MICROSOFT', 'X', 'BOX', 'ONE', 'X', '1TB', '1TO', 'SKU', 'CYV', '00001', 'Nº', 'SÉRIE', '059928183217', 'CHINA']
# ['INFORMATICA', 'NOTEBOOK', 'APPLE', 'MACBOOK', 'AIR', '13', 'INCH', 'MODEL', 'Nº', 'A2179', 'SFVFCPVMGMNHP', 'CHINA', 'CP12', '003']
# ['RELOGIOS', 'RELOGIO', 'DE', 'PULSO', 'INDICANDO', 'INVICTA', 'MODEL', 'NO', '23702', 'MADE', 'IN', 'JAPAN', 'BF', '291']
# ['LUNETA', 'BUSHNELL', 'BANNER', '9900000801359', '3', '9X40EG', 'NO', '80135', 'BF', '251']
# ['LUNETA', 'HERO', '6', '24X50AOE', 'NO', '100933', 'BF', '264']
# ['INFORMATICA', 'NOTEBOOK', 'MACBOOK', 'PRO', '13', 'INCH', 'MODEL', 'NO', 'A2159', '8GB', '256GB', 'SERIAL', 'SC02Z265NL410', 'CHINA', 'BF', '061']
# ['ROUPAS', 'DIVERSAS', 'CONFORME', 'TERMO', 'DE', 'CONTAGEM', 'E', 'IDENTIFICAÇÃO', 'NO', 'ANEXO', '2', 'DSIC', '091', '1300', '1936']
# ['', 'PEÇA', 'METÁLICA', 'MARCA', 'GRACE', 'Nº', '9801402']
# ['', 'PEÇA', 'METÁLICA', 'MARCA', 'GRACE', 'Nº', '9801402']
# ['', 'SUPLEMENTO', 'NO', 'FLUSH', 'NIACIN', '800MG', '100', 'CÁPSULAS', 'LIFE', 'EXTENSION']
# ['SUPLEMENTO', 'NO', 'FLUSH', 'NIACIN', '800MG', '100', 'CÁPSULAS', 'LIFE', 'EXTENSION']
# ['CINZEIRO', 'DE', 'VIDRO', 'YG17007', 'COM', 'ESTAMPAS', 'FOLHAS', 'DE', 'CANNABIS', 'SATIVA', 'MACONHA', 'DI', 'Nº', '20', '0392493', '0', 'AD', '07', 'ITEM', '01']
# ['CINZEIRO', 'DE', 'VIDRO', 'YG17006', 'COM', 'ESTAMPAS', 'FOLHAS', 'DE', 'CANNABIS', 'SATIVA', 'MACONHA', 'DI', 'Nº', '20', '0392493', '0', 'AD', '07', 'ITEM', '02']
# ['CINZEIRO', 'DE', 'VIDRO', 'YG17007', 'COM', 'ESTAMPAS', 'FOLHAS', 'DE', 'CANNABIS', 'SATIVA', 'MACONHA', 'DI', 'Nº', '20', '0392493', '0', 'AD', '07', 'ITEM', '01']
# ['CINZEIRO', 'DE', 'VIDRO', 'YG17006', 'COM', 'ESTAMPAS', 'FOLHAS', 'DE', 'CANNABIS', 'SATIVA', 'MACONHA', 'DI', 'Nº', '20', '0392493', '0', 'AD', '07', 'ITEM', '02']
# ['TECIDO', 'CORTE', '2', '100', 'ROLOS', '100', 'POLIESTER', 'TECIDO', 'PLANO', 'TINTO', '75', 'DTEX', 'NO', 'URDUME', '150', 'DTEX', 'TRAMA', '96X54', 'LARGURA', '2', '40M', 'GRAM', '65G', 'M2', 'S', 'FIO', 'BORRACHA']
# ['TECIDO', 'CORTE', '729', 'ROLOS', '100', 'POLIESTER', 'TECIDO', 'PLANO', 'TINTO', '75', 'DTEX', 'NO', 'URDUME', '150', 'DTEX', 'TRAMA', '96X54', 'LARGURA', '2', '40M', 'GRAM', '65G', 'M2', 'S', 'FIO', 'BORRACHA']

# %%
# itens.loc[8].descricao, itens.loc[8].descricao_limpa

# %%
# 20 palavras mais comuns (com maior freq acumulada)
word_count.most_common(20)
# Out:
# [(b'de', 49719),
#  (b'eletronicos', 31582),
#  (b'telefones', 27452),
#  (b'xiaomi', 27094),
#  (b'informatica', 23422),
#  (b'redmi', 19078),
#  (b'celular', 17472),
#  (b'smartphone', 16312),
#  (b'note', 13307),
#  (b'china', 12359),
#  (b'bebidas', 12354),
#  (b'origem', 11366),
#  (b'telefone', 11318),
#  (b'perfume', 11206),
#  (b'perfumes', 11205),
#  (b's', 10987),
#  (b'64gb', 9854),
#  (b'128gb', 9582),
#  (b'vinho', 8989),
#  (b'9', 7733)]

# %% [markdown]
# ## 5.2 - Nuvem de palavras - 50 palavras mais frequentes

# %%
# cria um dicionário temporário 'text' com as 50 palavras mais frequentes
max_values = 50
text = {}
for (k, v) in word_count.most_common(max_values):
    text[str(k.decode())] = v

# %%
# cria a nuvem de palavras
wordcloud = WordCloud(width=1600, height=800).generate_from_frequencies(text)

# %%
# configurações de plotagem
fig, ax = plt.subplots(figsize=(20,10))
ax.imshow(wordcloud, interpolation='bilinear')
ax.set_axis_off()
plt.show()

# %%
# Cria dataframe com as 50 palavras mais frequentes
df_word_count = pd.DataFrame()
df_word_count['descricao_limpa'] = text.keys()
df_word_count.head(10)
# Out:
#   descricao_limpa
# 0              de
# 1     eletronicos
# 2       telefones
# 3          xiaomi
# 4     informatica
# 5           redmi
# 6         celular
# 7      smartphone
# 8            note
# 9           china

# %% [markdown]
# ### Conclusão: Pelo fato de não termos retirado as stopwords, dentre as palavras mais frequentes temos "de", "china", "origem" que são palavras que não agregam nada na classificação pois elas podem estar na descrição de diferentes NCMs

# %% [markdown]
# ## 5.3 - Salva dataframe em formato parquet

# %%
secta.to_parquet('3_secta_desc_limpa.parquet')  # salva em formato parquet

# %% [markdown]
# ## 6 - Cria a coluna 'descricao_limpa_sem_stopwords'
# ## 6.1 - Nessa coluna foram retiradas as stopwords para termos descrições com palavras mais importantes.
# ## Não foram retirados os afixos

# %%
num_words, word_count = cria_coluna_descricao(secta, 'descricao', 'descricao_limpa_sem_stopwords', stopwords)

# %%
# itens.loc[8].descricao, itens.loc[8].descricao_limpa_sem_stopwords

# %%
word_count.most_common(20)
# Out:
# [(b'telefones', 27452),
#  (b'informatica', 23422),
#  (b'celular', 17472),
#  (b'smartphone', 16312),
#  (b'bebidas', 12354),
#  (b'telefone', 11318),
#  (b'perfume', 11206),
#  (b'perfumes', 11205),
#  (b'vinho', 8989),
#  (b'roteador', 6408),
#  (b'receptor', 6361),
#  (b'vestuarios', 5805),
#  (b'cigarros', 5484),
#  (b'fone', 4880),
#  (b'pro', 4576),
#  (b'acess', 4484),
#  (b'satelite', 4374),
#  (b'acustica', 4005),
#  (b'smartwatch', 3954),
#  (b'relog', 3848)]

# %% [markdown]
# ## 6.2 - Nuvem de palavras - 50 palavras mais frequentes

# %%
max_values = 50
text = {}
for (k, v) in word_count.most_common(max_values):
    text[str(k.decode())] = v

# %%
wordcloud = WordCloud(width=1600, height=800).generate_from_frequencies(text)

# %%
fig, ax = plt.subplots(figsize=(20,10))
ax.imshow(wordcloud, interpolation='bilinear')
ax.set_axis_off()
plt.show()

# %%
df_word_count['descricao_limpa_sem_stopwords'] = text.keys()
df_word_count.head(10)
# Out:
#   descricao_limpa descricao_limpa_sem_stopwords
# 0              de                     telefones
# 1     eletronicos                   informatica
# 2       telefones                       celular
# 3          xiaomi                    smartphone
# 4     informatica                       bebidas
# 5           redmi                      telefone
# 6         celular                       perfume
# 7      smartphone                      perfumes
# 8            note                         vinho
# 9           china                      roteador

# %% [markdown]
# ### Conclusão: a retirada de stopwords melhorou as palavras da descrição.
# ### Vale a pena incluir no stopwords "china", "xiaomi", "huawei", "no", "gb"?

# %% [markdown]
# ## 6.3 - Salva dataframe em formato parquet

# %%
secta.to_parquet('3_secta_desc_limpa_sem_stopwords.parquet')  # salva em formato parquet

# %% [markdown]
# ## 7 - Cria a coluna 'descricao_limpa_stemming'
# ## 7.1 - Nessa coluna não foram retiradas as stopwords
# ## Mas foram retirados os afixos, mantendo somente o radical das palavras

# %%
num_words, word_count = cria_coluna_descricao(secta, 'descricao', 'descricao_limpa_stemming', "", True)
# Out:
# ['CIGARROS', 'CHARUTO', 'PARTAGAS', 'MADURO', 'NO', '1', 'CAIXA', 'COM', '25', 'UNIDADES']
# ['CIGARROS', 'CHARUTO', 'PARTAGAS', 'SERIE', 'E', 'NO', '2', 'CAIXA', 'COM', '25', 'UNIDADES']
# ['CIGARROS', 'CHARUTO', 'HOYO', 'DE', 'MONTERREY', 'EPICURE', 'NO', '2', 'CAIXA', 'COM', '25', 'UNIDADES']
# ['INFORMATICA', 'PLACA', 'MAE', 'ASUS', 'PRIME', 'A320M', 'K', 'INSTALADA', 'NO', 'GABINETE']
# ['INFORMATICA', 'COOLER', 'VENTILADOR', 'CPU', 'AMD', 'INSTALADO', 'NO', 'GAINETE']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'NO', '168', '25ML']
# ['PERFUMES', 'PERFUME', 'BRAND', 'COLLECTION', 'NO', '152', '25ML']
# ['PERFUMES', 'PERFUME', 'BRAND', 'COLLECTION', 'NO', '235', '25ML']
# ['PERFUMES', 'PERFUME', 'BRAND', 'COLLECTION', 'NO', '250', '25ML']
# ['CREME', 'PROD', 'BELEZA', 'DREAM', 'BRAND', 'NO', '194', '200ML']
# ['PERFUMES', 'PERFUME', 'BRAND', 'COLECTION', 'NO', '010', '25ML']
# ['BEBIDAS', 'UISQUE', 'JACK', 'DANIELS', 'OLD', 'Nº', '7', '1', 'LITRO']
# ['PERFUMES', 'PERFUME', 'BRAND', 'COLLECTION', 'NO', '003', '25ML']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'COLLECTION', 'NO', '070', '25ML']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'COLLECTION', 'NO', '116', '25ML']
# ['CREMES', 'HIDRATANTES', 'DREAM', 'BRAND', 'NO', '021', 'NO', '168', 'NO', '097', 'NO', '069', '200ML']
# ['CREMES', 'HIDRATANTES', 'DREAM', 'BRAND', 'NO', '021', 'NO', '168', 'NO', '097', 'NO', '069', '200ML']
# ['CREMES', 'HIDRATANTES', 'DREAM', 'BRAND', 'NO', '021', 'NO', '168', 'NO', '097', 'NO', '069', '200ML']
# ['CREMES', 'HIDRATANTES', 'DREAM', 'BRAND', 'NO', '021', 'NO', '168', 'NO', '097', 'NO', '069', '200ML']
# ['PERFUMES', 'PERFUME', 'BRAND', 'COLLECTION', 'NO', '100', '25ML']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'NO', '012', '25ML']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'NO', '136', '25ML']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'NO', '087', '25ML']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'NO', '070', '25ML']
# ['LINHA', 'DE', 'PESCA', 'MARURI', 'NO', '50', '100M']
# ['PERFUMES', 'PERFUME', 'CHANEL', 'nº', '5', '100ml']
# ['PERFUMES', 'PERFUME', 'CHANEL', 'nº', '5', '100ml']
# ['PERFUMES', 'PERFUME', 'CHANEL', 'nº', '5', '100ml']
# ['BEBIDAS', 'UISQUE', 'JACK', 'DANIELS', 'OLD', 'NO', '7']
# ['BEBIDAS', 'UISQUE', 'JACK', 'DANIELS', 'OLD', 'NO', '7', 'BRAND']
# ['BROCA', 'PARA', 'FURADEIRA', 'IRVEN', 'Nº', '28']
# ['BROCA', 'PARA', 'FURADEIRA', 'IRVEN', 'Nº', '28']
# ['PERFUMES', 'PERFUME', 'CHANEL', 'Nº', '5', '100', 'ML']
# ['PERFUMES', 'PERFUME', 'CHANEL', 'Nº', '5']
# ['PERFUMES', 'PERFUME', 'CHANEL', 'Nº', '5']
# ['CIGARROS', 'CIGARRO', 'CLASSIC', 'FABRICADO', 'NO', 'PARAGUAI']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'NO', '161', '25ML']
# ['ARMAS', 'APARELHO', 'DE', 'CHOQUE', 'ART', 'NO', '801', '']
# ['PARTES', 'E', 'PEÇAS', 'CX', 'ELETRON', 'SUPORTE', 'PLASTICO', 'PARA', 'FLUXO', 'DE', 'NOTAS', 'NO', 'CAIXA', 'ELETRONICO']
# ['MEDICAMENTOS', 'SUPLEMENTO', 'VITAMINICO', 'NO', 'FLUSCH', 'NIACIN', '800MG', '100', 'CAP']
# ['PARTES', 'E', 'PEÇAS', 'DE', 'MOTOR', 'HOLLEY', 'EFI', 'COTOVELO', 'DE', 'ADMISSÃO', 'DO', 'CORPO', 'DO', 'ACELERADOR', 'EFI', '4150', 'SE', 'ENCAIXA', 'NOS', 'CORPOS', 'DO', 'ACELERADOR', 'GM', 'LS']
# ['PARTES', 'E', 'PEÇAS', 'OUTRAS', 'MAQUINAS', 'SUPORTE', 'DO', 'CONTROLADOR', 'DIGITAL', 'PARA', 'AQUECIMENTO', 'DE', 'PNEUS', 'NO', 'BOX']
# ['BOLSAS', 'BOLSA', 'DE', 'VIAGEM', 'USADA', 'UTILIZADA', 'NO', 'TRANSPORTE', 'DAS', 'MERCADORIAS', '']
# ['PERFUMES', 'PERFUME', 'BRAND', 'COLLECTION', 'Nº', '191']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'Nº', '5']
# ['PERFUMES', 'PERFUME', 'BRAND', 'COLLETION', 'Nº', '076']
# ['PERFUMES', 'PERFUME', 'BRAND', 'COLLETION', 'Nº', '171']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'Nº', '116']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'Nº', '008']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'Nº', '009']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'Nº', '100']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'Nº', '153']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'Nº', '154']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'Nº', '007']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'Nº', '087']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'Nº', '124']
# ['PNEUS', 'PNEU', 'DE', 'CAMINHAO', 'DOUBLESTAR', 'INSTALADOS', 'NO', 'VEICULO']
# ['PNEUS', 'PNEU', 'DE', 'CAMINHAO', 'DERUBIO', 'INSTALADOS', 'NO', 'VEICULO']
# ['PNEUS', 'PNEU', 'DE', 'CAMINHAO', 'DOUBLESTAR', 'INSTALADOS', 'NO', 'VEICULO']
# ['PNEUS', 'PNEU', 'DE', 'CAMINHAO', 'DERUBIO', 'INSTALADOS', 'NO', 'VEICULO']
# ['PNEUS', 'PNEU', 'DE', 'CAMINHAO', 'SUNSET', 'INSTALADOS', 'NO', 'VEICULO']
# ['PNEUS', 'PNEU', 'DE', 'CAMINHAO', 'PNEUS', 'INST', 'NO', 'VEICULO', '']
# ['INFORMATICA', 'IMPRESSORA', 'HP', 'LASER', '0135W', '110V', 'SERIE', 'NO', 'CNB3M5VBMS']
# ['INFORMATICA', 'IMPRESSORA', 'HP', 'LASER', '0135W', '110V', 'SERIE', 'NO', 'CMB1M5ZXOZ']
# ['INFORMATICA', 'IMPRESSORA', 'HP', 'LASER', 'M107W', '110V', 'SERIE', 'NO', 'CNB1N3W5GT']
# ['PERFUMES', 'PERFUME', 'BRAND', 'COLLECTION', 'Nº', '191']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'Nº', '5']
# ['PERFUMES', 'PERFUME', 'BRAND', 'COLLETION', 'Nº', '076']
# ['PERFUMES', 'PERFUME', 'BRAND', 'COLLETION', 'Nº', '171']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'Nº', '116']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'Nº', '008']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'Nº', '009']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'Nº', '100']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'Nº', '153']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'Nº', '154']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'Nº', '007']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'Nº', '087']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'Nº', '124']
# ['VEICULOS', 'CAVALO', 'MECANICO', 'SCANIA', 'BWO', '7416', '1987', '1987', 'BRANCA', 'CHASSI', '9BSTH4X2ZH3225880', 'RENAVAM', '00367424312', 'PNEUS', 'INST', 'NO', 'VEICULO']
# ['PNEUS', 'PNEU', 'DE', 'CAMINHAO', 'AUTONE', '295', '80R22', '5', 'PNEUS', 'INST', 'NO', 'VEICULO', '']
# ['PNEUS', 'PNEU', 'DE', 'CAMINHAO', 'LONG', 'MARCH', '295', '80R22', '5', 'PNEUS', 'INST', 'NO', 'VEICULO', '']
# ['PNEUS', 'PNEU', 'DE', 'CAMINHAO', 'LONG', 'MARCH', '275', '80R22', '5', 'PNEUS', 'INST', 'NO', 'VEICULO', '']
# ['PNEUS', 'PNEU', 'DE', 'CAMINHAO', 'LONG', 'MARCH', '295', '80R22', '5', 'INST', 'NO', 'ESTEPE', '']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'APPLE', 'SERIES', '3', 'Nº', 'S', 'SGJ9D3YXBJ5X0', '38MM']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9S', '128GB', 'Nº', 'S', '27961', '60VC00828']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9S', '128GB', 'Nº', 'S', '27281', '60VD06468']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9S', '128GB', 'Nº', 'S', '27281', '60VD05153']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9S', '128GB', 'Nº', 'S', '27961', '60VC00844']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '27921', 'K0VB02086']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '27921', 'K0VB02545']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29233', '60UR06472']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29228', '60V810717']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29234', '60UN82900']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9C', '64GB', 'Nº', 'S', '29295', '60V780303']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9C', '64GB', 'Nº', 'S', '29295', '60V874129']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25419', '60VC02317']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25419', '60UT11401']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'AMAZFIT', 'BIPLITE', 'Nº', 'S', '19151033087459']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'AMAZFIT', 'BIPLITE', 'Nº', 'S', '19151032065381']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'XIAOMI', 'MI', 'BAND', '5', 'Nº', 'S', '28350', '20908825']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'XIAOMI', 'MI', 'BAND', '5', 'Nº', 'S', '28350', '20908938']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'APPLE', 'SERIES', '3', 'Nº', 'S', 'SGJ9D3YXBJ5X0', '38MM']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9S', '128GB', 'Nº', 'S', '27961', '60VC00828']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9S', '128GB', 'Nº', 'S', '27281', '60VD06468']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9S', '128GB', 'Nº', 'S', '27281', '60VD05153']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9S', '128GB', 'Nº', 'S', '27961', '60VC00844']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '27921', 'K0VB02086']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '27921', 'K0VB02545']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29233', '60UR06472']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29228', '60V810717']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29234', '60UN82900']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9C', '64GB', 'Nº', 'S', '29295', '60V780303']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9C', '64GB', 'Nº', 'S', '29295', '60V874129']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25419', '60VC02317']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25419', '60UT11401']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'AMAZFIT', 'BIPLITE', 'Nº', 'S', '19151033087459']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'AMAZFIT', 'BIPLITE', 'Nº', 'S', '19151032065381']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'XIAOMI', 'MI', 'BAND', '5', 'Nº', 'S', '28350', '20908825']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'XIAOMI', 'MI', 'BAND', '5', 'Nº', 'S', '28350', '20908938']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29233', '60U801791']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29233', '60U806982']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29233', '60U904746']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29233', '60U806954']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29227', '60TY19668']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '27921', 'K0UF07046']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '27921', 'K0UF06354']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '27921', 'K0UF02802']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '27921', 'K0UF06495']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '27921', 'K0UF07087']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25420', '60UH01057']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25420', '60UH01059']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '27922', 'K0UJ03092']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25420', '60U308233']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25434', '60T309001']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25420', '60U308337']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25421', '60UR07927']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '24976', '60SW04379']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '24976', '60RN03148']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '8A', '64GB', 'Nº', 'S', '26311', '30T501471']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '8A', '64GB', 'Nº', 'S', '26311', '30T501476']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '8A', '64GB', 'Nº', 'S', '26311', '00TA00624']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '8A', '64GB', 'Nº', 'S', '26313', '30SU04542']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '8A', '64GB', 'Nº', 'S', '26312', '00RF08190']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '8A', '64GB', 'Nº', 'S', '26313', '30SU04769']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '8A', '64GB', 'Nº', 'S', '26311', '30T506910']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '8A', '64GB', 'Nº', 'S', '26312', '00RF08200']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '8A', '64GB', 'Nº', 'S', '26311', '00TA00272']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29229', '60UQ79749']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29227', '60U602049']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9', '32GB', 'Nº', 'S', '28376', '30TA00592']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9', '32GB', 'Nº', 'S', '28378', 'S0T708317']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9', '32GB', 'Nº', 'S', '28378', 'S0UA04037']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9', '32GB', 'Nº', 'S', '28380', '30U800110']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9', '32GB', 'Nº', 'S', '28377', 'S0TJ04566']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9', '32GB', 'Nº', 'S', '28377', 'S0TJ04660']
# ['TELEFONES', 'SMARTPHONE', 'MOTOROLA', 'MOTO', 'C', '16GB', 'Nº', 'S', 'PA6K04903D']
# ['TELEFONES', 'SMARTPHONE', 'MOTOROLA', 'MOTO', 'C', '16GB', 'Nº', 'S', 'PA6K04399D']
# ['VIDEOGAMES', 'VIDEO', 'GAME', 'SONY', 'PLAYSTATION', '4', 'Nº', 'S', 'MC722895038']
# ['ELETRONICOS', 'FONE', 'DE', 'OUVIDO', 'JBL', 'TUNE', '500', 'Nº', 'S', 'TL0796', 'FJ0026331']
# ['ELETRONICOS', 'FONE', 'DE', 'OUVIDO', 'JBL', 'TUNE', '500', 'BT', 'Nº', 'S', 'TL0705', 'JJ0439763']
# ['ELETRONICOS', 'FONE', 'DE', 'OUVIDO', 'JBL', 'TUNE', '500', 'Nº', 'S', 'TL0796', 'FJ0026230']
# ['ELETRONICOS', 'FONE', 'DE', 'OUVIDO', 'JBL', 'TUNE', '500', 'BT', 'Nº', 'S', 'TL0705', 'JJ0432219']
# ['ELETRONICOS', 'FONE', 'DE', 'OUVIDO', 'JBL', 'TUNE', '500', 'BT', 'Nº', 'S', 'TL0705', 'JJ0439777']
# ['ELETRONICOS', 'RADIO', 'TOCA', 'CD', 'P', 'AUTO', 'QUANTA', 'QTRA73', 'Nº', 'S', '0520', 'QTSVA']
# ['ELETRONICOS', 'CAIXA', 'ACUSTICA', 'QUANTA', 'QTMSR10', 'Nº', 'S', '0520', 'QTGZW']
# ['ELETRONICOS', 'CAIXA', 'ACUSTICA', 'QUANTA', 'QTMSR10', 'Nº', 'S', '0520', 'QTGZW']
# ['ELETRONICOS', 'CAIXA', 'ACUSTICA', 'JBL', 'GO2', 'Nº', 'S', 'AN0351', 'HJ0481148']
# ['ELETRONICOS', 'CAIXA', 'ACUSTICA', 'JBL', 'GO2', 'Nº', 'S', 'AN0351', 'HJ0480809']
# ['INFORMATICA', 'ROTEADOR', 'TP', 'LINK', 'TL', 'WR949N', 'Nº', 'S', '219B493002330']
# ['INFORMATICA', 'ROTEADOR', 'TP', 'LINK', 'AC1350', 'Nº', 'S', '2197297004196']
# ['INFORMATICA', 'ROTEADOR', 'TP', 'LINK', 'ARCHER', 'C50', 'Nº', 'S', '2201482005910']
# ['INFORMATICA', 'ROTEADOR', 'TP', 'LINK', 'ARCHER', 'C50', 'Nº', 'S', '2201482003381']
# ['INFORMATICA', 'ROTEADOR', 'TP', 'LINK', 'ARCHER', 'C50', 'Nº', 'S', '2201482003386']
# ['INFORMATICA', 'ROTEADOR', 'TP', 'LINK', 'ARCHER', 'C50', 'Nº', 'S', '2201482003388']
# ['INFORMATICA', 'ROTEADOR', 'TP', 'LINK', 'ARCHER', 'C50', 'Nº', 'S', '2201482003385']
# ['INFORMATICA', 'ROTEADOR', 'TP', 'LINK', 'ARCHER', 'C50', 'Nº', 'S', '2201482003382']
# ['INFORMATICA', 'ROTEADOR', 'TP', 'LINK', 'TL', 'WR849N', 'Nº', 'S', '2194309018629']
# ['INFORMATICA', 'ROTEADOR', 'TP', 'LINK', 'TL', 'WR849N', 'Nº', 'S', '2194895010767']
# ['INFORMATICA', 'ROTEADOR', 'TP', 'LINK', 'TL', 'WR849N', 'Nº', 'S', '219BB32012483']
# ['INFORMATICA', 'REPETIDOR', 'WIFI', 'TP', 'LINK', 'TL', 'WA850RE', 'Nº', 'S', '22033D4000903']
# ['INFORMATICA', 'REPETIDOR', 'WIFI', 'TP', 'LINK', 'TL', 'WA850RE', 'Nº', 'S', '22033D4000353']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'XIAOMI', 'MI', 'SMART', 'BAND', '4', 'PLUS', 'Nº', 'S', 'MGW4052GL']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'XIAOMI', 'MI', 'SMART', 'BAND', '4', 'PLUS', 'Nº', 'S', 'MGW4052GL']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'XIAOMI', 'MI', 'SMART', 'BAND', '4', 'PLUS', 'Nº', 'S', 'MGW4052GL']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'XIAOMI', 'MI', 'SMART', 'BAND', '4', 'PLUS', 'Nº', 'S', 'MGW4052GL']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'XIAOMI', 'MI', 'SMART', 'BAND', '4', 'PLUS', 'Nº', 'S', 'MGW4052GL']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'XIAOMI', 'MI', 'SMART', 'BAND', 'PLUS', 'Nº', 'S', 'MGW4052GL']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'XIAOMI', 'MI', 'FITNESS', 'BAND', '4', 'Nº', 'S', 'MGW4046CN']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'XIAOMI', 'MI', 'FITNESS', 'BAND', '4', 'Nº', 'S', 'MGW4046CN']
# ['ELETRONICOS', 'RECEPTOR', 'DE', 'MIDIA', 'GOOGLE', 'CHROMECASTE', 'Nº', 'S', 'GA00439', 'US']
# ['VIDEOGAMES', 'CONTROLE', 'DE', 'VIDEO', 'GAME', 'MICROSOFT', 'XBOX', 'ONE', 'Nº', 'S', '09640708285951']
# ['ELETRONICOS', 'FONE', 'DE', 'OUVIDO', 'XIAOMI', 'REDMI', 'AIR', 'DOTS', 'Nº', 'S', '22632', '11190955']
# ['ELETRONICOS', 'FONE', 'DE', 'OUVIDO', 'XIAOMI', 'REDMI', 'AIR', 'DOTS', 'Nº', 'S', '22632', '09408949']
# ['ELETRONICOS', 'FONE', 'DE', 'OUVIDO', 'XIAOMI', 'REDMI', 'AIR', 'DOTS', 'Nº', 'S', '22632', '09409046']
# ['ELETRONICOS', 'FONE', 'DE', 'OUVIDO', 'XIAOMI', 'REDMI', 'AIR', 'DOTS', 'Nº', 'S', '22632', '09408983']
# ['ELETRONICOS', 'FONE', 'DE', 'OUVIDO', 'XIAOMI', 'REDMI', 'AIR', 'DOTS', 'Nº', 'S', '22632', '09408969']
# ['ELETRONICOS', 'FONE', 'DE', 'OUVIDO', 'XIAOMI', 'REDMI', 'AIR', 'DOTS', 'Nº', 'S', '22632', '09409101']
# ['ELETRONICOS', 'FONE', 'DE', 'OUVIDO', 'XIAOMI', 'REDMI', 'EARBUDS', 'BASIC', 'Nº', 'S', '23579', '00582182']
# ['TELEFONES', 'TELEFONE', 'CELULAR', 'BLU', 'TANK', '4', 'Nº', 'S', '1080021018072871']
# ['TELEFONES', 'TELEFONE', 'CELULAR', 'BLU', 'TANK', '4', 'Nº', 'S', '1020021018007568']
# ['TELEFONES', 'TELEFONE', 'CELULAR', 'BLU', 'TANK', '4', 'Nº', 'S', '1020021018007366']
# ['TELEFONES', 'TELEFONE', 'CELULAR', 'TANK', '4', 'Nº', 'S', '1080021018072883']
# ['TELEFONES', 'TELEFONE', 'CELULAR', 'DTC', 'SELFIE', 'FLIP', 'Nº', 'S', '354376080590918']
# ['TELEFONES', 'TELEFONE', 'CELULAR', 'DTC', 'SELFIE', 'FLIP', 'Nº', 'S', '354376080556638']
# ['TELEFONES', 'TELEFONE', 'CELULAR', 'DTC', 'SELFIE', 'FLIP', 'Nº', 'S', '354376080577097']
# ['TELEFONES', 'TELEFONE', 'CELULAR', 'DTC', 'SELFIE', 'FLIP', 'Nº', 'S', '354376080565571']
# ['TELEFONES', 'TELEFONE', 'CELULAR', 'POSITIVO', 'P25', 'Nº', 'S', 'P25CPY2001035535']
# ['TELEFONES', 'TELEFONE', 'CELULAR', 'POSITIVO', 'P25', 'Nº', 'S', 'P25CPY2001031621']
# ['TELEFONES', 'TELEFONE', 'CELULAR', 'ALCATEL', 'ONE', 'TOUCH', 'Nº', 'S', '1052D', '3AOFUS1']
# ['TELEFONES', 'TELEFONE', 'CELULAR', 'ALCATEL', 'ONE', 'TOUCH', 'Nº', 'S', '1052D', '3AOFUS1']
# ['TELEFONES', 'TELEFONE', 'CELULAR', 'BLU', 'C4', 'Nº', 'S', '2120018018025685']
# ['ELETRONICOS', 'FONE', 'DE', 'OUVIDO', 'JBL', 'TUNE115', 'BT', 'Nº', 'S', 'KT0130', 'HJ0039126']
# ['ELETRONICOS', 'FONE', 'DE', 'OUVIDO', 'JBL', 'TUNE115', 'BT', 'Nº', 'S', 'KT0130', 'HJ0039128']
# ['ELETRONICOS', 'FONE', 'DE', 'OUVIDO', 'JBL', 'TUNE115', 'BT', 'Nº', 'S', 'KT0130', 'HJ0039146']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9', '64GB', 'Nº', 'S', '28377', 'S0TJ07829']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9', '64GB', 'Nº', 'S', '28377', 'S0TJ06046']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29227', '60U403026']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29228', '60VJ16120']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29229', '60VC02481']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29228', '60VJ15652']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9C', '64GB', 'Nº', 'S', '29299', '60VE09439']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9C', '64GB', 'Nº', 'S', '29300', '60VE78807']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9C', '64GB', 'Nº', 'S', '29300', '60VE78799']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9C', '64GB', 'Nº', 'S', '29298', '60VC72628']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9C', '64GB', 'Nº', 'S', '29299', '60VE10352']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9C', '64GB', 'Nº', 'S', '29299', '60VE09330']
# ['INFORMATICA', 'TABLET', 'AMAZON', 'FIRE', '7', '32GB', 'Nº', 'S', 'G0W0XK089316F52K']
# ['ELETRONICOS', 'RECEPTOR', 'DE', 'MIDIA', 'AMAZON', 'ECHO', 'DOT', 'ALEXA', 'Nº', 'S', 'G0911M07935619SD']
# ['ELETRONICOS', 'RECEPTOR', 'DE', 'MIDIA', 'AMAZON', 'ECHO', 'DOT', 'ALEXA', 'Nº', 'S', 'G0911M0994970LUW']
# ['ELETRONICOS', 'RECEPTOR', 'DE', 'MIDIA', 'AMAZON', 'ECHO', 'DOT', 'ALEXA', 'Nº', 'S', 'G0911M0995052Q0A']
# ['ELETRONICOS', 'RECEPTOR', 'DE', 'MIDIA', 'AMAZON', 'ECHO', 'DOT', 'ALEXA', 'Nº', 'S', 'G0911M0894361PV8']
# ['ELETRONICOS', 'RECEPTOR', 'DE', 'MIDIA', 'AMAZON', 'ECHO', 'DOT', 'ALEXA', 'Nº', 'S', 'G0911M09950611AK']
# ['ELETRONICOS', 'RECEPTOR', 'DE', 'MIDIA', 'AMAZON', 'ECHO', 'DOT', 'ALEXA', 'Nº', 'S', 'G0911M07930403J6']
# ['INFORMATICA', 'ROTEADOR', 'TP', 'LINK', 'TL', 'WR840', 'Nº', 'S', '3203126001785']
# ['INFORMATICA', 'ROTEADOR', 'TP', 'LINK', 'TL', 'WR840', 'Nº', 'S', '3202096009530']
# ['INFORMATICA', 'ROTEADOR', 'TP', 'LINK', 'TL', 'WR840', 'Nº', 'S', '3202096009537']
# ['INFORMATICA', 'ROTEADOR', 'TP', 'LINK', 'TL', 'WR840', 'Nº', 'S', '3203126001791']
# ['VIDEOGAMES', 'VIDEO', 'GAME', 'MICROSOFT', 'XBOX', 'ONE', 'X', '1', 'TB', 'Nº', 'S', '016937183517']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9S', '128GB', 'Nº', 'S', '27283', '20VZ00026']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9S', '128GB', 'Nº', 'S', '27283', '20VZ00151']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9S', '128GB', 'Nº', 'S', '27283', '20VZ00219']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9S', '128GB', 'Nº', 'S', '27283', '20VZ00353']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '27921', '20V502579']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '27921', '20UW00695']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', 'PRO', '128GB', 'Nº', 'S', '25973', 'K0UF01304']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', 'PRO', '128GB', 'Nº', 'S', '25536', '00UN00649']
# ['ELETRONICOS', 'BABA', 'ELETRONICA', 'MOTOROLA', 'HALO', 'Nº', 'S', '421719E017253']
# ['ELETRONICOS', 'BABA', 'ELETRONICA', 'MOTOROLA', 'COMFORT50', 'Nº', 'S', '418519C092061']
# ['ELETRONICOS', 'BABA', 'ELETRONICA', 'MOTOROLA', 'COMFORT50', 'Nº', 'S', '418519C090771']
# ['INFORMATICA', 'MOUSE', 'RAZER', 'DEATHADDER', 'ELITE', 'Nº', 'S', '8886419332060']
# ['INFORMATICA', 'MOUSE', 'RAZER', 'DEATHADDER', 'ELITE', 'Nº', 'S', '8886419332060']
# ['INFORMATICA', 'MOUSE', 'RAZER', 'DEATHADDER', 'ELITE', 'Nº', 'S', '8886419332060']
# ['INFORMATICA', 'MOUSE', 'RAZER', 'DEATHADDER', 'ELITE', 'Nº', 'S', '8886419332060']
# ['INFORMATICA', 'MOUSE', 'RAZER', 'DEATHADDER', 'ELITE', 'Nº', 'S', '8886419332060']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'AMAZFIT', 'BIP', 'S', 'Nº', 'S', '18211016053947']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'AMAZFIT', 'BIP', 'S', 'Nº', 'S', '18211016053870']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'AMAZFIT', 'BIP', 'S', 'Nº', 'S', '18211016053901']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'AMAZFIT', 'BIP', 'S', 'Nº', 'S', '18211016053905']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'AMAZFIT', 'BIP', 'S', 'Nº', 'S', '18211016053806']
# ['ELETRONICOS', 'RECEPTOR', 'DE', 'MIDIA', 'GOOGLE', 'CHROMECAST', 'Nº', 'S', '03281HFADYA18Q']
# ['INFORMATICA', 'HD', 'PARA', 'NOTEBOOK', 'CRUCIAL', 'SSD', '240GB', 'Nº', 'S', '2026E403C357']
# ['INFORMATICA', 'MOUSE', 'REDRAGON', 'M711', 'FPS', 'Nº', 'S', 'RDM711', 'FPS19033104428']
# ['INFORMATICA', 'MOUSE', 'REDRAGON', 'M711', 'Nº', 'S', 'RDM71119121507748']
# ['INFORMATICA', 'ADAPTADOR', 'USB', 'REDE', 'S', 'FIO', 'TP', 'LINK', 'UE300', 'Nº', 'S', '22064H0002072']
# ['INFORMATICA', 'ADAPTADOR', 'USB', 'REDE', 'S', 'FIO', 'TP', 'LINK', 'UE300', 'Nº', 'S', '2206410003570']
# ['INFORMATICA', 'ADAPTADOR', 'USB', 'REDE', 'S', 'FIO', 'TP', 'LINK', 'UE300', 'Nº', 'S', '2206410003576']
# ['INFORMATICA', 'ADAPTADOR', 'USB', 'REDE', 'S', 'FIO', 'TP', 'LINK', 'UE300', 'Nº', 'S', '22064H0002048']
# ['INFORMATICA', 'ADAPTADOR', 'USB', 'REDE', 'S', 'FIO', 'TP', 'LINK', 'UE300', 'Nº', 'S', '22064H0002054']
# ['INFORMATICA', 'ADAPTADOR', 'USB', 'REDE', 'S', 'FIO', 'TP', 'LINK', 'UE300', 'Nº', 'S', '22064H0002051']
# ['INFORMATICA', 'MODEM', 'G', 'EPON', '01G', 'Nº', 'S', 'V18122406808']
# ['INFORMATICA', 'MODEM', 'G', 'EPON', '01G', 'Nº', 'S', 'V18122406802']
# ['INFORMATICA', 'MODEM', 'G', 'EPON', '01G', 'Nº', 'S', 'V18122406796']
# ['INFORMATICA', 'MODEM', 'G', 'EPON', '01G', 'Nº', 'S', 'V18122406797']
# ['INFORMATICA', 'MODEM', 'G', 'EPON', '01G', 'Nº', 'S', 'V18122406803']
# ['INFORMATICA', 'MODEM', 'G', 'EPON', '01G', 'Nº', 'S', 'V18122406798']
# ['INFORMATICA', 'MODEM', 'G', 'EPON', '01G', 'Nº', 'S', 'V18122406800']
# ['INFORMATICA', 'MODEM', 'G', 'EPON', '01G', 'Nº', 'S', 'V18122406805']
# ['INFORMATICA', 'MODEM', 'G', 'EPON', '01G', 'Nº', 'S', 'V18122406788']
# ['INFORMATICA', 'MODEM', 'G', 'EPON', '01G', 'Nº', 'S', 'V18122406813']
# ['INFORMATICA', 'MODEM', 'G', 'EPON', '01G', 'Nº', 'S', 'V18122406799']
# ['INFORMATICA', 'MODEM', 'G', 'EPON', '01G', 'Nº', 'S', 'V18122406794']
# ['INFORMATICA', 'MODEM', 'G', 'EPON', '01G', 'Nº', 'S', 'V18122406804']
# ['INFORMATICA', 'MODEM', 'G', 'EPON', '01G', 'Nº', 'S', 'V18122406784']
# ['INFORMATICA', 'MODEM', 'G', 'EPON', '01G', 'Nº', 'S', 'V18122406785']
# ['INFORMATICA', 'MODEM', 'G', 'EPON', '01G', 'Nº', 'S', 'V18122406789']
# ['INFORMATICA', 'MODEM', 'G', 'EPON', '01G', 'Nº', 'S', 'V18122406793']
# ['INFORMATICA', 'MODEM', 'G', 'EPON', '01G', 'Nº', 'S', 'V18122406782']
# ['INFORMATICA', 'MODEM', 'G', 'EPON', '01G', 'Nº', 'S', 'V18122406787']
# ['INFORMATICA', 'MODEM', 'G', 'EPON', '01G', 'Nº', 'S', 'V18122406814']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9S', '128GB', 'Nº', 'S', '27912', '60TS02274']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9S', '64GB', 'Nº', 'S', '27284', '20UR01492']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9S', '64GB', 'Nº', 'S', '27284', '20UR00659']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9', '64GB', 'Nº', 'S', '28379', 'S0TX06480']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9', '64GB', 'Nº', 'S', '28377', 'S0TJ12439']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9', '64GB', 'Nº', 'S', '28379', 'S0TX06500']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9', '64GB', 'Nº', 'S', '28379', 'S0TX06515']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9', '64GB', 'Nº', 'S', '28379', 'S0TX06520']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '64GB', 'Nº', 'S', '27995', '20UC01336']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '64GB', 'Nº', 'S', '27991', 'K0RT00591']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '64GB', 'Nº', 'S', '27990', 'K0RV04049']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '64GB', 'Nº', 'S', '27990', 'K0RV03173']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '64GB', 'Nº', 'S', '27991', 'K0RS03639']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '64GB', 'Nº', 'S', '27990', 'K0RV06723']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29229', '60US77942']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29229', '60US78206']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29229', '60US78026']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29229', '60US78002']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '128GB', 'Nº', 'S', '25992', '60UJ00568']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '128GB', 'Nº', 'S', '25992', '60UE01052']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '128GB', 'Nº', 'S', '25993', '60UQ03405']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '128GB', 'Nº', 'S', '25993', '60UQ04122']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25434', '60TN09472']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25421', '60UD06181']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25419', '60UK00258']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25419', '60UK00309']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25421', '60TV12834']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25419', '60U601487']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25434', '60TN08209']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25421', '60UD00235']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25421', '60TV13922']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25421', '60TV14235']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25420', '60UJ04196']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25419', '60U601540']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25419', '60U601782']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25420', '60UJ00142']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25420', '60UJ01029']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '8A', '32GB', 'Nº', 'S', '26321', '00TP04617']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '8A', '32GB', 'Nº', 'S', '26321', '00TP04752']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9S', '128GB', 'Nº', 'S', '27961', '60WF03988']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9S', '128GB', 'Nº', 'S', '27281', '60VU00522']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9S', '128GB', 'Nº', 'S', '27281', '60VU00084']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9', '32GB', 'Nº', 'S', '28375', '30U303561']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9', '32GB', 'Nº', 'S', '28376', '30TW01513']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9', '32GB', 'Nº', 'S', '28376', '30TW01982']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29233', '60V408242']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29229', '60UV07899']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29228', '60V572439']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29234', '60UE72402']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9A', '32GB', 'Nº', 'S', '29228', '60V572480']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25421', '60VN04929']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25421', '60VN02494']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25421', '60VN02549']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '25421', '60VN02382']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'AMAZFIT', 'BIPE', 'LITE', 'A1915', 'Nº', 'S', '19151031061265']
# ['ELETRONICOS', 'RECEPTOR', 'DE', 'MIDIA', 'GOOGLE', 'CHROMECAST', 'Nº', 'S', '07231HFADWJ118']
# ['ELETRONICOS', 'RECEPTOR', 'DE', 'MIDIA', 'GOOGLE', 'CHROMECAST', 'Nº', 'S', '07231HFADWJ4N7']
# ['ELETRONICOS', 'RECEPTOR', 'DE', 'MIDIA', 'GOOGLE', 'CHROMECAST', 'Nº', 'S', '07231HFADWJ2K9']
# ['ELETRONICOS', 'RECEPTOR', 'DE', 'MIDIA', 'AMAZON', 'FIRE', 'TV', 'STICK', 'ALEXA', 'Nº', 'S', 'G070L824019210W6']
# ['TELEFONES', 'SMARTPHONE', 'SAMSUNG', 'GALAXY', 'A01', 'CORE', '16GB', 'Nº', 'S', 'R58N85R3MAR']
# ['TELEFONES', 'SMARTPHONE', 'SAMSUNG', 'GALAXY', 'A01', 'CORE', '16GB', 'Nº', 'S', 'R58N85R1M6H']
# ['TELEFONES', 'SMARTPHONE', 'BLU', 'J2', '32GB', 'Nº', 'S', '7070018020011015']
# ['TELEFONES', 'SMARTPHONE', 'BLU', 'J2', '32GB', 'Nº', 'S', '7070018020010890']
# ['TELEFONES', 'SMARTPHONE', 'POSITIVO', 'TWIST', '16GB', 'Nº', 'S', 'S511YCPY003484']
# ['TELEFONES', 'SMARTPHONE', 'POSITIVO', 'TWIST', '16GB', 'Nº', 'S', 'S511YCPY005396']
# ['TELEFONES', 'SMARTPHONE', 'POSITIVO', 'TWIST', '16GB', 'Nº', 'S', 'S511YCPY005124']
# ['PNEUS', 'PNEU', 'DE', 'AUTOMOVEL', 'XBRI', '175', '75', 'R14', 'MONTADOS', 'NO', 'VEÍCULO', '']
# ['TELEFONES', 'SMARTPHONE', 'APPLE', 'IPHONE', '12', '64GB', 'Nº', 'S', 'F17DP5NT0F0Q']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'APPLE', 'SERIES', '6', '44MM', 'Nº', 'S', 'SH4HDN69RQ1RP']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'APPLE', 'SERIES', '6', '44MM', 'Nº', 'S', 'SH4HDM32BQ1RP']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'APPLE', 'SERIES', '6', '44MM', 'Nº', 'S', 'SGY6DQLBUQ1RF']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'APPLE', 'SERIES', '6', '44MM', 'Nº', 'S', 'SGY6DQLBAQ1RF']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'APPLE', 'SERIES', '6', '44MM', 'Nº', 'S', 'SH4JDM8ZHQ1RP']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'APPLE', 'SERIES', '6', '44MM', 'Nº', 'S', 'SH4HDMD5JQ1RF']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'APPLE', 'SERIES', '6', '44MM', 'Nº', 'S', 'SH4JDM07EQ1RP']
# ['PNEUS', 'PNEU', 'DE', 'AUTOMOVEL', 'XBRI', '175', '75', 'R14', 'MONTADOS', 'NO', 'VEÍCULO', '']
# ['PNEUS', 'PNEU', 'DE', 'AUTOMOVEL', 'XBRI', '175', '75', 'R14', 'MONTADOS', 'NO', 'VEÍCULO', '']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '29934', 'K0YS00695']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '29934', 'K0YS00762']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9C', '64GB', 'Nº', 'S', '29305', '60WC01167']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', '9C', '64GB', 'Nº', 'S', '29295', '60XJ03691']
# ['ELETRONICOS', 'RECEPTOR', 'DE', 'MIDIA', 'GOOGLE', 'CHROMECAST', 'Nº', 'S', '08221HFADU27AL']
# ['ELETRONICOS', 'RECEPTOR', 'DE', 'MIDIA', 'GOOGLE', 'CHROMECAST', 'Nº', 'S', '09211HFADXD0DV']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'XIAOMI', 'MI', 'SMART', 'BAND', '5', 'Nº', 'S', '28350', '10920245']
# ['ELETRONICOS', 'SMARTWATCH', 'RELOG', 'INTLG', 'XIAOMI', 'MI', 'SMART', 'BAND', '5', 'Nº', 'S', '28350', '10920254']
# ['INFORMATICA', 'HD', 'EXTERNO', 'SEAGATE', '2TB', 'Nº', 'S', 'NAASA321']
# ['INFORMATICA', 'HD', 'EXTERNO', 'SEAGATE', '2TB', 'Nº', 'S', 'NAASA2AS']
# ['ELETRONICOS', 'FONE', 'DE', 'OUVIDO', 'XIAOMI', 'MI', 'EARBUDS', 'BASIC', '2', 'Nº', 'S', '28592', '05646622']
# ['ELETRONICOS', 'FONE', 'DE', 'OUVIDO', 'XIAOMI', 'MI', 'EARBUDS', 'BASIC', '2', 'Nº', 'S', '28592', '05423317']
# ['INFORMATICA', 'ROTEADOR', 'TP', 'LINK', 'ARCHER', 'C60', 'Nº', 'S', '2197297003107']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'MI', 'NOTE', '10', 'LITE', '128GB', 'Nº', 'S', '2764320SC00146']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'MI', 'NOTE', '10', 'LITE', '128GB', 'Nº', 'S', '2751920SC00542']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'MI', 'NOTE', '10', 'LITE', '128GB', 'Nº', 'S', '2751220RV00270']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'MI', 'NOTE', '10', 'LITE', '128GB', 'Nº', 'S', '2751920SC00446']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'MI', 'NOTE', '10', 'LITE', '128GB', 'Nº', 'S', '2751920SC01033']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'MI', 'NOTE', '10', 'LITE', '128GB', 'Nº', 'S', '2751920SC01045']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'MI', 'NOTE', '10', 'LITE', '128GB', 'Nº', 'S', '2751220RW00247']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'MI', 'NOTE', '10', 'LITE', '128GB', 'Nº', 'S', '2751920SC00133']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'MI', 'NOTE', '10', 'LITE', '128GB', 'Nº', 'S', '2751920SC00639']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'MI', 'NOTE', '10', 'LITE', '128GB', 'Nº', 'S', '2764320SC00133']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'MI', 'NOTE', '10', 'LITE', '128GB', 'Nº', 'S', '2613020T501885']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'MI', 'NOTE', '9', 'LITE', '128GB', 'Nº', 'S', '2521829X805642']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'MI', 'NOTE', '9', 'LITE', '128GB', 'Nº', 'S', '2521829X806000']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9S', '128GB', 'Nº', 'S', '2791060UN01568']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', 'PRO', '128GB', 'Nº', 'S', '2795320VE02527']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', 'PRO', '128GB', 'Nº', 'S', '2795320VE02498']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', 'PRO', '128GB', 'Nº', 'S', '2795320VE02427']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', 'PRO', '64GB', 'Nº', 'S', '2795220UD00265']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', 'PRO', '64GB', 'Nº', 'S', '2795220UD00015']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '28544K0V206876']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '28545K0UX02096']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '28544K0V206899']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '28545K0UX01946']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '28544K0V206734']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '28545K0UX02049']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '29929K0VE02050']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '28544K0V206893']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '28545K0UX01840']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '28545K0UX01957']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '28545K0UX02093']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '29929K0VE02921']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '29929K0VE03263']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '28545K0UX02024']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '28545K0UX01961']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '28545K0UX01910']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '28545K0UX02003']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '28545K0UX02050']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '29929K0VE02923']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '28544K0V206551']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '28545K0UX02109']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '28545K0UX01977']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '28545K0UX02040']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '9', '128GB', 'Nº', 'S', '28545K0UX01990']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', 'PRO', '128GB', 'Nº', 'S', '2553600VD04171']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', 'PRO', '128GB', 'Nº', 'S', '2553600VD04083']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', 'PRO', '128GB', 'Nº', 'S', '2553600VD04206']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', 'PRO', '128GB', 'Nº', 'S', '2553100UC00446']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', 'PRO', '128GB', 'Nº', 'S', '2553200R205694']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', 'PRO', '128GB', 'Nº', 'S', '2553600VD04044']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', 'PRO', '128GB', 'Nº', 'S', '25973K0UM00014']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', 'PRO', '128GB', 'Nº', 'S', '2553100UC00447']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', 'PRO', '128GB', 'Nº', 'S', '2553600VD04204']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', 'PRO', '128GB', 'Nº', 'S', '25973K0UM00791']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '128GB', 'Nº', 'S', '2598760V803976']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '128GB', 'Nº', 'S', '2598760V804632']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '128GB', 'Nº', 'S', '2598760V804666']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2543260UF00061']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2543360VB00250']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2541960UQ05358']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2542160UV15730']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2541960UR06230']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2541960UQ02866']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2542060UA02720']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2543360VB00114']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2541960UR04488']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2541960UQ04122']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2542160UV10905']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2541960UQ07465']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2542060UA02086']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2543260UF02488']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2542060UA01044']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2541960UQ06450']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2543360VB00226']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2541960UQ04102']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2542160UV14573']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2543360VB00101']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2543360VB00153']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2542060UA02672']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2542160UV15579']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2541960UQ05271']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2541960UQ00470']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '8', '64GB', 'Nº', 'S', '2543260UF03443']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '7A', '32GB', 'Nº', 'S', '2425930SD01556']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '7A', '32GB', 'Nº', 'S', '2367330SC04522']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '7A', '32GB', 'Nº', 'S', '2425930SD01437']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '7A', '32GB', 'Nº', 'S', '2367330SC04199']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '7A', '32GB', 'Nº', 'S', '2367330SC05164']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '7A', '32GB', 'Nº', 'S', '2367330SC05038']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '7A', '32GB', 'Nº', 'S', '2367330SD00060']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '7A', '32GB', 'Nº', 'S', '2367330SC05369']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '7A', '32GB', 'Nº', 'S', '2425930SD01532']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '7A', '32GB', 'Nº', 'S', '2367330SC04921']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '7A', '32GB', 'Nº', 'S', '2367330SC04365']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '7A', '32GB', 'Nº', 'S', '2425930SD01555']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '7A', '32GB', 'Nº', 'S', '2367330SD00262']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '7A', '32GB', 'Nº', 'S', '2367330SC03642']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '7A', '32GB', 'Nº', 'S', '2367330SD00298']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '7A', '32GB', 'Nº', 'S', '2367330SC05413']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '7A', '32GB', 'Nº', 'S', '2367330SC04496']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '7A', '32GB', 'Nº', 'S', '2425930SD01444']
# ['TELEFONES', 'SMARTPHONE', 'XIAOMI', 'REDMI', 'NOTE', '7A', '32GB', 'Nº', 'S', '2367330SC04573']
# ['INFORMATICA', 'PLACA', 'MAE', 'GIGABYTE', 'H310M', 'S2H', '2', '0', 'Nº', 'S', 'SN19439A013928']
# ['INFORMATICA', 'PLACA', 'MAE', 'GIGABYTE', 'H310M', 'S2H', '2', '0', 'Nº', 'S', 'SN19439A013924']
# ['INFORMATICA', 'PLACA', 'MAE', 'GIGABYTE', 'H310M', 'S2H', '2', '0', 'Nº', 'S', 'SN19439A013927']
# ['INFORMATICA', 'PLACA', 'MAE', 'GIGABYTE', 'H310M', 'S2H', '2', '0', 'Nº', 'S', 'SN19439A013958']
# ['INFORMATICA', 'PLACA', 'MAE', 'GIGABYTE', 'H310M', 'S2H', '2', '0', 'Nº', 'S', 'SN19439A013951']
# ['INFORMATICA', 'PLACA', 'MAE', 'GIGABYTE', 'H310M', 'S2H', '2', '0', 'Nº', 'S', 'SN19439A013922']
# ['INFORMATICA', 'PLACA', 'MAE', 'GIGABYTE', 'H310M', 'S2H', '2', '0', 'Nº', 'S', 'SN19439A013957']
# ['INFORMATICA', 'PLACA', 'MAE', 'GIGABYTE', 'H310M', 'S2H', '2', '0', 'Nº', 'S', 'SN19439A013899']
# ['INFORMATICA', 'PLACA', 'MAE', 'GIGABYTE', 'H310M', 'S2H', '2', '0', 'Nº', 'S', 'SN19439A014017']
# ['INFORMATICA', 'PLACA', 'MAE', 'GIGABYTE', 'H310M', 'S2H', '2', '0', 'Nº', 'S', 'SN19439A013952']
# ['INFORMATICA', 'PLACA', 'MAE', 'GIGABYTE', 'H310M', 'S2H', '2', '0', 'Nº', 'S', 'SN19439A013828']
# ['INFORMATICA', 'PLACA', 'MAE', 'GIGABYTE', 'H310M', 'S2H', '2', '0', 'Nº', 'S', 'SN19439A013956']
# ['INFORMATICA', 'PLACA', 'MAE', 'GIGABYTE', 'H310M', 'S2H', '2', '0', 'Nº', 'S', 'SN19439A013900']
# ['INFORMATICA', 'PLACA', 'MAE', 'GIGABYTE', 'H310M', 'S2H', '2', '0', 'Nº', 'S', 'SN19439A013826']
# ['INFORMATICA', 'PLACA', 'MAE', 'GIGABYTE', 'H310M', 'S2H', '2', '0', 'Nº', 'S', 'SN19439A013930']
# ['INFORMATICA', 'PLACA', 'MAE', 'GIGABYTE', 'H310M', 'S2H', '2', '0', 'Nº', 'S', 'SN19439A013921']
# ['INFORMATICA', 'PLACA', 'MAE', 'GIGABYTE', 'H310M', 'S2H', '2', '0', 'Nº', 'S', 'SN19439A013954']
# ['INFORMATICA', 'PLACA', 'MAE', 'GIGABYTE', 'H310M', 'S2H', '2', '0', 'Nº', 'S', 'SN19439A013953']
# ['INFORMATICA', 'PLACA', 'MAE', 'GIGABYTE', 'H310M', 'S2H', '2', '0', 'Nº', 'S', 'SN19439A013929']
# ['INFORMATICA', 'PLACA', 'MAE', 'GIGABYTE', 'H310M', 'S2H', '2', '0', 'Nº', 'S', 'SN19439A013955']
# ['INFORMATICA', 'PROCESSADOR', 'CPU', 'INTEL', 'CORE', 'I3', '9', '100F', 'Nº', 'S', 'U0EY641802204']
# ['INFORMATICA', 'PROCESSADOR', 'CPU', 'INTEL', 'CORE', 'I3', '9', '100F', 'Nº', 'S', 'U0M62V4101079']
# ['INFORMATICA', 'PROCESSADOR', 'CPU', 'INTEL', 'CORE', 'I3', '9', '100F', 'Nº', 'S', 'U0EY641802192']
# ['INFORMATICA', 'PROCESSADOR', 'CPU', 'INTEL', 'CORE', 'I3', '9', '100F', 'Nº', 'S', 'U0M62V4101424']
# ['INFORMATICA', 'PROCESSADOR', 'CPU', 'INTEL', 'CORE', 'I3', '9', '100F', 'Nº', 'S', 'U0M62V4100794']
# ['INFORMATICA', 'PROCESSADOR', 'CPU', 'INTEL', 'CORE', 'I3', '9', '100F', 'Nº', 'S', 'U0EY641802845']
# ['INFORMATICA', 'PROCESSADOR', 'CPU', 'INTEL', 'CORE', 'I3', '9', '100F', 'Nº', 'S', 'U0EY641802814']
# ['INFORMATICA', 'PROCESSADOR', 'CPU', 'INTEL', 'CORE', 'I3', '9', '100F', 'Nº', 'S', 'U0M62V4103927']
# ['INFORMATICA', 'PROCESSADOR', 'CPU', 'INTEL', 'CORE', 'I3', '9', '100F', 'Nº', 'S', 'U0EY641800116']
# ['INFORMATICA', 'PROCESSADOR', 'CPU', 'INTEL', 'CORE', 'I3', '9', '100F', 'Nº', 'S', 'U0EY641802887']
# ['INFORMATICA', 'PROCESSADOR', 'CPU', 'INTEL', 'CORE', 'I3', '9', '100F', 'Nº', 'S', 'U0EY641802699']
# ['INFORMATICA', 'PROCESSADOR', 'CPU', 'INTEL', 'CORE', 'I3', '9', '100F', 'Nº', 'S', 'U0M62V4100926']
# ['INFORMATICA', 'PROCESSADOR', 'CPU', 'INTEL', 'CORE', 'I3', '9', '100F', 'Nº', 'S', 'U0EY641802524']
# ...
# ['PERFUMES', 'PERFUME', '25', 'ML', 'CX', 'COM', '12', 'UN', 'DREAM', 'BRAND', 'Nº', '136']
# ['PERFUMES', 'PERFUME', '25', 'ML', 'CX', 'COM', '12', 'UN', 'DREAM', 'BRAN', 'Nº', '116']
# ['BEBIDAS', 'UISQUE', 'JACK', 'DANIELS', 'NO', '7', '1', 'LITRO']
# ['BEBIDAS', 'UISQUE', 'JACK', 'DANIELS', 'NO', '7', '1', 'LITRO']
# ['BEBIDAS', 'UISQUE', 'JACK', 'DANIELS', 'NO', '7', '1', 'LITRO']
# ['BEBIDAS', 'UISQUE', 'JACK', 'DANIELS', 'NO', '7', '1', 'LITRO']
# ['ELETRONICOS', 'TELA', 'TOUCH', 'PARA', 'IPAD', 'NO', 'HOME', 'BUTTON', 'DIVERSOS', 'CAIXA', '36']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'NO', '105']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'NO', '005']
# ['CIGARROS', 'CIGARRO', 'HILL', 'REF', 'OFÍCIO', 'Nº', '2825', '2020']
# ['CIGARROS', 'CIGARRO', 'CLASSIC', 'REF', 'OFÍCIO', 'Nº', '2825', '2020']
# ['CIGARROS', 'CIGARRO', 'PALERMO', 'REF', 'OFÍCIO', 'Nº', '10992020', '700610']
# ['BEBIDAS', 'GIM', 'TANQUERAY', 'Nº', 'TEN']
# ['BEBIDAS', 'UISQUE', 'JACK', 'DANIELS', 'Nº', '7']
# ['ELETRONICOS', 'FONE', 'DE', 'OUVIDO', 'BOSE', 'USADO', 'INCOMPLETO', 'FONE', 'DE', 'OUVIDO', 'COM', 'ESTOJO', 'C', 'DESGASTE', 'NOS', 'ABAFADORES', '']
# ['AGROTOXICOS', 'AGROTOXICO', 'CONFORME', 'LAUDO', 'PERICIAL', 'ANEXADO', 'NO', 'PROCESSO']
# ['AGROTOXICOS', 'AGROTOXICO', 'CONFORME', 'LAUDO', 'PERICIAL', 'ANEXADO', 'NO', 'PROCESSO']
# ['PERFUMES', 'PERFUME', 'CHANEL', 'Nº', '5', '100ML']
# ['TELEFONES', 'TELEFONE', 'CELULAR', 'SANSUNG', 'GALAXY', 'A10S', '32GB', '4GLTE', 'PRODUZIDO', 'NO', 'BRASIL', 'BF04', '077']
# ['TELEFONES', 'TELEFONE', 'CELULAR', 'MULTILASER', 'P9076', 'PRODUZIDO', 'NO', 'BRASIL', 'BF04', '077']
# ['ADESIVO', 'JOES', 'PARA', 'PNEU', 'NO', 'FLATS', 'S', 'O']
# ['PNEUS', 'PNEU', 'DE', 'AUTOMOVEL', 'MONTADO', 'NA', 'RODA', 'GALANT', 'GL', '905', '295', '80R', '22', '5', 'ORIGEM', 'CHINA', 'NO', 'ESTEPE', '']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'COLLECTION', 'NO', '008', '25ML']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'COLLECTION', 'NO', '116', '30ML']
# ['MAQUIAGEM', 'MISSHA', 'M', 'PERFECT', 'COVER', 'B', 'B', 'CREAM', 'NO', '25', 'BASE']
# ['MEDICAMENTOS', 'MEDICAMENTOS', 'DIVERSOS', 'VOLUME', 'LACRE', 'Nº', '9373']
# ['ARMAS', 'REVOLVER', 'ARMA', 'DE', 'FOGO', 'TEJANO', 'DETETIVE', '22LR', 'Nº', 'DA', 'ARMA', '01123A']
# ['VEICULOS', 'CAMINHAO', 'M', 'BENZ', '710', 'PLACAS', 'IIG1892', 'BRANCA', '1998', 'CHASSI', 'Nº', '9BM688156WB176147']
# ['80170379', 'KIT', 'PLÁSTICO', 'PARA', 'FIX', 'DO', 'MOTOR', 'NO', 'SISTEMA', 'DE', 'TOLDOS', 'NIMBUS']
# ['80170383', 'KIT', 'PLÁSTICO', 'PARA', 'FIXAÇÃO', 'DO', 'MOTOR', 'NO', 'SISTEMA', 'DE', 'TOLDOS', 'NIMBUS', 'COM', 'CAIXA']
# ['70020150', 'DISCO', 'EM', 'PLÁSTICO', 'COM', 'C', 'EIXO', 'EM', 'AÇO', 'C', 'REDUTOR', 'P', 'CONDUZIR', 'DE', 'PESO', 'E', 'SERVE', 'A', 'FITA', 'RECOLHEDORA', 'NO', 'SISTEMA', 'PERSIANA']
# ['80170254', 'CAIXA', 'EM', 'ALUMINIO', 'UTILIZADA', 'NO', 'SISTEMA', 'DE', 'TOLDOS', 'NIMBUS']
# ['710003', '001712', '5000', 'ANTENA', 'DIRECIONAL', 'PAINEL', 'OUTDOOR', '694', '960', '694', '960', '1710', '2690', '1710', '2690MHZ', 'Nº', 'DE', 'SÉRIE', 'RELAÇÃO', 'ANEXA']
# ['ACESS', 'DE', 'CELULAR', 'N', 'D', 'NO', 'K868', '25086', '2020', 'SMALL', 'MAGIC', 'BALL', 'LED']
# ['PINCEL', 'Nº', '6']
# ['PNEUS', 'PNEU', 'DE', 'AUTOMOVEL', 'DOUBLESTAR', 'INSTALADO', 'NO', 'VÉIC', 'GOL', 'PLACA', 'BVM', '2813', '195', '60', 'R15']
# ['TELEFONES', 'TELEFONE', 'CISCO', 'IP', 'PHONE', '7975', 'NO', 'ESTADO', '045', '0939', '2725', '5112269481']
# ['COMPUTADORES', 'USADOS', 'NO', 'ESTADO', 'OBSOLETOS', 'BIEMENS', 'RAPIS', 'POINT', '500', '5', 'VOL', '045', '0978', '7293']
# ['BEBIDAS', 'VINHO', 'ESPUMANTE', 'ROSE', 'BRUT', 'GFA', 'C', '750', 'ML', 'NO', 'ESTADO', '075', '4738', '0056', '1316733445']
# ['LEITOR', 'RFID', 'XSPAN', 'RFID', 'READER', 'SYSTEM', 'IPJ', 'REV', 'R660', 'IMPINJ', 'C', 'ACESS', 'MAT', 'DIVS', 'NO', 'ESTADO', '045', '3081', '5002', '5908350766']
# ['INFORMATICA', 'NOTEBOOK', 'HP', 'PAVILION', 'NO', 'ESTADO', '891', '1303', '4114']
# ['TELEFONES', 'TELEFONE', 'CISCO', 'IP', 'PHONE', '7975', 'NO', 'ESTADO', '045', '0939', '2725', '5112269481']
# ['INFORMATICA', 'NOTEBOOK', 'HP', 'C', 'ACESS', 'NO', 'ESTADO', '01', 'VOL', '891', '1305', '3762']
# ['TELEFONES', 'TELEFONE', 'CELULAR', 'IPHONE', '5S', 'NO', 'ESTADO', 'VOL', '05', '891', '1305', '3246']
# ['TELEFONES', 'TELEFONE', 'CELULAR', 'IPHONE', '5', 'E', 'SANSUNG', 'NO', 'ESTADO', '891', '1302', '8831']
# ['PEÇAS', 'DE', 'ARTESANATO', 'AFRICANO', 'ESTATUETAS', 'DE', 'MADEIRA', 'MÁSCARAS', 'DIVS', 'NO', 'ESTADO', '083', '9076', '6233']
# ['INFORMATICA', 'NOTEBOOK', 'NO', 'ESTADO', 'VOL', '03', '957', '8619', '5745', '1019319162']
# ['INFORMATICA', 'NOTEBOOK', 'BAK', 'NO', 'ESTADO', '_VOL', '01', '891', '1302', '2951']
# ['INFORMATICA', 'NOTEBOOK', 'HP', 'PAVILION', 'NO', 'ESTADO', '891', '1303', '4114']
# ['ROUPAS', 'EM', 'GRANDE', 'QUANT', 'PARA', 'ALEGADA', 'DOAÇÃO', 'P', 'CRIANÇAS', 'POBRES', 'DE', 'ORGANIZAÇÕES', 'SOCIAIS', 'NO', 'BRASIL', '891', '2013', '9534']
# ['ROUPA', 'EM', 'GRANDE', 'QUANT', 'PARA', 'ALEGADA', 'DOAÇÃO', 'P', 'CRIANÇAS', 'POBRES', 'DE', 'ORGANIZAÇÕES', 'SOCIAIS', 'NO', 'BRASIL', '891', '2013', '9545']
# ['ROUPAS', 'EM', 'GRANDE', 'QUANT', 'PARA', 'ALEGADA', 'DOAÇÃO', 'P', 'CRIANÇAS', 'POBRES', 'DE', 'ORGANIZAÇÕES', 'SOCIAIS', 'NO', 'BRASIL', '891', '2013', '9604']
# ['ROUPAS', 'EM', 'GRANDE', 'QUANT', 'PARA', 'ALEGADA', 'DOAÇÃO', 'P', 'CRIANÇAS', 'POBRES', 'DE', 'ORGANIZAÇÕES', 'SOCIAIS', 'NO', 'BRASIL', '891', '2013', '9630']
# ['INFORMATICA', 'TABLET', 'E', 'TECLADO', 'PARA', 'TABLET', 'NO', 'ESTADO', '891', '1200', '1426']
# ['QUADRO', 'COM', 'CERTIFICADO', 'DE', 'AUTENTICIDA', 'DE', 'NO', 'ESTADO', '057', '3603', '0562', '208460025']
# ['ROUPAS', 'EM', 'GRANDE', 'QUANT', 'PARA', 'ALEGADA', 'DOAÇÃO', 'P', 'CRIANÇAS', 'POBRES', 'DE', 'ORGANIZAÇÕES', 'SOCIAIS', 'NO', 'BRASIL', '891', '2013', '9534']
# ['ROUPA', 'EM', 'GRANDE', 'QUANT', 'PARA', 'ALEGADA', 'DOAÇÃO', 'P', 'CRIANÇAS', 'POBRES', 'DE', 'ORGANIZAÇÕES', 'SOCIAIS', 'NO', 'BRASIL', '891', '2013', '9545']
# ['ROUPAS', 'EM', 'GRANDE', 'QUANT', 'PARA', 'ALEGADA', 'DOAÇÃO', 'P', 'CRIANÇAS', 'POBRES', 'DE', 'ORGANIZAÇÕES', 'SOCIAIS', 'NO', 'BRASIL', '891', '2013', '9604']
# ['ROUPAS', 'EM', 'GRANDE', 'QUANT', 'PARA', 'ALEGADA', 'DOAÇÃO', 'P', 'CRIANÇAS', 'POBRES', 'DE', 'ORGANIZAÇÕES', 'SOCIAIS', 'NO', 'BRASIL', '891', '2013', '9630']
# ['MATERIAL', 'ODONTOLÓGICO', 'PARA', 'ESTÉTICA', 'DESCRITO', 'E', 'QUANTIFICADO', 'NO', 'TERMO', 'DE', 'INTERDIÇÃO', 'ANVISA', '891', '2016', '1363']
# ['ELETRONICOS', 'DVD', 'PLAYER', 'PORTAT', 'C', 'TELA', 'MDX', 'NO', 'ESTADO', 'VOL', '01', '891', '1302', '8503']
# ['ROUPAS', 'INFANTIS', 'E', 'DE', 'BEBÊ', 'NO', 'ESTADO', 'PESO', 'BRUTO', '891', '2014', '5123']
# ['RELOGIOS', 'RELOGIO', 'DE', 'PULSO', 'MARCAS', 'DIVERSAS', 'VOL', '03', 'NO', 'ESTADO', '891', '1303', '8233']
# ['RELOGIOS', 'RELOGIO', 'DE', 'PULSO', 'NO', 'ESTADO', 'DIESEL', 'E', 'INVICTA', '01', 'VOL', '891', '1303', '9143']
# ['ARTIGO', 'DECORATIVO', 'DE', 'TETO', 'SEPAHAN', 'CEILING', 'NO', 'ESTADO', 'C', 'MANUAL', 'ACESS', '157', '5813', '2480']
# ['VIDEOGAMES', 'VIDEO', 'GAME', 'PLAYSTATION', '2', 'NO', 'ESTADO', '01', 'VOL', '891', '1302', '8842']
# ['CIGARROS', 'CIGARRO', 'CUJA', 'IMPORTAÇÃO', 'É', 'PROIBIDA', 'NO', 'BRASIL', 'PESO', 'BRUTO', '891', '2014', '2194']
# ['INFORMATICA', 'TABLET', 'E', 'TECLADO', 'PARA', 'TABLET', 'NO', 'ESTADO', '891', '1200', '1426']
# ['QUADRO', 'COM', 'CERTIFICADO', 'DE', 'AUTENTICIDA', 'DE', 'NO', 'ESTADO', '057', '3603', '0562', '208460025']
# ['ARTIGO', 'DECORATIVO', 'DE', 'TETO', 'SEPAHAN', 'CEILING', 'NO', 'ESTADO', 'C', 'MANUAL', 'ACESS', '157', '5813', '2480']
# ['INFORMATICA', 'NOTEBOOK', 'NO', 'ESTADO', 'VOL', '03', '957', '8619', '5745', '1019319162']
# ['INFORMATICA', 'NOTEBOOK', 'BAK', 'NO', 'ESTADO', '_VOL', '01', '891', '1302', '2951']
# ['RELOGIOS', 'RELOGIO', 'DE', 'PULSO', 'NO', 'ESTADO', 'DIESEL', 'E', 'INVICTA', '01', 'VOL', '891', '1303', '9143']
# ['TELEFONES', 'TELEFONE', 'CELULAR', 'IPHONE', '5', 'E', 'SANSUNG', 'NO', 'ESTADO', '891', '1302', '8831']
# ['CAMERAS', 'CAMERA', 'FOTOGRAFICA', 'SONY', 'NO', 'ESTADO', 'VOL', '01', '891', '1101', '7392']
# ['MECANISMO', 'DE', 'IMPRESSÃO', 'KODAK', 'SQUARE', 'SPOT', 'THERMAL', 'IMAGE', 'HEAD', 'SN', 'T08445', 'NO', 'ESTADO', '045', '0790', '0454', '12564217']
# ['RELOGIOS', 'RELOGIO', 'DE', 'PULSO', 'NO', 'ESTADO', 'IND', 'CONTRAFAÇÃO', '01', 'VOL', '891', '1202', '7842']
# ['INFORMATICA', 'NOTEBOOK', 'ASUS', 'NO', 'ESTADO', '01', 'VOL', '891', '1104', '1645']
# ['ELETRONICOS', 'FILMADORA', 'PANASONIC', 'NO', 'ESTADO', '01', 'VOL', '891', '1104', '1645']
# ['RELOGIOS', 'RELOGIO', 'DE', 'PULSO', 'NO', 'ESTADO', '01', 'VOL', '891', '1203', '0222']
# ['ACESS', 'DE', 'CELULAR', 'GAMEPAD', 'SUPORTE', 'PARA', 'JOGAR', 'NO', 'CELULAR', 'PAIS', 'CHINA']
# ['ACESS', 'DE', 'CELULAR', 'GAMEPAD', 'SUPORTE', 'PARA', 'JOGAR', 'NO', 'CELULAR', 'PAIS', 'CHINA']
# ['ELETRONICOS', 'COMPONENTES', 'ELETRONICOS', 'PLACAS', 'ELETRONICAS', 'NO', 'ESTADO', 'DIVERSOS', 'HREMEXPR40608536754767125D73NX', 'L', 'USADO']
# ['PECAS', 'DIVERSAS', 'KIT', 'PARA', 'MEDICAO', 'E', 'INSPECAO', 'DE', 'PARAFUSO', 'I', 'BOLT', 'LOADMASTER', '3600', 'NO', 'ESTADO', 'DSIC89220132313', 'L', 'USADO']
# ['ELETRONICOS', 'COMPONENTES', 'ELETRONICOS', 'PLACA', 'COM', 'TECLADO', 'DO', 'OPERADOR', 'NO', 'ESTADO', 'SIEMENS', 'SINUMERIK', '802', 'D', 'HREMEXPR0236534062371118054875', 'L', 'USADO']
# ['ELETRONICOS', 'COMPONENTES', 'ELETRONICOS', 'PLACA', 'ELETRONICA', 'NO', 'ESTADO', 'ROCKWELL', 'AUTOMATION', '179527', 'A02', 'HREMEXPR369775138339419557895', 'L', 'USADO']
# ['ELETRONICOS', 'COMPONENTES', 'ELETRONICOS', 'PLACA', 'ELETRONICA', 'NO', 'ESTADO', '394053', 'A01', 'HREMEXPR369775138339419557895', 'L', 'USADO']
# ['PECAS', 'DIVERSAS', 'KIT', 'PARA', 'MEDICAO', 'E', 'INSPECAO', 'DE', 'PARAFUSO', 'I', 'BOLT', 'LOADMASTER', '3600', 'NO', 'ESTADO', 'DSIC89220132313', 'L', 'USADO']
# ['ELETRONICOS', 'COMPONENTES', 'ELETRONICOS', 'PLACA', 'COM', 'TECLADO', 'DO', 'OPERADOR', 'NO', 'ESTADO', 'SIEMENS', 'SINUMERIK', '802', 'D', 'HREMEXPR0236534062371118054875', 'L', 'USADO']
# ['ELETRONICOS', 'COMPONENTES', 'ELETRONICOS', 'PLACA', 'ELETRONICA', 'NO', 'ESTADO', 'ROCKWELL', 'AUTOMATION', '179527', 'A02', 'HREMEXPR369775138339419557895', 'L', 'USADO']
# ['ELETRONICOS', 'COMPONENTES', 'ELETRONICOS', 'PLACA', 'ELETRONICA', 'NO', 'ESTADO', '394053', 'A01', 'HREMEXPR369775138339419557895', 'L', 'USADO']
# ['INFORMATICA', 'CPU', 'CPU', 'NO', 'ESTADO', 'DELL', 'DCCY', 'HREMEXPR40608543931700663PSVKW', 'L', 'USADO']
# ['INFORMATICA', 'CPU', 'CPU', 'NO', 'ESTADO', 'DELL', 'DCCY', 'HREMEXPR40608543931700663PSVKW', 'L', 'USADO']
# ['PECAS', 'DIVERSAS', 'KIT', 'MEDIDOR', 'DE', 'COR', 'NO', 'ESTADO', 'MINOLTA', 'CR', '300', 'AWB369699472314590545164', 'L', 'USADO']
# ['TELEFONES', 'TELEFONE', 'CELULAR', 'IPHONE', 'NO', 'ESTADO', 'APPLE', 'AWB369699473933160126686', 'L', 'USADO']
# ['VENTILADOR', 'PARANA', 'LACRES', 'Nº', '22346', '22347', '22348', '22349']
# ['MANTA', 'COBRE', 'LEITO', 'TAPETE', 'LACRES', 'Nº', '23350', '23351', '23352', '23353', '23354', '23355']
# ['BRINQUEDOS', 'BRINQUEDO', 'E', 'BAZAR', 'LACRES', 'Nº', '022356', '022357', '022358', '']
# ['BRINQUEDOS', 'BRINQUEDO', 'E', 'BAZAR', 'LACRES', 'Nº', '022356', '022357', '022358', '']
# ['MANTA', 'COBRE', 'LEITO', 'TAPETE', 'LACRES', 'Nº', '23350', '23351', '23352', '23353', '23354', '23355']
# ['VENTILADOR', 'PARANA', 'LACRES', 'Nº', '22346', '22347', '22348', '22349']
# ['BRINQUEDOS', 'BRINQUEDO', 'E', 'BAZAR', 'LACRES', 'Nº', '022356', '022357', '022358', '']
# ['MANTA', 'COBRE', 'LEITO', 'TAPETE', 'LACRES', 'Nº', '23350', '23351', '23352', '23353', '23354', '23355']
# ['VENTILADOR', 'PARANA', 'LACRES', 'Nº', '22346', '22347', '22348', '22349']
# ['PNEUS', 'PNEU', 'DE', 'AUTOMOVEL', 'DUPLADO', 'NO', 'INTERIOR', 'DOS', 'QUATRO', 'RODANDO']
# ['PERFUMES', 'PERFUME', 'DREAM', 'BRAND', 'NO', '021', '25ML']
# ['ARMAS', 'PARTES', 'E', 'PEÇAS', 'ARMA', 'FOGO', 'DLASK', 'ARMS', 'CORP', 'ULTRA', 'LIGHT', 'TRIGGER', 'GATILHO', 'PARA', 'ARMAS', 'DE', 'FOGO', 'FABRICADO', 'NO', 'CANADÁ']
# ['ARMAS', 'PARTES', 'E', 'PEÇAS', 'ARMA', 'FOGO', 'WEAVER', 'MODELO', '849970', 'MIRA', 'TELESCÓPICA', 'N', 'SÉRIE', 'C08668', 'FABRICADA', 'NO', 'JAPÃO']
# ['ARMAS', 'PARTES', 'E', 'PEÇAS', 'ARMA', 'FOGO', 'CANOS', 'DE', 'ARMA', 'DE', 'FOGO', '40', 'S', 'W', 'Nº', '5010', 'PCE', '']
# ['BRINQUEDOS', 'BRINQUEDO', 'ZHI', 'LE', 'XING', 'NO', 'H241', 'BOLA', 'VOADORA']
# ['PNEU', 'HELY', '22', '5', '295', '80', 'INSTALADOS', 'NO', 'CAMINHÃO', 'PLACAS', 'HEQ', '5365', 'SENDO', '1', 'ESTEPE', 'PNEUS', 'NOVOS', '']
# ['PNEU', 'HELY', '22', '5', '295', '80', 'INSTALADOS', 'NO', 'CAMINHÃO', 'PLACAS', 'OCZ', '5833', 'SENDO', '2', 'ESTEPES', 'PNEUS', 'NOVOS', '']
# ['BEBIDAS', 'BEBIDA', 'MOUCHÃO', 'VINHO', 'TINTO', 'TUNEL', 'Nº', '3', '4', 'SAFRA', '2013', '750', 'ML', 'GARRAFA']
# ['EMBALAGEM', 'DE', 'PAPEL', 'ROLEX', 'ESTOJO', 'DE', 'RELÓGIO', 'ROLEX', 'S', 'O', 'RELÓGIO', 'Nº', 'SÉRIE', '39139', '08', 'UNIDADE']
# ['EMBALAGEM', 'DE', 'PAPEL', 'ROLEX', 'ESTOJO', 'DE', 'RELÓGIO', 'ROLEX', 'S', 'O', 'RELÓGIO', 'Nº', 'SÉRIE', '39139', '02', 'UNIDADE']
# ['RELOGIOS', 'RELOGIO', 'DE', 'PULSO', 'INVICTA', 'MODELO', 'NO', '18213', 'NÃO', 'IDENTIFICANDO', 'ORIGEM']
# ['RELOGIOS', 'RELOGIO', 'DE', 'PULSO', 'INVICTA', 'RESERVE', 'BOLT', 'ZEUS', 'MODELO', 'NO', '25209', 'NÃO', 'IDENTIFICANDO', 'ORIGEM']
# ['INFORMATICA', 'IMPRESSORA', 'MAGICARD', 'ENDURONEO', 'DUPLEX', 'FABRICADO', 'NO', 'REINO', 'UNIDO']
# ['RELOGIOS', 'RELOGIO', 'DE', 'PULSO', 'INVICTA', 'MODEL', 'NO', '6981']
# ['RELOGIOS', 'RELOGIO', 'DE', 'PULSO', 'INVICTA', 'MODEL', 'NO', '25852']
# ['RELOGIOS', 'RELOGIO', 'DE', 'PULSO', 'INVICTA', 'MODEL', 'NO', '3330']
# ['VIDEOGAMES', 'VIDEO', 'GAME', 'MICROSOFT', 'X', 'BOX', 'ONE', 'X', '1TB', '1TO', 'SKU', 'CYV', '00001', 'Nº', 'SÉRIE', '059928183217', 'CHINA']
# ['INFORMATICA', 'NOTEBOOK', 'APPLE', 'MACBOOK', 'AIR', '13', 'INCH', 'MODEL', 'Nº', 'A2179', 'SFVFCPVMGMNHP', 'CHINA', 'CP12', '003']
# ['RELOGIOS', 'RELOGIO', 'DE', 'PULSO', 'INDICANDO', 'INVICTA', 'MODEL', 'NO', '23702', 'MADE', 'IN', 'JAPAN', 'BF', '291']
# ['LUNETA', 'BUSHNELL', 'BANNER', '9900000801359', '3', '9X40EG', 'NO', '80135', 'BF', '251']
# ['LUNETA', 'HERO', '6', '24X50AOE', 'NO', '100933', 'BF', '264']
# ['INFORMATICA', 'NOTEBOOK', 'MACBOOK', 'PRO', '13', 'INCH', 'MODEL', 'NO', 'A2159', '8GB', '256GB', 'SERIAL', 'SC02Z265NL410', 'CHINA', 'BF', '061']
# ['ROUPAS', 'DIVERSAS', 'CONFORME', 'TERMO', 'DE', 'CONTAGEM', 'E', 'IDENTIFICAÇÃO', 'NO', 'ANEXO', '2', 'DSIC', '091', '1300', '1936']
# ['', 'PEÇA', 'METÁLICA', 'MARCA', 'GRACE', 'Nº', '9801402']
# ['', 'PEÇA', 'METÁLICA', 'MARCA', 'GRACE', 'Nº', '9801402']
# ['', 'SUPLEMENTO', 'NO', 'FLUSH', 'NIACIN', '800MG', '100', 'CÁPSULAS', 'LIFE', 'EXTENSION']
# ['SUPLEMENTO', 'NO', 'FLUSH', 'NIACIN', '800MG', '100', 'CÁPSULAS', 'LIFE', 'EXTENSION']
# ['SUBST', 'QUIMICA', 'NAO', 'IDENTF', 'TRATA', 'SE', 'PROVAVELMENTE', 'DE', 'SKUNK', 'PESO', 'DA', 'ENCOMENDA', 'NOS', 'CORREIOS', 'DE', '0', '069', 'KG', '']
# ['CINZEIRO', 'DE', 'VIDRO', 'YG17007', 'COM', 'ESTAMPAS', 'FOLHAS', 'DE', 'CANNABIS', 'SATIVA', 'MACONHA', 'DI', 'Nº', '20', '0392493', '0', 'AD', '07', 'ITEM', '01']
# ['CINZEIRO', 'DE', 'VIDRO', 'YG17006', 'COM', 'ESTAMPAS', 'FOLHAS', 'DE', 'CANNABIS', 'SATIVA', 'MACONHA', 'DI', 'Nº', '20', '0392493', '0', 'AD', '07', 'ITEM', '02']
# ['CINZEIRO', 'DE', 'VIDRO', 'YG17007', 'COM', 'ESTAMPAS', 'FOLHAS', 'DE', 'CANNABIS', 'SATIVA', 'MACONHA', 'DI', 'Nº', '20', '0392493', '0', 'AD', '07', 'ITEM', '01']
# ['CINZEIRO', 'DE', 'VIDRO', 'YG17006', 'COM', 'ESTAMPAS', 'FOLHAS', 'DE', 'CANNABIS', 'SATIVA', 'MACONHA', 'DI', 'Nº', '20', '0392493', '0', 'AD', '07', 'ITEM', '02']
# ['TECIDO', 'CORTE', '2', '100', 'ROLOS', '100', 'POLIESTER', 'TECIDO', 'PLANO', 'TINTO', '75', 'DTEX', 'NO', 'URDUME', '150', 'DTEX', 'TRAMA', '96X54', 'LARGURA', '2', '40M', 'GRAM', '65G', 'M2', 'S', 'FIO', 'BORRACHA']
# ['TECIDO', 'CORTE', '729', 'ROLOS', '100', 'POLIESTER', 'TECIDO', 'PLANO', 'TINTO', '75', 'DTEX', 'NO', 'URDUME', '150', 'DTEX', 'TRAMA', '96X54', 'LARGURA', '2', '40M', 'GRAM', '65G', 'M2', 'S', 'FIO', 'BORRACHA']

# %%
# itens.loc[8].descricao, itens.loc[8].descricao_limpa_stemming

# %%
word_count.most_common(20)
# Out:
# [(b'de', 49732),
#  (b'telefon', 38773),
#  (b'eletron', 34361),
#  (b'xiaom', 27098),
#  (b'informa', 23422),
#  (b'perfum', 22427),
#  (b'redm', 19080),
#  (b'celul', 17507),
#  (b'smartphon', 16322),
#  (b'not', 13399),
#  (b'beb', 13189),
#  (b'cigarr', 12472),
#  (b'chin', 12363),
#  (b'orig', 11809),
#  (b's', 10987),
#  (b'64gb', 9854),
#  (b'128gb', 9582),
#  (b'vinh', 9010),
#  (b'9', 7733),
#  (b'vestuari', 7699)]

# %% [markdown]
# ## 7.2 - Nuvem de palavras - 50 palavras mais frequentes

# %%
max_values = 50
text = {}
for (k, v) in word_count.most_common(max_values):
    text[str(k.decode())] = v

# %%
wordcloud = WordCloud(width=1600, height=800).generate_from_frequencies(text)

# %%
fig, ax = plt.subplots(figsize=(20,10))
ax.imshow(wordcloud, interpolation='bilinear')
ax.set_axis_off()
plt.show()

# %%
df_word_count['descricao_limpa_stemming'] = text.keys()
df_word_count.head(10)
# Out:
#   descricao_limpa descricao_limpa_sem_stopwords descricao_limpa_stemming
# 0              de                     telefones                       de
# 1     eletronicos                   informatica                  telefon
# 2       telefones                       celular                  eletron
# 3          xiaomi                    smartphone                    xiaom
# 4     informatica                       bebidas                  informa
# 5           redmi                      telefone                   perfum
# 6         celular                       perfume                     redm
# 7      smartphone                      perfumes                    celul
# 8            note                         vinho                smartphon
# 9           china                      roteador                      not

# %% [markdown]
# ### Conclusão: ainda há o problema das stopwords, mas com  retirada dos afixos houve agrupamento de algumas palavras como 'feminino' e 'feminina', 'boneco' e 'boneca', 'diversos' e 'diversas', entre outras. Mas aparentemente não alterou as palavras mais frequentes.

# %% [markdown]
# # obs: esse dataframe não será utilizado como dado de entrada do modelo

# %% [markdown]
# ## 7.3 - Salva dataframe em formato parquet

# %%
secta.to_parquet('3_secta_desc_limpa_stemming.parquet')  # salva em formato parquet

# %% [markdown]
# ## 8 - Cria a coluna 'descricao_limpa_sem_stopwords_stemming'
# ## 8.1 - Nessa coluna foram retiradas as stopwords e os afixos

# %%
num_words, word_count = cria_coluna_descricao(secta, 'descricao', 'descricao_limpa_sem_stopwords_stemming', stopwords, True)

# %%
# itens.loc[8].descricao, itens.loc[8].descricao_limpa_sem_stopwords_stemming

# %%
word_count.most_common(20)
# Out:
# [(b'telefon', 38773),
#  (b'informa', 23422),
#  (b'perfum', 22427),
#  (b'celul', 17507),
#  (b'smartphon', 16322),
#  (b'beb', 13189),
#  (b'vinh', 9010),
#  (b'vestuari', 7699),
#  (b'brinqued', 6789),
#  (b'rote', 6414),
#  (b'recep', 6365),
#  (b'cigarr', 5486),
#  (b'divers', 5404),
#  (b'fon', 4954),
#  (b'pro', 4590),
#  (b'aces', 4484),
#  (b'satelit', 4378),
#  (b'acus', 4012),
#  (b'smartwatch', 3959),
#  (b'relog', 3852)]

# %% [markdown]
# ## 8.2 - Nuvem de palavras - 50 palavras mais frequentes

# %%
max_values = 50
text = {}
for (k, v) in word_count.most_common(max_values):
    text[str(k.decode())] = v

# %%
wordcloud = WordCloud(width=1600, height=800).generate_from_frequencies(text)

# %%
fig, ax = plt.subplots(figsize=(20,10))
ax.imshow(wordcloud, interpolation='bilinear')
ax.set_axis_off()
plt.show()

# %%
df_word_count['descricao_limpa_sem_stopwords_stemming'] = text.keys()

# %%
df_word_count = df_word_count.drop('descricao_limpa_stemming', 1)

# %%
df_word_count.head(20)
# Out:
#    descricao_limpa descricao_limpa_sem_stopwords  \
# 0               de                     telefones
# 1      eletronicos                   informatica
# 2        telefones                       celular
# 3           xiaomi                    smartphone
# 4      informatica                       bebidas
# 5            redmi                      telefone
# 6          celular                       perfume
# 7       smartphone                      perfumes
# 8             note                         vinho
# 9            china                      roteador
# 10         bebidas                      receptor
# 11          origem                    vestuarios
# 12        telefone                      cigarros
# 13         perfume                          fone
# 14        perfumes                           pro
# 15               s                         acess
# 16            64gb                      satelite
# 17           128gb                      acustica
# 18           vinho                    smartwatch
# 19               9                         relog
#
#    descricao_limpa_sem_stopwords_stemming
# 0                                 telefon
# 1                                 informa
# 2                                  perfum
# 3                                   celul
# 4                               smartphon
# 5                                     beb
# 6                                    vinh
# 7                                vestuari
# 8                                brinqued
# 9                                    rote
# 10                                  recep
# 11                                 cigarr
# 12                                 divers
# 13                                    fon
# 14                                    pro
# 15                                   aces
# 16                                satelit
# 17                                   acus
# 18                             smartwatch
# 19                                  relog

# %% [markdown]
# ### Conclusão: retirando as stopwords podemos perceber uma diferença nas palavras mais relevantes. Contudo o fato de utilizar a técnica de stemming não surte muito efeito.

# %% [markdown]
# ## 8.3 - Salva dataframe em formato parquet

# %%
secta.to_parquet('3_secta_desc_limpa_sem_stopwords_stemming.parquet')  # salva em formato parquet
